# %%
import sys
import time
import csv
import math
import numpy as np
import pyspark
from pyspark import SparkContext, SparkConf
import json
from operator import add
import pandas as pd
import xgboost as xgb
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from node2vec import Node2Vec as n2v
import networkx as nx
from hashlib import md5
import pickle
import os

pd.set_option('display.max_rows', None)

folder_path = "../data/"
test_filepath = "../yelp_true.csv"
output_filepath = ""

from utils import create_category_md5_mapping, integrate_mapping_user_bus_cat_data, dataframe_to_rdd_dict, analyze_top_business_categories, analyze_top_categories

# %%
def initialize_spark_context(APP_NAME="Train: XGBModel"):
    # Spark配置项列表
    SPARK_CONF = [
        ("spark.dynamicAllocation.enabled", "true"),  # 启用动态资源分配
        ("spark.dynamicAllocation.maxExecutors", "10"),  # 最大执行器数量
        ("spark.executor.memory", "3g"),  # 每个执行器的内存
        ("spark.executor.cores", "6"),  # 每个执行器的CPU核心数
        ("spark.executor.memoryOverhead", "3000"),  # 执行器内存开销
        ("spark.driver.memory", "4g"),  # 驱动程序的内存
        ("spark.driver.maxResultSize", "2g"),  # 驱动程序的最大结果大小
        ("spark.python.worker.memory", "2g"),  # Python工作进程的内存
        ("spark.sql.shuffle.partitions", "25"),  # Shuffle操作的分区数
        ("spark.sql.sources.partitionOverWriteMode", "dynamic"),  # 分区覆写模式
        ("spark.network.timeout", "600s"),  # 网络超时设置
        ("spark.executor.heartbeatInterval", "120s"),  # 执行器心跳间隔
    ]

    # 创建Spark配置
    spark_conf = pyspark.SparkConf()
    spark_conf.setAppName(APP_NAME)
    spark_conf.setAll(SPARK_CONF)

    # 创建SparkContext
    sc = pyspark.SparkContext(conf=spark_conf)
    sc.setLogLevel("ERROR")  # 设置日志级别

    return sc

sc = initialize_spark_context()
# Out:
# 24/04/19 13:02:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 32968)
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.8/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.8/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.8/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/usr/local/lib/python3.8/dist-packages/pyspark/accumulators.py", line 262, in handle
#     poll(accum_updates)
#   File "/usr/local/lib/python3.8/dist-packages/pyspark/accumulators.py", line 235, in poll
#     if func():
#   File "/usr/local/lib/python3.8/dist-packages/pyspark/accumulators.py", line 239, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/usr/local/lib/python3.8/dist-packages/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %% [markdown]
# # Initialize

# %%
# test
from better_features import FeatureProcessor, read_json_data, transform_user_data, transform_business_data,extract_review_data,extract_business_data
from KMeans_user_cluster import KMeans_process_user_clusters

# folder_path = '../data/'
# user_parsed_df = pd.read_csv('../well-trained/cache/user_df.csv')
# business_parsed_df = pd.read_csv('../well-trained/cache/business_df.csv')
# review_data = read_json_data(folder_path + '/review_train.json', extract_review_data, sc).collect()
# feature_processor = FeatureProcessor(user_parsed_df, business_parsed_df, review_data)

# from utils import integrate_mapping_user_bus_cat_data
# # category: category md5 mapping
# category_md5_df = create_category_md5_mapping(feature_processor.business_df)

# # historical reviews 
# final_mapped_review_df = integrate_mapping_user_bus_cat_data(feature_processor.df_conn, category_md5_df, review_data)

# %% [markdown]
# # Begin

# %% [markdown]
# ### Process a User-Biz Matrix using tip.json and train ALS

# %%
from pyspark import SparkContext, SparkConf
from collections import defaultdict

# 读取数据
# testing
rdd = sc.textFile('../data/tip.json')

# 解析JSON数据，每一行是一个字符串化的JSON对象
def parse_json(line):
    try:
        data = json.loads(line)
        return ((data['user_id'], data['business_id']), 1)
    except json.JSONDecodeError:
        return None

# %%
# 将数据解析成((user_id, business_id), 1)的元组
interaction_counts = rdd.map(parse_json).filter(lambda x: x is not None)

# 对所有交互进行计数, 后续使用；
user_business_interaction_counts = interaction_counts.reduceByKey(lambda a, b: a + b)

# 现在我们有了((user_id, business_id), count)的RDD
# 转换为(user_id, (business_id, count))
user_business_pairs = user_business_interaction_counts.map(lambda x: (x[0][0], (x[0][1], x[1])))

# 为了构建交互矩阵，我们将对每个用户的所有交互进行分组
user_grouped_interactions = user_business_pairs.groupByKey()

# 最终，我们将为每个用户生成一个包含所有商户ID和交互次数的列表
user_interaction_lists = user_grouped_interactions.mapValues(list)

# %%
from pyspark.mllib.recommendation import ALS
from pyspark import SparkContext, SparkConf
from pyspark.mllib.recommendation import MatrixFactorizationModel

# id转换为数值, id: string->int
user_ids = user_business_interaction_counts.keys().map(lambda x: x[0]).distinct().zipWithUniqueId().collectAsMap()
business_ids = user_business_interaction_counts.keys().map(lambda x: x[1]).distinct().zipWithUniqueId().collectAsMap()
user_ids_bcast = sc.broadcast(user_ids)
business_ids_bcast = sc.broadcast(business_ids)

def to_rating(line):
    user_id, business_id = line[0]
    count = line[1]
    return (user_ids_bcast.value[user_id], business_ids_bcast.value[business_id], count)

ratings = user_business_interaction_counts.map(to_rating)

# %%
# # if necessary (optional)
# num_partitions = 200  # 例如，根据您的集群大小可以调整此值
# partitioned_interactions = user_grouped_interactions.partitionBy(num_partitions)

# %%
# ratings.take(20)

# %%
# user_interaction_lists.take(1)
# Out:
# [('ulQ8Nyj7jCUR8M83SUMoRQ',
#   [('KNpcPGqDORDdvtekXd348w', 3),
#    ('Tl_jT2a0bRMac5_YW65GPg', 2),
#    ('c5NHHW0sNm7eaQBwvQJkkw', 1),
#    ('ESzO3Av0b1_TzKOiqzbQYQ', 1),
#    ('dAa0hB2yrnHzVmsCkN4YvQ', 1),
#    ('k7WRPbDd7rztjHcGGkEjlw', 2),
#    ('zJwm3DThV4WUIkyNv68Ahw', 1),
#    ('ofXtrtsaKzPpVXFa8fHgiw', 1),
#    ('SqW3igh1_Png336VIb5DUA', 1),
#    ('8qNOI6Q1-rJrvWWD5Btz6w', 2),
#    ('A73Dp0lo9s_Ci9NFDqbhqw', 1),
#    ('FCUVjQf762no86Uzcbv1Tg', 1),
#    ('--ujyvoQlwVoBgMYtADiLA', 1)])]

# %%
# ALS fine-tuned
rank=10
RegParam=0.5
alpha=1520.0

model = ALS.trainImplicit(ratings, rank, alpha=alpha, lambda_=reg_param)

# %% [markdown]
# ### use trained ALS to decomposed U, V vectors, but we need to fine-tune params first

# %%
# use trained ALS to decomposed U, V vectors
user_features_rdd = model.userFeatures()
product_features_rdd = model.productFeatures()
# .collectAsMap()

# %%
## matrix size=120000 , not that big, super fast
start_time = time.time()

user_features = user_features_rdd.collectAsMap()
product_features = product_features_rdd.collectAsMap()

print(time.time() - start_time)

# %%
# dot product of U*V
def affinity_score(user_id, business_id):
    user_feature = user_features[user_ids_bcast.value[user_id]]
    business_feature = product_features[business_ids_bcast.value[business_id]]
    return sum(x * y for x, y in zip(user_feature, business_feature))

# %%
# example_user_id = 'ulQ8Nyj7jCUR8M83SUMoRQ'
# example_business_id = 'Y9LN295xg9dQGBgbtu9Oaw'
# score = affinity_score(example_user_id, example_business_id)
# print("Affinity score for user {} and business {}: {}".format(example_user_id, example_business_id, score))

# %%
product_features[121030][5]

# %%
# product_features

# %%
# TODO

# %% [markdown]
# # Fine-Tune ALS: GridSearch to Find Best HyperParameters for ALS model

# %%
from pyspark.mllib.recommendation import ALS, Rating
from pyspark import SparkContext
from math import sqrt
import itertools

# %%
user_to_num_dict = user_ids_bcast.value
business_to_num_dict = business_ids_bcast.value
user_to_num_bc = sc.broadcast(user_to_num_dict)
business_to_num_bc = sc.broadcast(business_to_num_dict)

# %% [markdown]
# ## LOCAL GRID SEARCH

# %%
# Create Train, Val Set: ((user_id, business_id), count) format
training_rdd, validations_rdd = user_business_interaction_counts.randomSplit([0.8, 0.2], seed=42)

from pyspark.mllib.recommendation import ALS
from math import sqrt

# 创建Rating对象的RDD
ratings_rdd = user_business_interaction_counts.map(
    lambda p: Rating(user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]], float(p[1]))
)

# ALS模型参数网格搜索
ranks = [15, 20, 25]
reg_params = [0.01, 0.1, 1.0]
alphas = [0.01, 0.1, 1.0]
best_rmse = float('inf')
best_model = None
best_rank = 0
best_reg_param = 0
best_alpha = 0

for rank in ranks:
    for reg_param in reg_params:
        for alpha in alphas:
            for iteration in iterations:
                # 训练ALS模型
                model = ALS.trainImplicit(ratings_rdd, rank, seed=42, iterations=5, lambda_=reg_param, alpha=alpha)
                
                # 在验证集上评估模型
                # 我们需要将验证集的交互数据转换为(user_id_num, business_id_num)格式
                # 然后使用训练好的模型对其进行评分预测，并计算RMSE
                # 这里只是代码的框架，需要根据实际的验证集来实现评分预测和RMSE的计算
    
                # 假设validations_rdd是验证集的RDD，其格式为((user_id, business_id), count)
                validation_for_predict_rdd = validations_rdd.map(
                    lambda p: (user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]])
                )
                predictions = model.predictAll(validation_for_predict_rdd).map(
                    lambda r: ((r[0], r[1]), r[2])
                )
                rates_and_preds = validations_rdd.map(
                    lambda p: ((user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]]), float(p[1]))
                ).join(predictions)
                rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())
                
                # 比较并保存最佳模型
                if rmse < best_rmse:
                    best_rmse = rmse
                    best_model = model
                    best_rank = rank
                    best_reg_param = reg_param
                    best_alpha = alpha

# 打印最佳模型的参数
print(f"Best RMSE: {best_rmse}")
print(f"Best Rank: {best_rank}")
print(f"Best Regularization Parameter: {best_reg_param}")
print(f"Best Alpha: {best_alpha}")
# Out:
# 24/04/17 09:33:03 WARN BlockManager: Task 263082 already completed, not releasing lock for rdd_31_0
# 24/04/17 09:33:19 WARN BlockManager: Task 264159 already completed, not releasing lock for rdd_31_0
# 24/04/17 09:34:20 WARN BlockManager: Task 268350 already completed, not releasing lock for rdd_31_0
# 24/04/17 09:35:08 WARN BlockManager: Task 271084 already completed, not releasing lock for rdd_31_0
# [Stage 209721:===========================================>        (16 + 3) / 19]
# Best RMSE: 1.5809843015468776
# Best Rank: 15
# Best Regularization Parameter: 0.1
# Best Alpha: 1.0

# %% [markdown]
# ### BEST RMSE (Unprocessesd):

# %% [raw]
# Best RMSE: 1.5809843015468776
# Best Rank: 15
# Best Regularization Parameter: 0.1
# Best Alpha: 1.0
#
# Best parameters: (1.6605276164617149, 25, 0.1, 1.5)

# %% [markdown]
# ### EVALUATE: Log_transform score, user_business_interaction_counts and Determine Performance Metric (Cosine Dist. MAE)

# %%
test_df = user_business_interaction_counts.collect()

# %%
unique_users = user_business_interaction_counts.map(lambda x: x[0][0]).distinct().count()
unique_businesses = user_business_interaction_counts.map(lambda x: x[0][1]).distinct().count()
print(f"Unique Users: {unique_users}")
print(f"Unique Businesses: {unique_businesses}")

interaction_stats = user_business_interaction_counts.map(lambda x: x[1]).stats()
print(f"Interaction Counts Stats: {interaction_stats}")
# Out:
# Total interactions: 999945
# Unique Users: 304870
# Unique Businesses: 121526
# Interaction Counts Stats: (count: 999945, mean: 1.185413197725872, stdev: 1.2011436999553304, max: 284.0, min: 1.0)

# %%
# 使用histogram查看分布情况
interaction_histogram = user_business_interaction_counts.map(lambda x: x[1]).histogram(10)
for i, count in zip(interaction_histogram[0][:-1], interaction_histogram[1]):
    print(f"Interaction count range: {i} to {interaction_histogram[0][interaction_histogram[0].index(i)+1]}, Count: {count}")
# Out:
# Interaction count range: 1.0 to 29.3, Count: 999780
# Interaction count range: 29.3 to 57.6, Count: 118
# Interaction count range: 57.6 to 85.9, Count: 22
# Interaction count range: 85.9 to 114.2, Count: 14
# Interaction count range: 114.2 to 142.5, Count: 2
# Interaction count range: 142.5 to 170.8, Count: 5
# Interaction count range: 170.8 to 199.1, Count: 2
# Interaction count range: 199.1 to 227.4, Count: 1
# Interaction count range: 227.4 to 255.70000000000002, Count: 0
# Interaction count range: 255.70000000000002 to 284, Count: 1

# %%
from math import log

# 计算对数转换需要的基础值
min_interaction = 1  # 已知最小值
max_interaction = 284  # 已知最大值
log_min = log(min_interaction + 1)
log_max = log(max_interaction + 1)

def normalize_interaction(interaction):
    """ 将原始互动次数转换为1到5的评分 """
    normalized_rating = 1 + 4 * (log(interaction + 1) - log_min) / (log_max - log_min)
    return normalized_rating

# 应用转换
normalized_ratings_rdd = user_business_interaction_counts.map(
    lambda p: Rating(user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]], normalize_interaction(p[1]))
)

# %%
normalized_ratings_rdd
# Out:
# PythonRDD[41] at RDD at PythonRDD.scala:53

# %%
# # 查找异常高的交互次数
# high_interactions = user_business_interaction_counts.filter(lambda x: x[1] > 10).collect()
# print(f"High Interactions: {high_interactions[:10]}")  # 打印前10个例子
# Out:
# High Interactions: [(('blrWvPePSv87aU9hV1Zd8Q', 'Bf-yMQiSmDZyqfGyFKQ0bA'), 14), (('wNMnTY2D3hMTZSzSaU4EMw', 'Pn1f4xiZoynF0nDb-vtY0A'), 17), (('UsmTxWbobLsI6WR1Db0W7A', 'ESzO3Av0b1_TzKOiqzbQYQ'), 20), (('UsmTxWbobLsI6WR1Db0W7A', 'X-b4-QvZLENnf3yFwhpSXQ'), 12), (('6tbXpUIU6upoeqWNDo9k_A', 'ZR_UyVncA3R3pQu79MGr_A'), 11), (('CbmNBkKa9QKNxPiN_whFUw', 'Z7UryKxT7drcxbDjPSn4hA'), 12), (('jlpapIPWURjBUg3V31AjKw', '1Z4_zSITNVQ_Bt027R0S1g'), 11), (('B5FTjNWSgkAQ9UjOKVjGhw', 'j37Z4LIXTH9j6KOq9aX8DQ'), 11), (('rh_p4FqrWJcWGjcUA-oj0A', 'qNSZpcyoF7OM6g49sAFUcQ'), 14), (('SlgpAnj2gQd44EM_Uq6DkQ', 'IGxxnH4Q2S2y_ZdFFW469w'), 34)]

# %% [markdown]
# ### SPARK GRID SEARCH WORKING!!! Update: replace metric: (MAE and cosine)

# %%
# ratings_rdd = user_business_interaction_counts.map(
#     lambda p: Rating(user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]], float(p[1]))
# )
# ratings_rdd.collect()
# Out:
# [Rating(user=4, product=3, rating=1.0),
#  Rating(user=0, product=5, rating=3.0),
#  Rating(user=11, product=10, rating=1.0),
#  Rating(user=11, product=6, rating=2.0),
#  Rating(user=11, product=1, rating=1.0),
#  Rating(user=11, product=2, rating=1.0),
#  Rating(user=18, product=9, rating=1.0),
#  Rating(user=18, product=8, rating=1.0),
#  Rating(user=18, product=16, rating=1.0),
#  Rating(user=6, product=12, rating=1.0),
#  Rating(user=6, product=0, rating=1.0),
#  Rating(user=6, product=15, rating=2.0),
#  Rating(user=2, product=4, rating=2.0),
#  Rating(user=3, product=17, rating=1.0),
#  Rating(user=3, product=11, rating=1.0),
#  Rating(user=3, product=22, rating=1.0),
#  Rating(user=3, product=29, rating=1.0),
#  Rating(user=3, product=5, rating=2.0),
#  Rating(user=3, product=18, rating=2.0),
#  Rating(user=3, product=19, rating=3.0),
#  Rating(user=7, product=26, rating=1.0),
#  Rating(user=10, product=36, rating=1.0),
#  Rating(user=10, product=7, rating=1.0),
#  Rating(user=13, product=25, rating=3.0),
#  Rating(user=13, product=43, rating=1.0),
#  Rating(user=13, product=33, rating=1.0),
#  Rating(user=13, product=14, rating=2.0),
#  Rating(user=13, product=50, rating=1.0),
#  Rating(user=9, product=32, rating=1.0),
#  Rating(user=9, product=39, rating=1.0),
#  Rating(user=9, product=23, rating=6.0),
#  Rating(user=9, product=30, rating=5.0),
#  Rating(user=9, product=24, rating=1.0),
#  Rating(user=9, product=13, rating=1.0),
#  Rating(user=9, product=31, rating=2.0),
#  Rating(user=9, product=57, rating=1.0),
#  Rating(user=9, product=37, rating=1.0),
#  Rating(user=9, product=64, rating=3.0),
#  Rating(user=9, product=21, rating=2.0),
#  Rating(user=9, product=71, rating=14.0),
#  Rating(user=9, product=46, rating=3.0),
#  Rating(user=9, product=44, rating=1.0),
#  Rating(user=9, product=28, rating=1.0),
#  Rating(user=9, product=78, rating=2.0),
#  Rating(user=9, product=20, rating=2.0),
#  Rating(user=9, product=35, rating=2.0),
#  Rating(user=25, product=38, rating=1.0),
#  Rating(user=25, product=37, rating=1.0),
#  Rating(user=25, product=85, rating=1.0),
#  Rating(user=25, product=42, rating=1.0),
#  Rating(user=25, product=49, rating=1.0),
#  Rating(user=25, product=40, rating=2.0),
#  Rating(user=25, product=47, rating=1.0),
#  Rating(user=16, product=92, rating=1.0),
#  Rating(user=16, product=27, rating=1.0),
#  Rating(user=16, product=54, rating=1.0),
#  Rating(user=16, product=53, rating=1.0),
#  Rating(user=16, product=34, rating=5.0),
#  Rating(user=16, product=45, rating=1.0),
#  Rating(user=16, product=52, rating=1.0),
#  Rating(user=1, product=59, rating=5.0),
#  Rating(user=1, product=51, rating=2.0),
#  Rating(user=1, product=41, rating=1.0),
#  Rating(user=1, product=58, rating=2.0),
#  Rating(user=1, product=60, rating=1.0),
#  Rating(user=1, product=66, rating=1.0),
#  Rating(user=1, product=56, rating=3.0),
#  Rating(user=1, product=67, rating=2.0),
#  Rating(user=1, product=74, rating=2.0),
#  Rating(user=1, product=48, rating=5.0),
#  Rating(user=1, product=81, rating=2.0),
#  Rating(user=1, product=55, rating=1.0),
#  Rating(user=1, product=73, rating=2.0),
#  Rating(user=1, product=99, rating=1.0),
#  Rating(user=1, product=65, rating=1.0),
#  Rating(user=1, product=62, rating=1.0),
#  Rating(user=1, product=69, rating=1.0),
#  Rating(user=1, product=76, rating=5.0),
#  Rating(user=1, product=63, rating=3.0),
#  Rating(user=1, product=106, rating=1.0),
#  Rating(user=1, product=83, rating=1.0),
#  Rating(user=1, product=61, rating=1.0),
#  Rating(user=1, product=113, rating=3.0),
#  Rating(user=1, product=120, rating=1.0),
#  Rating(user=1, product=127, rating=6.0),
#  Rating(user=1, product=90, rating=5.0),
#  Rating(user=1, product=68, rating=2.0),
#  Rating(user=1, product=72, rating=1.0),
#  Rating(user=1, product=70, rating=2.0),
#  Rating(user=1, product=79, rating=1.0),
#  Rating(user=1, product=88, rating=1.0),
#  Rating(user=1, product=80, rating=1.0),
#  Rating(user=1, product=134, rating=2.0),
#  Rating(user=1, product=77, rating=2.0),
#  Rating(user=1, product=95, rating=2.0),
#  Rating(user=1, product=102, rating=1.0),
#  Rating(user=1, product=75, rating=1.0),
#  Rating(user=1, product=87, rating=2.0),
#  Rating(user=1, product=86, rating=1.0),
#  Rating(user=1, product=84, rating=1.0),
#  Rating(user=1, product=91, rating=2.0),
#  Rating(user=1, product=94, rating=3.0),
#  Rating(user=1, product=101, rating=1.0),
#  Rating(user=1, product=98, rating=1.0),
#  Rating(user=1, product=109, rating=1.0),
#  Rating(user=1, product=93, rating=1.0),
#  Rating(user=1, product=97, rating=3.0),
#  Rating(user=1, product=104, rating=4.0),
#  Rating(user=1, product=116, rating=7.0),
#  Rating(user=1, product=111, rating=2.0),
#  Rating(user=1, product=108, rating=3.0),
#  Rating(user=1, product=82, rating=3.0),
#  Rating(user=1, product=115, rating=3.0),
#  Rating(user=1, product=141, rating=3.0),
#  Rating(user=8, product=148, rating=1.0),
#  Rating(user=8, product=122, rating=1.0),
#  Rating(user=8, product=129, rating=1.0),
#  Rating(user=14, product=155, rating=1.0),
#  Rating(user=14, product=118, rating=5.0),
#  Rating(user=14, product=123, rating=1.0),
#  Rating(user=14, product=105, rating=3.0),
#  Rating(user=23, product=89, rating=1.0),
#  Rating(user=15, product=96, rating=1.0),
#  Rating(user=22, product=100, rating=1.0),
#  Rating(user=32, product=136, rating=1.0),
#  Rating(user=20, product=62, rating=1.0),
#  Rating(user=17, product=112, rating=2.0),
#  Rating(user=39, product=107, rating=1.0),
#  Rating(user=5, product=143, rating=2.0),
#  Rating(user=5, product=150, rating=1.0),
#  Rating(user=5, product=119, rating=1.0),
#  Rating(user=27, product=157, rating=1.0),
#  Rating(user=27, product=164, rating=1.0),
#  Rating(user=27, product=126, rating=2.0),
#  Rating(user=27, product=133, rating=7.0),
#  Rating(user=21, product=130, rating=1.0),
#  Rating(user=21, product=171, rating=5.0),
#  Rating(user=21, product=140, rating=4.0),
#  Rating(user=21, product=137, rating=1.0),
#  Rating(user=21, product=147, rating=1.0),
#  Rating(user=21, product=162, rating=2.0),
#  Rating(user=21, product=144, rating=1.0),
#  Rating(user=34, product=125, rating=1.0),
#  Rating(user=12, product=151, rating=1.0),
#  Rating(user=12, product=154, rating=2.0),
#  Rating(user=12, product=103, rating=1.0),
#  Rating(user=28, product=151, rating=1.0),
#  Rating(user=29, product=114, rating=1.0),
#  Rating(user=29, product=132, rating=1.0),
#  Rating(user=29, product=121, rating=1.0),
#  Rating(user=35, product=158, rating=2.0),
#  Rating(user=35, product=110, rating=1.0),
#  Rating(user=41, product=165, rating=1.0),
#  Rating(user=41, product=128, rating=2.0),
#  Rating(user=41, product=139, rating=1.0),
#  Rating(user=36, product=117, rating=1.0),
#  Rating(user=48, product=124, rating=1.0),
#  Rating(user=19, product=114, rating=1.0),
#  Rating(user=55, product=146, rating=1.0),
#  Rating(user=55, product=161, rating=1.0),
#  Rating(user=55, product=135, rating=1.0),
#  Rating(user=55, product=168, rating=1.0),
#  Rating(user=24, product=169, rating=1.0),
#  Rating(user=42, product=153, rating=1.0),
#  Rating(user=30, product=131, rating=1.0),
#  Rating(user=31, product=142, rating=1.0),
#  Rating(user=49, product=142, rating=1.0),
#  Rating(user=56, product=149, rating=1.0),
#  Rating(user=26, product=149, rating=1.0),
#  Rating(user=37, product=160, rating=1.0),
#  Rating(user=44, product=178, rating=1.0),
#  Rating(user=46, product=176, rating=4.0),
#  Rating(user=46, product=138, rating=1.0),
#  Rating(user=46, product=145, rating=1.0),
#  Rating(user=38, product=37, rating=1.0),
#  Rating(user=38, product=167, rating=2.0),
#  Rating(user=38, product=152, rating=1.0),
#  Rating(user=51, product=185, rating=1.0),
#  Rating(user=51, product=183, rating=1.0),
#  Rating(user=51, product=159, rating=1.0),
#  Rating(user=51, product=166, rating=1.0),
#  Rating(user=51, product=175, rating=1.0),
#  Rating(user=51, product=172, rating=2.0),
#  Rating(user=51, product=192, rating=1.0),
#  Rating(user=51, product=173, rating=1.0),
#  Rating(user=51, product=199, rating=1.0),
#  Rating(user=51, product=190, rating=1.0),
#  Rating(user=51, product=174, rating=1.0),
#  Rating(user=51, product=156, rating=1.0),
#  Rating(user=51, product=197, rating=1.0),
#  Rating(user=51, product=204, rating=1.0),
#  Rating(user=51, product=182, rating=1.0),
#  Rating(user=51, product=181, rating=1.0),
#  Rating(user=51, product=211, rating=2.0),
#  Rating(user=51, product=179, rating=3.0),
#  Rating(user=51, product=163, rating=1.0),
#  Rating(user=51, product=170, rating=1.0),
#  Rating(user=51, product=177, rating=1.0),
#  Rating(user=51, product=206, rating=1.0),
#  Rating(user=51, product=189, rating=1.0),
#  Rating(user=51, product=213, rating=1.0),
#  Rating(user=45, product=220, rating=1.0),
#  Rating(user=45, product=196, rating=2.0),
#  Rating(user=63, product=180, rating=1.0),
#  Rating(user=33, product=187, rating=2.0),
#  Rating(user=33, product=184, rating=1.0),
#  Rating(user=52, product=186, rating=1.0),
#  Rating(user=52, product=227, rating=1.0),
#  Rating(user=70, product=188, rating=1.0),
#  Rating(user=58, product=218, rating=1.0),
#  Rating(user=58, product=225, rating=1.0),
#  Rating(user=58, product=234, rating=1.0),
#  Rating(user=58, product=191, rating=1.0),
#  Rating(user=58, product=241, rating=3.0),
#  Rating(user=58, product=143, rating=2.0),
#  Rating(user=58, product=232, rating=3.0),
#  Rating(user=58, product=193, rating=1.0),
#  Rating(user=58, product=195, rating=1.0),
#  Rating(user=58, product=194, rating=2.0),
#  Rating(user=58, product=198, rating=2.0),
#  Rating(user=58, product=248, rating=1.0),
#  Rating(user=58, product=200, rating=1.0),
#  Rating(user=59, product=207, rating=1.0),
#  Rating(user=65, product=202, rating=1.0),
#  Rating(user=65, product=239, rating=1.0),
#  Rating(user=77, product=246, rating=1.0),
#  Rating(user=77, product=255, rating=1.0),
#  Rating(user=77, product=209, rating=1.0),
#  Rating(user=77, product=205, rating=1.0),
#  Rating(user=77, product=262, rating=1.0),
#  Rating(user=77, product=203, rating=1.0),
#  Rating(user=77, product=253, rating=1.0),
#  Rating(user=77, product=212, rating=1.0),
#  Rating(user=77, product=214, rating=1.0),
#  Rating(user=77, product=201, rating=1.0),
#  Rating(user=77, product=216, rating=1.0),
#  Rating(user=77, product=260, rating=3.0),
#  Rating(user=77, product=221, rating=8.0),
#  Rating(user=62, product=219, rating=1.0),
#  Rating(user=62, product=269, rating=1.0),
#  Rating(user=40, product=223, rating=1.0),
#  Rating(user=47, product=267, rating=1.0),
#  Rating(user=54, product=210, rating=1.0),
#  Rating(user=69, product=267, rating=3.0),
#  Rating(user=69, product=217, rating=1.0),
#  Rating(user=69, product=224, rating=17.0),
#  Rating(user=53, product=226, rating=1.0),
#  Rating(user=53, product=231, rating=1.0),
#  Rating(user=53, product=274, rating=8.0),
#  Rating(user=61, product=228, rating=1.0),
#  Rating(user=61, product=233, rating=1.0),
#  Rating(user=61, product=240, rating=1.0),
#  Rating(user=68, product=208, rating=1.0),
#  Rating(user=68, product=238, rating=1.0),
#  Rating(user=68, product=247, rating=1.0),
#  Rating(user=68, product=235, rating=2.0),
#  Rating(user=68, product=254, rating=1.0),
#  Rating(user=68, product=242, rating=1.0),
#  Rating(user=68, product=249, rating=1.0),
#  Rating(user=68, product=215, rating=1.0),
#  Rating(user=68, product=230, rating=1.0),
#  Rating(user=68, product=237, rating=1.0),
#  Rating(user=68, product=222, rating=2.0),
#  Rating(user=68, product=281, rating=1.0),
#  Rating(user=68, product=256, rating=1.0),
#  Rating(user=72, product=244, rating=1.0),
#  Rating(user=72, product=251, rating=1.0),
#  Rating(user=72, product=234, rating=1.0),
#  Rating(user=72, product=245, rating=1.0),
#  Rating(user=72, product=229, rating=2.0),
#  Rating(user=72, product=252, rating=1.0),
#  Rating(user=72, product=258, rating=3.0),
#  Rating(user=76, product=259, rating=1.0),
#  Rating(user=66, product=288, rating=1.0),
#  Rating(user=66, product=236, rating=1.0),
#  Rating(user=60, product=263, rating=1.0),
#  Rating(user=60, product=276, rating=1.0),
#  Rating(user=60, product=283, rating=1.0),
#  Rating(user=60, product=295, rating=1.0),
#  Rating(user=84, product=243, rating=1.0),
#  Rating(user=75, product=290, rating=1.0),
#  Rating(user=75, product=261, rating=1.0),
#  Rating(user=75, product=297, rating=1.0),
#  Rating(user=91, product=265, rating=1.0),
#  Rating(user=91, product=302, rating=1.0),
#  Rating(user=82, product=43, rating=20.0),
#  Rating(user=82, product=250, rating=5.0),
#  Rating(user=82, product=268, rating=3.0),
#  Rating(user=82, product=304, rating=7.0),
#  Rating(user=82, product=272, rating=1.0),
#  Rating(user=82, product=275, rating=2.0),
#  Rating(user=82, product=266, rating=1.0),
#  Rating(user=82, product=282, rating=1.0),
#  Rating(user=82, product=289, rating=1.0),
#  Rating(user=82, product=257, rating=1.0),
#  Rating(user=82, product=309, rating=1.0),
#  Rating(user=82, product=316, rating=1.0),
#  Rating(user=82, product=273, rating=1.0),
#  Rating(user=82, product=27, rating=1.0),
#  Rating(user=82, product=279, rating=1.0),
#  Rating(user=82, product=264, rating=1.0),
#  Rating(user=82, product=311, rating=1.0),
#  Rating(user=82, product=270, rating=3.0),
#  Rating(user=82, product=277, rating=1.0),
#  Rating(user=82, product=271, rating=1.0),
#  Rating(user=82, product=296, rating=1.0),
#  Rating(user=82, product=318, rating=1.0),
#  Rating(user=82, product=323, rating=1.0),
#  Rating(user=82, product=303, rating=1.0),
#  Rating(user=82, product=37, rating=12.0),
#  Rating(user=82, product=325, rating=1.0),
#  Rating(user=82, product=280, rating=2.0),
#  Rating(user=82, product=310, rating=1.0),
#  Rating(user=82, product=286, rating=1.0),
#  Rating(user=82, product=293, rating=2.0),
#  Rating(user=82, product=332, rating=3.0),
#  Rating(user=82, product=339, rating=5.0),
#  Rating(user=82, product=287, rating=1.0),
#  Rating(user=82, product=300, rating=1.0),
#  Rating(user=82, product=294, rating=1.0),
#  Rating(user=82, product=346, rating=1.0),
#  Rating(user=82, product=353, rating=1.0),
#  Rating(user=82, product=284, rating=1.0),
#  Rating(user=82, product=360, rating=9.0),
#  Rating(user=82, product=317, rating=1.0),
#  Rating(user=82, product=301, rating=1.0),
#  Rating(user=82, product=324, rating=1.0),
#  Rating(user=82, product=330, rating=1.0),
#  Rating(user=82, product=331, rating=1.0),
#  Rating(user=82, product=307, rating=1.0),
#  Rating(user=82, product=337, rating=1.0),
#  Rating(user=67, product=314, rating=1.0),
#  Rating(user=67, product=321, rating=1.0),
#  Rating(user=79, product=278, rating=1.0),
#  Rating(user=79, product=285, rating=1.0),
#  Rating(user=83, product=308, rating=1.0),
#  Rating(user=83, product=291, rating=1.0),
#  Rating(user=74, product=338, rating=2.0),
#  Rating(user=74, product=345, rating=1.0),
#  Rating(user=86, product=247, rating=1.0),
#  Rating(user=86, product=250, rating=1.0),
#  Rating(user=86, product=352, rating=1.0),
#  Rating(user=86, product=315, rating=1.0),
#  Rating(user=86, product=367, rating=1.0),
#  Rating(user=86, product=374, rating=1.0),
#  Rating(user=86, product=359, rating=1.0),
#  Rating(user=86, product=344, rating=1.0),
#  Rating(user=86, product=137, rating=1.0),
#  Rating(user=86, product=366, rating=1.0),
#  Rating(user=86, product=328, rating=1.0),
#  Rating(user=86, product=292, rating=1.0),
#  Rating(user=86, product=299, rating=1.0),
#  Rating(user=86, product=335, rating=1.0),
#  Rating(user=86, product=381, rating=1.0),
#  Rating(user=86, product=342, rating=1.0),
#  Rating(user=86, product=373, rating=1.0),
#  Rating(user=86, product=351, rating=1.0),
#  Rating(user=86, product=349, rating=6.0),
#  Rating(user=86, product=306, rating=1.0),
#  Rating(user=86, product=388, rating=2.0),
#  Rating(user=86, product=380, rating=1.0),
#  Rating(user=86, product=322, rating=1.0),
#  Rating(user=86, product=329, rating=1.0),
#  Rating(user=86, product=387, rating=1.0),
#  Rating(user=86, product=336, rating=1.0),
#  Rating(user=86, product=343, rating=1.0),
#  Rating(user=86, product=356, rating=1.0),
#  Rating(user=89, product=358, rating=1.0),
#  Rating(user=90, product=220, rating=1.0),
#  Rating(user=90, product=395, rating=1.0),
#  Rating(user=90, product=363, rating=1.0),
#  Rating(user=90, product=370, rating=2.0),
#  Rating(user=90, product=377, rating=2.0),
#  Rating(user=90, product=394, rating=1.0),
#  Rating(user=90, product=402, rating=1.0),
#  Rating(user=90, product=165, rating=1.0),
#  Rating(user=90, product=298, rating=1.0),
#  Rating(user=90, product=343, rating=3.0),
#  Rating(user=90, product=129, rating=2.0),
#  Rating(user=90, product=305, rating=1.0),
#  Rating(user=43, product=384, rating=1.0),
#  Rating(user=96, product=409, rating=1.0),
#  Rating(user=96, product=350, rating=1.0),
#  Rating(user=96, product=365, rating=1.0),
#  Rating(user=98, product=372, rating=1.0),
#  Rating(user=98, product=416, rating=4.0),
#  Rating(user=98, product=357, rating=1.0),
#  Rating(user=98, product=394, rating=1.0),
#  Rating(user=98, product=379, rating=1.0),
#  Rating(user=98, product=423, rating=3.0),
#  Rating(user=98, product=345, rating=1.0),
#  Rating(user=93, product=167, rating=1.0),
#  Rating(user=93, product=391, rating=2.0),
#  Rating(user=93, product=401, rating=1.0),
#  Rating(user=93, product=398, rating=1.0),
#  Rating(user=93, product=405, rating=1.0),
#  Rating(user=73, product=313, rating=1.0),
#  Rating(user=73, product=412, rating=1.0),
#  Rating(user=73, product=364, rating=1.0),
#  Rating(user=73, product=419, rating=1.0),
#  Rating(user=73, product=320, rating=1.0),
#  Rating(user=73, product=312, rating=1.0),
#  Rating(user=73, product=48, rating=1.0),
#  Rating(user=73, product=327, rating=1.0),
#  Rating(user=73, product=334, rating=1.0),
#  Rating(user=73, product=319, rating=2.0),
#  Rating(user=73, product=386, rating=1.0),
#  Rating(user=73, product=393, rating=1.0),
#  Rating(user=73, product=400, rating=2.0),
#  Rating(user=73, product=408, rating=10.0),
#  Rating(user=73, product=326, rating=6.0),
#  Rating(user=73, product=430, rating=1.0),
#  Rating(user=103, product=66, rating=1.0),
#  Rating(user=103, product=419, rating=1.0),
#  Rating(user=103, product=341, rating=1.0),
#  Rating(user=103, product=371, rating=1.0),
#  Rating(user=103, product=426, rating=1.0),
#  Rating(user=103, product=415, rating=2.0),
#  Rating(user=103, product=422, rating=1.0),
#  Rating(user=103, product=378, rating=1.0),
#  Rating(user=103, product=437, rating=1.0),
#  Rating(user=103, product=433, rating=2.0),
#  Rating(user=103, product=440, rating=1.0),
#  Rating(user=103, product=447, rating=1.0),
#  Rating(user=103, product=444, rating=1.0),
#  Rating(user=81, product=429, rating=1.0),
#  Rating(user=81, product=143, rating=1.0),
#  Rating(user=110, product=454, rating=1.0),
#  Rating(user=110, product=451, rating=2.0),
#  Rating(user=50, product=436, rating=1.0),
#  Rating(user=80, product=443, rating=2.0),
#  Rating(user=88, product=45, rating=1.0),
#  Rating(user=57, product=314, rating=1.0),
#  Rating(user=57, product=458, rating=1.0),
#  Rating(user=100, product=443, rating=1.0),
#  Rating(user=100, product=333, rating=1.0),
#  Rating(user=107, product=340, rating=2.0),
#  Rating(user=95, product=407, rating=1.0),
#  Rating(user=95, product=348, rating=1.0),
#  Rating(user=95, product=461, rating=1.0),
#  Rating(user=102, product=443, rating=1.0),
#  Rating(user=102, product=465, rating=2.0),
#  Rating(user=102, product=347, rating=2.0),
#  Rating(user=102, product=468, rating=2.0),
#  Rating(user=102, product=475, rating=1.0),
#  Rating(user=102, product=482, rating=1.0),
#  Rating(user=102, product=489, rating=2.0),
#  Rating(user=102, product=472, rating=2.0),
#  Rating(user=102, product=414, rating=1.0),
#  Rating(user=102, product=234, rating=4.0),
#  Rating(user=102, product=421, rating=1.0),
#  Rating(user=102, product=385, rating=2.0),
#  Rating(user=102, product=355, rating=1.0),
#  Rating(user=102, product=450, rating=1.0),
#  Rating(user=102, product=122, rating=1.0),
#  Rating(user=102, product=428, rating=1.0),
#  Rating(user=102, product=457, rating=1.0),
#  Rating(user=102, product=392, rating=2.0),
#  Rating(user=102, product=354, rating=2.0),
#  Rating(user=102, product=479, rating=1.0),
#  Rating(user=102, product=361, rating=1.0),
#  Rating(user=102, product=486, rating=1.0),
#  Rating(user=102, product=435, rating=4.0),
#  Rating(user=102, product=362, rating=1.0),
#  Rating(user=102, product=399, rating=1.0),
#  Rating(user=102, product=442, rating=2.0),
#  Rating(user=102, product=368, rating=1.0),
#  Rating(user=102, product=369, rating=1.0),
#  Rating(user=102, product=406, rating=1.0),
#  Rating(user=102, product=493, rating=1.0),
#  Rating(user=102, product=464, rating=1.0),
#  Rating(user=97, product=500, rating=1.0),
#  Rating(user=87, product=507, rating=1.0),
#  Rating(user=105, product=496, rating=1.0),
#  Rating(user=105, product=449, rating=1.0),
#  Rating(user=94, product=376, rating=1.0),
#  Rating(user=94, product=375, rating=1.0),
#  Rating(user=94, product=456, rating=1.0),
#  Rating(user=94, product=471, rating=1.0),
#  Rating(user=64, product=383, rating=1.0),
#  Rating(user=64, product=503, rating=2.0),
#  Rating(user=64, product=390, rating=1.0),
#  Rating(user=101, product=478, rating=1.0),
#  Rating(user=101, product=510, rating=2.0),
#  Rating(user=101, product=413, rating=1.0),
#  Rating(user=101, product=463, rating=1.0),
#  Rating(user=101, product=485, rating=1.0),
#  Rating(user=101, product=382, rating=1.0),
#  Rating(user=71, product=514, rating=1.0),
#  Rating(user=71, product=517, rating=1.0),
#  Rating(user=78, product=55, rating=1.0),
#  Rating(user=117, product=397, rating=2.0),
#  Rating(user=117, product=389, rating=1.0),
#  Rating(user=117, product=492, rating=1.0),
#  Rating(user=117, product=396, rating=1.0),
#  Rating(user=117, product=470, rating=1.0),
#  Rating(user=108, product=403, rating=1.0),
#  Rating(user=104, product=433, rating=1.0),
#  Rating(user=111, product=420, rating=1.0),
#  Rating(user=111, product=427, rating=1.0),
#  Rating(user=111, product=499, rating=2.0),
#  Rating(user=111, product=404, rating=1.0),
#  Rating(user=111, product=477, rating=1.0),
#  Rating(user=111, product=410, rating=1.0),
#  Rating(user=111, product=506, rating=1.0),
#  Rating(user=111, product=513, rating=4.0),
#  Rating(user=111, product=520, rating=11.0),
#  Rating(user=111, product=411, rating=2.0),
#  Rating(user=111, product=484, rating=1.0),
#  Rating(user=111, product=417, rating=1.0),
#  Rating(user=111, product=521, rating=1.0),
#  Rating(user=111, product=527, rating=1.0),
#  Rating(user=111, product=534, rating=2.0),
#  Rating(user=111, product=424, rating=1.0),
#  Rating(user=111, product=541, rating=1.0),
#  Rating(user=111, product=528, rating=2.0),
#  Rating(user=111, product=491, rating=3.0),
#  Rating(user=111, product=498, rating=1.0),
#  Rating(user=111, product=124, rating=1.0),
#  Rating(user=111, product=431, rating=2.0),
#  Rating(user=111, product=438, rating=1.0),
#  Rating(user=111, product=434, rating=1.0),
#  Rating(user=111, product=418, rating=1.0),
#  Rating(user=111, product=425, rating=2.0),
#  Rating(user=111, product=432, rating=1.0),
#  Rating(user=111, product=441, rating=7.0),
#  Rating(user=111, product=439, rating=1.0),
#  Rating(user=109, product=420, rating=1.0),
#  Rating(user=116, product=505, rating=1.0),
#  Rating(user=114, product=548, rating=1.0),
#  Rating(user=123, product=282, rating=1.0),
#  Rating(user=123, product=535, rating=1.0),
#  Rating(user=123, product=512, rating=1.0),
#  Rating(user=85, product=445, rating=1.0),
#  Rating(user=85, product=519, rating=1.0),
#  Rating(user=85, product=448, rating=1.0),
#  Rating(user=92, product=445, rating=1.0),
#  Rating(user=115, product=452, rating=1.0),
#  Rating(user=118, product=526, rating=1.0),
#  Rating(user=118, product=446, rating=1.0),
#  Rating(user=112, product=459, rating=1.0),
#  Rating(user=112, product=542, rating=1.0),
#  Rating(user=112, product=466, rating=1.0),
#  Rating(user=112, product=524, rating=1.0),
#  Rating(user=112, product=473, rating=2.0),
#  Rating(user=112, product=549, rating=1.0),
#  Rating(user=112, product=427, rating=3.0),
#  Rating(user=112, product=480, rating=1.0),
#  Rating(user=112, product=487, rating=1.0),
#  Rating(user=112, product=556, rating=1.0),
#  Rating(user=112, product=455, rating=2.0),
#  Rating(user=112, product=563, rating=1.0),
#  Rating(user=112, product=555, rating=2.0),
#  Rating(user=112, product=242, rating=3.0),
#  Rating(user=112, product=531, rating=2.0),
#  Rating(user=112, product=533, rating=1.0),
#  Rating(user=112, product=540, rating=1.0),
#  Rating(user=112, product=453, rating=1.0),
#  Rating(user=112, product=547, rating=1.0),
#  Rating(user=112, product=538, rating=1.0),
#  Rating(user=112, product=570, rating=1.0),
#  Rating(user=112, product=393, rating=1.0),
#  Rating(user=112, product=462, rating=2.0),
#  Rating(user=112, product=78, rating=1.0),
#  Rating(user=112, product=545, rating=1.0),
#  Rating(user=112, product=554, rating=9.0),
#  Rating(user=112, product=562, rating=1.0),
#  Rating(user=112, product=494, rating=3.0),
#  Rating(user=112, product=460, rating=1.0),
#  Rating(user=112, product=552, rating=1.0),
#  Rating(user=112, product=559, rating=2.0),
#  Rating(user=112, product=469, rating=1.0),
#  Rating(user=112, product=569, rating=3.0),
#  Rating(user=112, product=576, rating=5.0),
#  Rating(user=112, product=476, rating=1.0),
#  Rating(user=112, product=483, rating=1.0),
#  Rating(user=112, product=467, rating=1.0),
#  Rating(user=112, product=561, rating=1.0),
#  Rating(user=112, product=568, rating=1.0),
#  Rating(user=112, product=577, rating=2.0),
#  Rating(user=112, product=474, rating=1.0),
#  Rating(user=112, product=490, rating=1.0),
#  Rating(user=112, product=583, rating=5.0),
#  Rating(user=112, product=566, rating=7.0),
#  Rating(user=122, product=575, rating=1.0),
#  Rating(user=122, product=481, rating=1.0),
#  Rating(user=122, product=584, rating=1.0),
#  Rating(user=121, product=590, rating=1.0),
#  Rating(user=121, product=591, rating=1.0),
#  Rating(user=121, product=573, rating=1.0),
#  Rating(user=125, product=597, rating=1.0),
#  Rating(user=119, product=604, rating=1.0),
#  Rating(user=128, product=497, rating=1.0),
#  Rating(user=128, product=250, rating=1.0),
#  Rating(user=128, product=395, rating=1.0),
#  Rating(user=128, product=504, rating=1.0),
#  Rating(user=128, product=582, rating=1.0),
#  Rating(user=128, product=611, rating=1.0),
#  Rating(user=128, product=589, rating=1.0),
#  Rating(user=128, product=488, rating=1.0),
#  Rating(user=128, product=618, rating=1.0),
#  Rating(user=128, product=625, rating=2.0),
#  Rating(user=128, product=511, rating=1.0),
#  Rating(user=128, product=518, rating=1.0),
#  Rating(user=128, product=495, rating=1.0),
#  Rating(user=128, product=501, rating=1.0),
#  Rating(user=128, product=508, rating=1.0),
#  Rating(user=99, product=525, rating=1.0),
#  Rating(user=99, product=632, rating=1.0),
#  Rating(user=99, product=521, rating=1.0),
#  Rating(user=99, product=502, rating=1.0),
#  Rating(user=99, product=532, rating=1.0),
#  Rating(user=130, product=580, rating=1.0),
#  Rating(user=130, product=598, rating=1.0),
#  Rating(user=130, product=515, rating=1.0),
#  Rating(user=130, product=65, rating=1.0),
#  Rating(user=130, product=596, rating=1.0),
#  Rating(user=130, product=509, rating=1.0),
#  Rating(user=130, product=539, rating=1.0),
#  Rating(user=130, product=68, rating=1.0),
#  Rating(user=106, product=516, rating=1.0),
#  Rating(user=106, product=605, rating=2.0),
#  Rating(user=106, product=639, rating=2.0),
#  Rating(user=106, product=587, rating=1.0),
#  Rating(user=106, product=603, rating=1.0),
#  Rating(user=106, product=546, rating=1.0),
#  Rating(user=126, product=522, rating=5.0),
#  Rating(user=126, product=646, rating=1.0),
#  Rating(user=126, product=521, rating=1.0),
#  Rating(user=132, product=610, rating=2.0),
#  Rating(user=132, product=529, rating=1.0),
#  Rating(user=132, product=415, rating=1.0),
#  Rating(user=132, product=617, rating=1.0),
#  Rating(user=132, product=553, rating=1.0),
#  Rating(user=132, product=45, rating=1.0),
#  Rating(user=132, product=536, rating=1.0),
#  Rating(user=113, product=489, rating=1.0),
#  Rating(user=113, product=560, rating=1.0),
#  Rating(user=113, product=567, rating=1.0),
#  Rating(user=113, product=653, rating=3.0),
#  Rating(user=137, product=574, rating=1.0),
#  Rating(user=137, product=523, rating=5.0),
#  Rating(user=137, product=660, rating=2.0),
#  Rating(user=137, product=167, rating=2.0),
#  Rating(user=137, product=286, rating=1.0),
#  Rating(user=137, product=581, rating=2.0),
#  Rating(user=137, product=423, rating=2.0),
#  Rating(user=137, product=588, rating=1.0),
#  Rating(user=137, product=595, rating=1.0),
#  Rating(user=144, product=602, rating=1.0),
#  Rating(user=144, product=594, rating=1.0),
#  Rating(user=144, product=612, rating=1.0),
#  Rating(user=120, product=624, rating=1.0),
#  Rating(user=120, product=601, rating=1.0),
#  Rating(user=120, product=619, rating=1.0),
#  Rating(user=120, product=631, rating=1.0),
#  Rating(user=120, product=626, rating=1.0),
#  Rating(user=120, product=530, rating=1.0),
#  Rating(user=120, product=537, rating=1.0),
#  Rating(user=120, product=633, rating=1.0),
#  Rating(user=120, product=667, rating=2.0),
#  Rating(user=120, product=609, rating=2.0),
#  Rating(user=120, product=640, rating=1.0),
#  Rating(user=120, product=195, rating=1.0),
#  Rating(user=120, product=616, rating=1.0),
#  Rating(user=120, product=674, rating=1.0),
#  Rating(user=120, product=544, rating=1.0),
#  Rating(user=120, product=543, rating=2.0),
#  Rating(user=151, product=638, rating=1.0),
#  Rating(user=151, product=681, rating=1.0),
#  Rating(user=151, product=551, rating=1.0),
#  Rating(user=139, product=550, rating=1.0),
#  Rating(user=129, product=688, rating=1.0),
#  Rating(user=136, product=558, rating=1.0),
#  Rating(user=135, product=623, rating=1.0),
#  Rating(user=158, product=645, rating=1.0),
#  Rating(user=143, product=645, rating=1.0),
#  Rating(user=143, product=565, rating=1.0),
#  Rating(user=127, product=652, rating=1.0),
#  Rating(user=127, product=630, rating=1.0),
#  Rating(user=124, product=695, rating=2.0),
#  Rating(user=131, product=572, rating=3.0),
#  Rating(user=131, product=557, rating=1.0),
#  Rating(user=142, product=579, rating=1.0),
#  Rating(user=149, product=659, rating=1.0),
#  Rating(user=149, product=105, rating=1.0),
#  Rating(user=149, product=702, rating=1.0),
#  Rating(user=149, product=608, rating=1.0),
#  Rating(user=156, product=637, rating=1.0),
#  Rating(user=138, product=709, rating=1.0),
#  Rating(user=138, product=615, rating=1.0),
#  Rating(user=138, product=586, rating=1.0),
#  Rating(user=134, product=716, rating=1.0),
#  Rating(user=141, product=723, rating=1.0),
#  Rating(user=141, product=666, rating=1.0),
#  Rating(user=141, product=593, rating=1.0),
#  Rating(user=146, product=564, rating=1.0),
#  Rating(user=133, product=647, rating=1.0),
#  Rating(user=133, product=673, rating=1.0),
#  Rating(user=133, product=415, rating=1.0),
#  Rating(user=153, product=358, rating=1.0),
#  Rating(user=153, product=654, rating=1.0),
#  Rating(user=150, product=311, rating=1.0),
#  Rating(user=150, product=571, rating=1.0),
#  Rating(user=150, product=661, rating=1.0),
#  Rating(user=140, product=41, rating=1.0),
#  Rating(user=140, product=349, rating=1.0),
#  Rating(user=140, product=578, rating=1.0),
#  Rating(user=140, product=609, rating=1.0),
#  Rating(user=165, product=589, rating=1.0),
#  Rating(user=165, product=600, rating=1.0),
#  Rating(user=147, product=730, rating=1.0),
#  Rating(user=147, product=349, rating=1.0),
#  Rating(user=147, product=581, rating=1.0),
#  Rating(user=147, product=644, rating=1.0),
#  Rating(user=147, product=668, rating=4.0),
#  Rating(user=147, product=675, rating=1.0),
#  Rating(user=147, product=607, rating=1.0),
#  Rating(user=157, product=680, rating=1.0),
#  Rating(user=145, product=615, rating=1.0),
#  Rating(user=145, product=609, rating=1.0),
#  Rating(user=160, product=651, rating=1.0),
#  Rating(user=148, product=413, rating=1.0),
#  Rating(user=148, product=585, rating=1.0),
#  Rating(user=148, product=687, rating=1.0),
#  Rating(user=167, product=658, rating=1.0),
#  Rating(user=154, product=682, rating=1.0),
#  Rating(user=163, product=622, rating=1.0),
#  Rating(user=163, product=689, rating=4.0),
#  Rating(user=163, product=614, rating=3.0),
#  Rating(user=163, product=694, rating=1.0),
#  Rating(user=163, product=629, rating=1.0),
#  Rating(user=163, product=621, rating=2.0),
#  Rating(user=163, product=701, rating=3.0),
#  Rating(user=163, product=74, rating=2.0),
#  Rating(user=163, product=708, rating=1.0),
#  Rating(user=163, product=665, rating=3.0),
#  Rating(user=163, product=333, rating=1.0),
#  Rating(user=163, product=672, rating=1.0),
#  Rating(user=163, product=249, rating=3.0),
#  Rating(user=163, product=215, rating=2.0),
#  Rating(user=163, product=715, rating=10.0),
#  Rating(user=163, product=722, rating=1.0),
#  Rating(user=163, product=679, rating=2.0),
#  Rating(user=163, product=636, rating=1.0),
#  Rating(user=163, product=696, rating=3.0),
#  Rating(user=163, product=686, rating=1.0),
#  Rating(user=163, product=737, rating=1.0),
#  Rating(user=163, product=343, rating=1.0),
#  Rating(user=163, product=729, rating=1.0),
#  Rating(user=155, product=600, rating=2.0),
#  Rating(user=155, product=592, rating=1.0),
#  Rating(user=155, product=703, rating=2.0),
#  Rating(user=155, product=599, rating=1.0),
#  Rating(user=155, product=736, rating=1.0),
#  Rating(user=164, product=606, rating=1.0),
#  Rating(user=152, product=606, rating=1.0),
#  Rating(user=159, product=628, rating=1.0),
#  Rating(user=159, product=647, rating=1.0),
#  Rating(user=159, product=744, rating=1.0),
#  Rating(user=159, product=462, rating=2.0),
#  Rating(user=159, product=390, rating=1.0),
#  Rating(user=162, product=643, rating=1.0),
#  Rating(user=162, product=710, rating=1.0),
#  Rating(user=170, product=628, rating=1.0),
#  Rating(user=170, product=693, rating=1.0),
#  Rating(user=172, product=743, rating=1.0),
#  Rating(user=172, product=650, rating=1.0),
#  Rating(user=169, product=717, rating=1.0),
#  Rating(user=169, product=750, rating=1.0),
#  Rating(user=169, product=757, rating=1.0),
#  Rating(user=179, product=751, rating=1.0),
#  Rating(user=166, product=764, rating=1.0),
#  Rating(user=177, product=771, rating=1.0),
#  Rating(user=161, product=700, rating=1.0),
#  Rating(user=161, product=778, rating=1.0),
#  Rating(user=174, product=724, rating=1.0),
#  Rating(user=173, product=613, rating=1.0),
#  Rating(user=173, product=785, rating=1.0),
#  Rating(user=176, product=635, rating=2.0),
#  Rating(user=176, product=657, rating=1.0),
#  Rating(user=176, product=758, rating=1.0),
#  Rating(user=176, product=792, rating=1.0),
#  Rating(user=176, product=642, rating=1.0),
#  Rating(user=176, product=707, rating=1.0),
#  Rating(user=171, product=620, rating=1.0),
#  Rating(user=183, product=714, rating=1.0),
#  Rating(user=180, product=765, rating=1.0),
#  Rating(user=180, product=627, rating=1.0),
#  Rating(user=186, product=521, rating=1.0),
#  Rating(user=178, product=634, rating=1.0),
#  Rating(user=178, product=271, rating=1.0),
#  Rating(user=178, product=721, rating=1.0),
#  Rating(user=168, product=50, rating=1.0),
#  Rating(user=175, product=664, rating=1.0),
#  Rating(user=187, product=634, rating=1.0),
#  Rating(user=193, product=750, rating=1.0),
#  Rating(user=182, product=465, rating=1.0),
#  Rating(user=182, product=772, rating=1.0),
#  Rating(user=194, product=728, rating=1.0),
#  Rating(user=194, product=671, rating=1.0),
#  Rating(user=201, product=731, rating=1.0),
#  Rating(user=200, product=735, rating=1.0),
#  Rating(user=184, product=649, rating=1.0),
#  Rating(user=184, product=664, rating=1.0),
#  Rating(user=184, product=641, rating=1.0),
#  Rating(user=190, product=678, rating=1.0),
#  Rating(user=190, product=779, rating=2.0),
#  Rating(user=190, product=738, rating=1.0),
#  Rating(user=190, product=589, rating=2.0),
#  Rating(user=190, product=592, rating=1.0),
#  Rating(user=190, product=131, rating=1.0),
#  Rating(user=190, product=742, rating=1.0),
#  Rating(user=190, product=749, rating=1.0),
#  Rating(user=190, product=786, rating=1.0),
#  Rating(user=189, product=442, rating=1.0),
#  Rating(user=208, product=297, rating=2.0),
#  Rating(user=208, product=484, rating=2.0),
#  Rating(user=208, product=745, rating=1.0),
#  Rating(user=208, product=685, rating=1.0),
#  Rating(user=208, product=793, rating=1.0),
#  Rating(user=185, product=799, rating=1.0),
#  Rating(user=185, product=50, rating=2.0),
#  Rating(user=185, product=648, rating=1.0),
#  Rating(user=185, product=45, rating=1.0),
#  Rating(user=181, product=664, rating=1.0),
#  Rating(user=181, product=752, rating=1.0),
#  Rating(user=197, product=756, rating=1.0),
#  Rating(user=215, product=656, rating=1.0),
#  Rating(user=188, product=655, rating=2.0),
#  Rating(user=188, product=763, rating=3.0),
#  Rating(user=188, product=692, rating=1.0),
#  Rating(user=192, product=806, rating=1.0),
#  Rating(user=195, product=770, rating=1.0),
#  Rating(user=195, product=663, rating=1.0),
#  Rating(user=195, product=800, rating=1.0),
#  Rating(user=195, product=670, rating=1.0),
#  Rating(user=195, product=777, rating=1.0),
#  Rating(user=195, product=813, rating=1.0),
#  Rating(user=195, product=807, rating=1.0),
#  Rating(user=195, product=759, rating=1.0),
#  Rating(user=195, product=243, rating=1.0),
#  Rating(user=195, product=820, rating=1.0),
#  Rating(user=195, product=766, rating=1.0),
#  Rating(user=195, product=677, rating=1.0),
#  Rating(user=195, product=251, rating=1.0),
#  Rating(user=195, product=708, rating=1.0),
#  Rating(user=195, product=814, rating=1.0),
#  Rating(user=195, product=105, rating=1.0),
#  Rating(user=195, product=234, rating=2.0),
#  Rating(user=195, product=254, rating=1.0),
#  Rating(user=195, product=827, rating=1.0),
#  Rating(user=195, product=773, rating=1.0),
#  Rating(user=195, product=780, rating=1.0),
#  Rating(user=195, product=787, rating=1.0),
#  Rating(user=195, product=662, rating=1.0),
#  Rating(user=195, product=699, rating=2.0),
#  Rating(user=195, product=280, rating=1.0),
#  Rating(user=195, product=821, rating=1.0),
#  Rating(user=195, product=828, rating=1.0),
#  Rating(user=195, product=596, rating=1.0),
#  Rating(user=195, product=71, rating=1.0),
#  Rating(user=195, product=784, rating=1.0),
#  Rating(user=195, product=706, rating=1.0),
#  Rating(user=195, product=669, rating=1.0),
#  Rating(user=195, product=600, rating=1.0),
#  Rating(user=195, product=835, rating=1.0),
#  Rating(user=195, product=842, rating=1.0),
#  Rating(user=195, product=737, rating=1.0),
#  Rating(user=195, product=503, rating=1.0),
#  Rating(user=195, product=834, rating=1.0),
#  Rating(user=195, product=841, rating=1.0),
#  Rating(user=195, product=470, rating=1.0),
#  Rating(user=195, product=676, rating=1.0),
#  Rating(user=195, product=794, rating=1.0),
#  Rating(user=195, product=848, rating=2.0),
#  Rating(user=195, product=801, rating=1.0),
#  Rating(user=195, product=855, rating=1.0),
#  Rating(user=195, product=849, rating=1.0),
#  Rating(user=195, product=683, rating=1.0),
#  Rating(user=195, product=791, rating=1.0),
#  Rating(user=195, product=684, rating=1.0),
#  Rating(user=195, product=862, rating=1.0),
#  Rating(user=195, product=691, rating=2.0),
#  Rating(user=195, product=856, rating=1.0),
#  Rating(user=195, product=713, rating=1.0),
#  Rating(user=195, product=869, rating=1.0),
#  Rating(user=195, product=798, rating=1.0),
#  Rating(user=195, product=698, rating=1.0),
#  Rating(user=195, product=705, rating=1.0),
#  Rating(user=195, product=720, rating=1.0),
#  Rating(user=195, product=727, rating=1.0),
#  Rating(user=195, product=876, rating=1.0),
#  Rating(user=195, product=808, rating=1.0),
#  Rating(user=195, product=712, rating=1.0),
#  Rating(user=196, product=734, rating=1.0),
#  Rating(user=191, product=815, rating=1.0),
#  Rating(user=222, product=805, rating=1.0),
#  Rating(user=222, product=822, rating=1.0),
#  Rating(user=204, product=235, rating=1.0),
#  Rating(user=211, product=719, rating=1.0),
#  Rating(user=211, product=812, rating=1.0),
#  Rating(user=211, product=45, rating=1.0),
#  Rating(user=203, product=690, rating=2.0),
#  Rating(user=203, product=726, rating=1.0),
#  Rating(user=203, product=733, rating=1.0),
#  Rating(user=229, product=883, rating=1.0),
#  Rating(user=199, product=819, rating=1.0),
#  Rating(user=199, product=890, rating=1.0),
#  Rating(user=199, product=897, rating=1.0),
#  Rating(user=199, product=863, rating=1.0),
#  Rating(user=199, product=740, rating=1.0),
#  Rating(user=202, product=349, rating=1.0),
#  Rating(user=206, product=85, rating=1.0),
#  Rating(user=236, product=167, rating=1.0),
#  Rating(user=236, product=826, rating=1.0),
#  Rating(user=236, product=107, rating=1.0),
#  Rating(user=209, product=697, rating=1.0),
#  Rating(user=209, product=829, rating=1.0),
#  Rating(user=209, product=696, rating=1.0),
#  Rating(user=209, product=600, rating=1.0),
#  Rating(user=209, product=704, rating=1.0),
#  Rating(user=209, product=741, rating=1.0),
#  Rating(user=218, product=427, rating=1.0),
#  Rating(user=210, product=883, rating=1.0),
#  Rating(user=216, product=836, rating=1.0),
#  Rating(user=207, product=711, rating=1.0),
#  Rating(user=243, product=904, rating=1.0),
#  Rating(user=243, product=48, rating=1.0),
#  Rating(user=243, product=718, rating=1.0),
#  Rating(user=243, product=843, rating=1.0),
#  Rating(user=243, product=911, rating=1.0),
#  Rating(user=243, product=725, rating=1.0),
#  Rating(user=243, product=747, rating=2.0),
#  Rating(user=243, product=324, rating=1.0),
#  Rating(user=213, product=833, rating=1.0),
#  Rating(user=223, product=748, rating=1.0),
#  Rating(user=214, product=755, rating=1.0),
#  Rating(user=214, product=870, rating=1.0),
#  Rating(user=217, product=43, rating=1.0),
#  Rating(user=217, product=918, rating=2.0),
#  Rating(user=217, product=85, rating=1.0),
#  Rating(user=217, product=762, rating=2.0),
#  Rating(user=217, product=925, rating=2.0),
#  Rating(user=217, product=877, rating=1.0),
#  Rating(user=250, product=754, rating=1.0),
#  Rating(user=250, product=840, rating=1.0),
#  Rating(user=220, product=847, rating=1.0),
#  Rating(user=220, product=854, rating=1.0),
#  Rating(user=220, product=732, rating=4.0),
#  Rating(user=220, product=850, rating=5.0),
#  Rating(user=220, product=48, rating=1.0),
#  Rating(user=220, product=769, rating=1.0),
#  Rating(user=220, product=761, rating=2.0),
#  Rating(user=220, product=768, rating=2.0),
#  Rating(user=220, product=884, rating=1.0),
#  Rating(user=220, product=857, rating=1.0),
#  Rating(user=230, product=133, rating=1.0),
#  Rating(user=198, product=864, rating=1.0),
#  Rating(user=257, product=871, rating=1.0),
#  Rating(user=257, product=79, rating=1.0),
#  Rating(user=237, product=878, rating=1.0),
#  Rating(user=225, product=891, rating=1.0),
#  Rating(user=227, product=898, rating=1.0),
#  Rating(user=264, product=861, rating=1.0),
#  Rating(user=232, product=868, rating=1.0),
#  Rating(user=224, product=932, rating=1.0),
#  Rating(user=234, product=905, rating=1.0),
#  Rating(user=234, product=875, rating=1.0),
#  Rating(user=205, product=775, rating=1.0),
#  Rating(user=221, product=905, rating=1.0),
#  Rating(user=221, product=912, rating=2.0),
#  Rating(user=271, product=919, rating=1.0),
#  Rating(user=271, product=782, rating=1.0),
#  Rating(user=271, product=739, rating=1.0),
#  Rating(user=244, product=789, rating=1.0),
#  Rating(user=241, product=885, rating=1.0),
#  Rating(user=228, product=926, rating=1.0),
#  Rating(user=228, product=746, rating=1.0),
#  Rating(user=228, product=892, rating=1.0),
#  Rating(user=228, product=426, rating=1.0),
#  Rating(user=228, product=933, rating=1.0),
#  Rating(user=228, product=899, rating=1.0),
#  Rating(user=228, product=587, rating=1.0),
#  Rating(user=248, product=939, rating=1.0),
#  Rating(user=248, product=796, rating=6.0),
#  Rating(user=248, product=906, rating=1.0),
#  Rating(user=248, product=776, rating=2.0),
#  Rating(user=248, product=803, rating=1.0),
#  Rating(user=248, product=946, rating=4.0),
#  Rating(user=248, product=158, rating=1.0),
#  Rating(user=248, product=488, rating=2.0),
#  Rating(user=248, product=940, rating=3.0),
#  Rating(user=248, product=783, rating=1.0),
#  Rating(user=255, product=913, rating=1.0),
#  Rating(user=255, product=549, rating=1.0),
#  Rating(user=255, product=427, rating=2.0),
#  Rating(user=255, product=953, rating=3.0),
#  Rating(user=255, product=810, rating=1.0),
#  Rating(user=255, product=817, rating=1.0),
#  ...]

# %%
# ranks = list(range(15,20))  # 从5到20的范围
ranks = [15, 20, 25]
reg_params = [0.1, 0.5, 1.0]  # 更细粒度的调整
alphas = [0.01, 0.5, 1.5]  # 保持在0.5到1.5之间的范围

# 修改后的参数列表
params = [(rank, reg_param, alpha) for rank in ranks for reg_param in reg_params for alpha in alphas]

# %%
from pyspark.mllib.recommendation import ALS, Rating
from pyspark import SparkContext
from math import sqrt

def train_model(train_data, val_data, params, user_dict, business_dict):
    rank, reg_param, alpha = params
    
    # 将映射字典转换为局部变量，以避免序列化全局环境
    user_to_num = sc.broadcast(user_dict)
    business_to_num = sc.broadcast(business_dict)

    def rating_mapper(p):
        user_id = user_to_num.value.get(p[0][0], -1)
        business_id = business_to_num.value.get(p[0][1], -1)
        return Rating(user_id, business_id, float(p[1]))

    # 使用局部的训练数据RDD
    local_ratings_rdd = train_data.map(rating_mapper)
    model = ALS.trainImplicit(local_ratings_rdd, rank, iterations=10, lambda_=reg_param, alpha=alpha)
    
    def validation_mapper(p):
        return (user_to_num.value.get(p[0][0], -1), business_to_num.value.get(p[0][1], -1))

    # 使用局部的验证数据RDD
    local_validation_rdd = val_data.map(validation_mapper)
    predictions = model.predictAll(local_validation_rdd).map(lambda r: ((r.user, r.product), r.rating))
    rates_and_preds = val_data.map(lambda p: ((user_to_num.value.get(p[0][0], -1), business_to_num.value.get(p[0][1], -1)), p[1])).join(predictions)
    rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

    return (rmse, rank, reg_param, alpha)

sc = SparkContext.getOrCreate()
full_rdd = user_business_interaction_counts.cache()
training_rdd, validation_rdd = full_rdd.randomSplit([0.8, 0.2], seed=42)

# 提前准备所有需要的数据和映射
user_dict = full_rdd.map(lambda p: p[0][0]).distinct().zipWithIndex().collectAsMap()
business_dict = full_rdd.map(lambda p: p[0][1]).distinct().zipWithIndex().collectAsMap()

results = [train_model(training_rdd, validation_rdd, param, user_dict, business_dict) for param in params]
best_params = min(results, key=lambda x: x[0])
print("Best parameters:", best_params)
# Out:
# 24/04/17 09:41:25 WARN BlockManager: Task 274206 already completed, not releasing lock for rdd_31_0
# 24/04/17 09:41:58 WARN BlockManager: Task 276690 already completed, not releasing lock for rdd_31_0
# [Stage 222747:===========================>                        (10 + 9) / 19]
# Best parameters: (1.6605276164617149, 25, 0.1, 1.5)

# %% [markdown]
# ### using normalized ratings rdd to further explore performace

# %%
from pyspark.mllib.recommendation import ALS
import numpy as np
from math import sqrt
from pyspark import SparkContext
from pyspark.mllib.recommendation import ALS, Rating

def log_transform_interaction(interaction_count):
    """对交互次数应用对数转换并标准化到1到5的评分范围"""
    return 1 + 4 * (np.log(interaction_count + 1) - np.log(1 + 1)) / (np.log(284 + 1) - np.log(1 + 1))

# %%
# ranks = list(range(15,20))  # 从5到20的范围
ranks = [25]
reg_params = [0.01]  # 更细粒度的调整
alphas = [1.0]  # 保持在0.5到1.5之间的范围

# 修改后的参数列表
params = [(rank, reg_param, alpha) for rank in ranks for reg_param in reg_params for alpha in alphas]

# %%
start_time = time.time()

def train_model(train_data, val_data, params, user_dict, business_dict):
    rank, reg_param, alpha = params
    
    # 将映射字典转换为局部变量，以避免序列化全局环境
    user_to_num = sc.broadcast(user_dict)
    business_to_num = sc.broadcast(business_dict)

    def rating_mapper(p):
        user_id = user_to_num.value.get(p[0][0], -1)
        business_id = business_to_num.value.get(p[0][1], -1)
        log_transformed_rating = log_transform_interaction(float(p[1]))  # 应用对数转换
        return Rating(user_id, business_id, log_transformed_rating)


    # 使用局部的训练数据RDD
    local_ratings_rdd = train_data.map(rating_mapper)
    model = ALS.trainImplicit(local_ratings_rdd, rank, iterations=10, lambda_=reg_param, alpha=alpha)
    
    def validation_mapper(p):
        return (user_to_num.value.get(p[0][0], -1), business_to_num.value.get(p[0][1], -1))

    # 使用局部的验证数据RDD
    local_validation_rdd = val_data.map(validation_mapper)
    predictions = model.predictAll(local_validation_rdd).map(lambda r: ((r.user, r.product), r.rating))
    rates_and_preds = val_data.map(lambda p: ((user_to_num.value.get(p[0][0], -1), business_to_num.value.get(p[0][1], -1)), p[1])).join(predictions)
    rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

    return (rmse, rank, reg_param, alpha)

sc = SparkContext.getOrCreate()
full_rdd = user_business_interaction_counts.cache()
training_rdd, validation_rdd = full_rdd.randomSplit([0.8, 0.2], seed=42)

# 提前准备所有需要的数据和映射
user_dict = full_rdd.map(lambda p: p[0][0]).distinct().zipWithIndex().collectAsMap()
business_dict = full_rdd.map(lambda p: p[0][1]).distinct().zipWithIndex().collectAsMap()

results = [train_model(training_rdd, validation_rdd, param, user_dict, business_dict) for param in params]
best_params = min(results, key=lambda x: x[0])
print("Best parameters:", best_params)

print(f"Duration: {time.time() - start_time}")
# Out:
# [Stage 8039:===============================>                      (11 + 8) / 19]
# Best parameters: (1.6724080106076653, 25, 0.01, 1.0)
# Duration: 10.629076957702637

# %% [markdown]
# #### Parallized

# %%
'''
Parallelized!! No deterministic split
'''
start_time = time.time()

from pyspark.mllib.recommendation import ALS, Rating
from pyspark import SparkContext
from math import sqrt
import numpy as np

def log_transform_interaction(interaction_count):
    """对交互次数应用对数转换并标准化到1到5的评分范围"""
    return 1 + 4 * (np.log(interaction_count + 1) - np.log(1 + 1)) / (np.log(284 + 1) - np.log(1 + 1))

def train_model(params, user_dict, business_dict, data_samples):
    sc = SparkContext.getOrCreate()
    full_rdd = sc.parallelize(data_samples)
    user_to_num_bc = sc.broadcast(user_dict)
    business_to_num_bc = sc.broadcast(business_dict)

    rank, reg_param, alpha = params
    train_data, val_data = full_rdd.randomSplit([0.8, 0.2], seed=42)
    
    def rating_mapper(p):
        user_id = user_to_num_bc.value.get(p[0][0], -1)
        business_id = business_to_num_bc.value.get(p[0][1], -1)
        log_transformed_rating = log_transform_interaction(float(p[1]))
        return Rating(user_id, business_id, log_transformed_rating)
        
    local_ratings_rdd = train_data.map(rating_mapper)
    model = ALS.trainImplicit(local_ratings_rdd, rank, iterations=5, lambda_=reg_param, alpha=alpha)

    def validation_mapper(p):
        return (user_to_num_bc.value.get(p[0][0], -1), business_to_num_bc.value.get(p[0][1], -1))
    
    local_validation_rdd = val_data.map(validation_mapper)
    predictions = model.predictAll(local_validation_rdd).map(lambda r: ((r.user, r.product), r.rating))
    rates_and_preds = val_data.map(lambda p: ((user_to_num_bc.value.get(p[0][0], -1), business_to_num_bc.value.get(p[0][1], -1)), p[1])).join(predictions)
    rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

    return (rmse, rank, reg_param, alpha)

sc = SparkContext.getOrCreate()
data_samples = user_business_interaction_counts.collect()

user_dict = sc.parallelize(data_samples).map(lambda p: p[0][0]).distinct().zipWithIndex().collectAsMap()
business_dict = sc.parallelize(data_samples).map(lambda p: p[0][1]).distinct().zipWithIndex().collectAsMap()

param_list = [(20, 0.02, 1.0), (25, 0.01, 1.0), (25, 0.05, 1.0), (25, 0.01, 0.5), (30, 0.01, 1.0)]
results = [train_model(params, user_dict, business_dict, data_samples) for params in param_list]
best_params = min(results, key=lambda x: x[0])
print("Best parameters:", best_params)

print(f"Duration: {time.time() - start_time}")
# Out:
# [Stage 9014:=============================================>        (20 + 4) / 24]
# Best parameters: (1.857118000784612, 25, 0.05, 1.0)

# %%
'''
Parallelized!! deterministic split
'''
from pyspark.mllib.recommendation import ALS, Rating
from pyspark import SparkContext
from math import sqrt
import numpy as np

def log_transform_interaction(rating):
    return np.log1p(rating)

# def log_transform_interaction(interaction_count):
#     """对交互次数应用对数转换并标准化到1到5的评分范围"""
#     return 1 + 4 * (np.log(interaction_count + 1) - np.log(1 + 1)) / (np.log(284 + 1) - np.log(1 + 1))

sc = SparkContext.getOrCreate()

data_samples = user_business_interaction_counts.collect()
full_rdd = sc.parallelize(data_samples)
train_data, val_data = full_rdd.randomSplit([0.8, 0.2], seed=42)

user_dict = full_rdd.map(lambda p: p[0][0]).distinct().zipWithIndex().collectAsMap()
business_dict = full_rdd.map(lambda p: p[0][1]).distinct().zipWithIndex().collectAsMap()
user_to_num_bc = sc.broadcast(user_dict)
business_to_num_bc = sc.broadcast(business_dict)

def train_model(params, training_rdd, validation_rdd, user_to_num_bcast, business_to_num_bcast):
    rank, reg_param, alpha = params
    
    user_to_num = user_to_num_bcast.value
    business_to_num = business_to_num_bcast.value

    ratings_rdd = training_rdd.map(lambda p: Rating(user_to_num[p[0][0]], business_to_num[p[0][1]], log_transform_interaction(p[1])))
    model = ALS.trainImplicit(ratings_rdd, rank, iterations=5, lambda_=reg_param, alpha=alpha)

    validation_for_predict_rdd = validation_rdd.map(lambda p: (user_to_num[p[0][0]], business_to_num[p[0][1]]))
    predictions = model.predictAll(validation_for_predict_rdd).map(lambda r: ((r.user, r.product), r.rating))
    rates_and_preds = validation_rdd.map(lambda p: ((user_to_num[p[0][0]], business_to_num[p[0][1]]), p[1])).join(predictions)
    rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

    return (rmse, rank, reg_param, alpha)

ranks = [10, 15, 20, 25, 30, 35, 40]
reg_params = [0.001, 0.005, 0.01, 0.02, 0.05, 0.1]
alphas = [0.2, 0.5, 1.0, 2.0, 3.0]

import itertools

# Generating all combinations of parameters
param_grid = list(itertools.product(ranks, reg_params, alphas))

results = [train_model(params, train_data, val_data, user_to_num_bc, business_to_num_bc) for params in param_grid]
best_params = min(results, key=lambda x: x[0])

print(f"Best RMSE: {best_params[0]}")
print(f"Best Rank: {best_params[1]}")
print(f"Best Regularization Parameter: {best_params[2]}")
print(f"Best Alpha: {best_params[3]}")
# Out:
# Best RMSE: 1.8468406523414755
# Best Rank: 40
# Best Regularization Parameter: 0.1
# Best Alpha: 3.0

# %% [markdown]
# ### BASIC STANDARD WAY TO DO GRID SEARCH w/ LogTrans

# %%
# Create Train, Val Set: ((user_id, business_id), count) format
training_rdd, validations_rdd = user_business_interaction_counts.randomSplit([0.8, 0.2], seed=42)

from pyspark.mllib.recommendation import ALS
from math import sqrt
import numpy as np
from pyspark.mllib.recommendation import Rating

def log_transform_interaction(interaction_count):
    """对交互次数应用对数转换并标准化到1到5的评分范围"""
    return 1 + 4 * (np.log(interaction_count + 1) - np.log(1 + 1)) / (np.log(284 + 1) - np.log(1 + 1))

# 创建经过对数转换的Rating对象的RDD
ratings_rdd = user_business_interaction_counts.map(
    lambda p: Rating(user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]], log_transform_interaction(p[1]))
)

# ALS模型参数网格搜索
# ranks = [20, 22, 25, 28, 30]
# reg_params = [0.005, 0.01, 0.02, 0.05]
# alphas = [0.5, 1.0, 2.0, 3.0]

# ranks = [10, 15, 20, 25, 30, 35, 40]
# reg_params = [0.001, 0.005, 0.01, 0.02, 0.05, 0.1]
# alphas = [0.2, 0.5, 1.0, 2.0, 3.0]

# Updated grid parameters for fine-tuning
# ranks = [35, 38, 40, 42, 45]
# reg_params = [0.0005, 0.001, 0.002]
# alphas = [2.5, 3.0, 3.5, 4.0]
ranks = [48, 50, 55]
reg_params = [0.00001, 0.0001, 0.0005]
alphas = [4.5, 5.0, 6.0]

best_rmse = float('inf')
best_model = None
best_rank = 0
best_reg_param = 0
best_alpha = 0

start_time = time.time()

for rank in ranks:
    for reg_param in reg_params:
        for alpha in alphas:
            # 训练ALS模型
            model = ALS.trainImplicit(ratings_rdd, rank, seed=42, iterations=5, lambda_=reg_param, alpha=alpha)
            
            # 在验证集上评估模型
            validation_for_predict_rdd = validations_rdd.map(
                lambda p: (user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]])
            )
            predictions = model.predictAll(validation_for_predict_rdd).map(
                lambda r: ((r[0], r[1]), r[2])
            )
            # 将实际评分和预测评分数据基于用户ID和商户ID进行对齐
            rates_and_preds = validations_rdd.map(
                lambda p: ((user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]]), log_transform_interaction(p[1]))
            ).join(predictions)
            # [1][0]是通过log_transform_interaction函数转换后的实际评分数据；[1][1]是ALS预测出的评分数据
            rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())
            
            # 比较并保存最佳模型
            if rmse < best_rmse:
                best_rmse = rmse
                best_model = model
                best_rank = rank
                best_reg_param = reg_param
                best_alpha = alpha

# 打印最佳模型的参数
print(f"Best RMSE: {best_rmse}")
print(f"Best Rank: {best_rank}")
print(f"Best Regularization Parameter: {best_reg_param}")
print(f"Best Alpha: {best_alpha}")

print("Duration: ", tiem.time() - start_time)
# Out:
# [Stage 99321:====================================>                (13 + 6) / 19]
# Best RMSE: 0.9748005892115309
# Best Rank: 45
# Best Regularization Parameter: 0.0005
# Best Alpha: 4.0

# %% [markdown]
# ## RMSE (Log.Trans) no CV
#
# Best RMSE: 1.0262119633332438
# Best Rank: 25
# Best Regularization Parameter: 0.01
# Best Alpha: 1.0
#
# Best parameters: (1.8574931815882971, 25, 0.05, 1.0)
#
# Best RMSE: 0.9936078540025709
# Best Rank: 40
# Best Regularization Parameter: 0.001
# Best Alpha: 3.0
#
# Best RMSE: 0.9748005892115309
# Best Rank: 45
# Best Regularization Parameter: 0.0005
# Best Alpha: 4.0

# %%
''' basic + K-fold'''

from pyspark.mllib.recommendation import ALS
from math import sqrt
from pyspark.mllib.recommendation import Rating

# 创建经过对数转换的Rating对象的RDD
ratings_rdd = user_business_interaction_counts.map(
    lambda p: Rating(user_to_num_bc.value[p[0][0]], business_to_num_bc.value[p[0][1]], log_transform_interaction(p[1]))
)

# 参数设置
ranks = [45, 48, 50]
reg_params = [0.0001, 0.0005, 0.001]
alphas = [4.0, 4.5, 5.0]
numFolds = 5

# 初始化最佳设置记录
best_rmse = float('inf')
best_model = None
best_params = {}

# 创建K折数据集
weights = [1.0] * numFolds
seed = 42
folds = ratings_rdd.randomSplit(weights, seed)

for rank in ranks:
    for reg_param in reg_params:
        for alpha in alphas:
            fold_rmse = []
            for i in range(numFolds):
                train = sc.union([folds[j] for j in range(numFolds) if j != i])
                test = folds[i]
                
                # 训练ALS模型
                model = ALS.trainImplicit(train, rank, seed=seed, iterations=5, lambda_=reg_param, alpha=alpha)
                
                # 在测试集上评估模型
                test_for_predict_rdd = test.map(lambda p: (p.user, p.product))
                predictions = model.predictAll(test_for_predict_rdd).map(lambda r: ((r.user, r.product), r.rating))
                rates_and_preds = test.map(lambda p: ((p.user, p.product), p.rating)).join(predictions)
                rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())
                fold_rmse.append(rmse)
            
            # 计算当前参数组合下的平均RMSE
            avg_rmse = sum(fold_rmse) / numFolds
            print(f"Tested Model: rank={rank}, regParam={reg_param}, alpha={alpha}, Average RMSE={avg_rmse}")
            
            # 比较并保存最佳模型
            if avg_rmse < best_rmse:
                best_rmse = avg_rmse
                best_model = model
                best_params = {'rank': rank, 'regParam': reg_param, 'alpha': alpha}

# 打印最佳模型参数
print(f"Best Model Parameters: {best_params}, with Average RMSE: {best_rmse}")
# Out:
# Tested Model: rank=45, regParam=0.0001, alpha=4.0, Average RMSE=1.020548586310234
# Tested Model: rank=45, regParam=0.0001, alpha=4.5, Average RMSE=1.0170479077425632
# Tested Model: rank=45, regParam=0.0001, alpha=5.0, Average RMSE=1.0137617029677723
# Tested Model: rank=45, regParam=0.0005, alpha=4.0, Average RMSE=1.0234635850847786
# Tested Model: rank=45, regParam=0.0005, alpha=4.5, Average RMSE=1.0197158244996927
# Tested Model: rank=45, regParam=0.0005, alpha=5.0, Average RMSE=1.0162092081964083
# Tested Model: rank=45, regParam=0.001, alpha=4.0, Average RMSE=1.025526182332733
# Tested Model: rank=45, regParam=0.001, alpha=4.5, Average RMSE=1.0216714494862111
# Tested Model: rank=45, regParam=0.001, alpha=5.0, Average RMSE=1.0180678816464532
# Tested Model: rank=48, regParam=0.0001, alpha=4.0, Average RMSE=1.020309202161415
# Tested Model: rank=48, regParam=0.0001, alpha=4.5, Average RMSE=1.0168311861671702
# Tested Model: rank=48, regParam=0.0001, alpha=5.0, Average RMSE=1.0135636348153345
# Tested Model: rank=48, regParam=0.0005, alpha=4.0, Average RMSE=1.0229594274337024
# Tested Model: rank=48, regParam=0.0005, alpha=4.5, Average RMSE=1.0192347565823727
# Tested Model: rank=48, regParam=0.0005, alpha=5.0, Average RMSE=1.0157566205956243
# Tested Model: rank=48, regParam=0.001, alpha=4.0, Average RMSE=1.024923515166234
# Tested Model: rank=48, regParam=0.001, alpha=4.5, Average RMSE=1.0210847314566984
# Tested Model: rank=48, regParam=0.001, alpha=5.0, Average RMSE=1.0174948685778518
# [Stage 119077:=========================>                         (14 + 12) / 28]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 35
#      32 test = folds[i]
#      34 # 训练ALS模型
# ---> 35 model = ALS.trainImplicit(train, rank, seed=seed, iterations=5, lambda_=reg_param, alpha=alpha)
#      37 # 在测试集上评估模型
#      38 test_for_predict_rdd = test.map(lambda p: (p.user, p.product))
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/mllib/recommendation.py:324, in ALS.trainImplicit(cls, ratings, rank, iterations, lambda_, blocks, alpha, nonnegative, seed)
#     284 @classmethod
#     285 def trainImplicit(cls, ratings, rank, iterations=5, lambda_=0.01, blocks=-1, alpha=0.01,
#     286                   nonnegative=False, seed=None):
#     287     """
#     288     Train a matrix factorization model given an RDD of 'implicit
#     289     preferences' of users for a subset of products. The ratings matrix
#    (...)
#     322         (default: None)
#     323     """
# --> 324     model = callMLlibFunc("trainImplicitALSModel", cls._prepare(ratings), rank,
#     325                           iterations, lambda_, blocks, alpha, nonnegative, seed)
#     326     return MatrixFactorizationModel(model)
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/mllib/common.py:125, in callMLlibFunc(name, *args)
#     123 sc = SparkContext.getOrCreate()
#     124 api = getattr(sc._jvm.PythonMLLibAPI(), name)
# --> 125 return callJavaFunc(sc, api, *args)
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/mllib/common.py:118, in callJavaFunc(sc, func, *args)
#     116 """ Call Java Function """
#     117 args = [_py2java(sc, a) for a in args]
# --> 118 return _java2py(sc, func(*args))
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1303, in JavaMember.__call__(self, *args)
#    1296 args_command, temp_args = self._build_args(*args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
# -> 1303 answer = self.gateway_client.send_command(command)
#    1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1033, in GatewayClient.send_command(self, command, retry, binary)
#    1031 connection = self._get_connection()
#    1032 try:
# -> 1033     response = connection.send_command(command)
#    1034     if binary:
#    1035         return response, self._create_connection_guard(connection)
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1200, in GatewayConnection.send_command(self, command)
#    1196     raise Py4JNetworkError(
#    1197         "Error while sending", e, proto.ERROR_ON_SEND)
#    1199 try:
# -> 1200     answer = smart_decode(self.stream.readline()[:-1])
#    1201     logger.debug("Answer received: {0}".format(answer))
#    1202     if answer.startswith(proto.RETURN_MESSAGE):
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Pipelineing GirdSearch w/ logTrans and CV

# %%
'''use pyspark pipeline, ml API and sparkDF for simplicity BUT WHY SO SLOW???'''


from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.feature import StringIndexer


# 创建ALS模型实例，设置implicitPrefs为True来指定使用隐式反馈
als = ALS(
    userCol="userIndex",
    itemCol="businessIndex",
    ratingCol="rating",
    coldStartStrategy="drop",
    nonnegative=True,  # 确保非负参数，这通常对于推荐系统是有意义的
    implicitPrefs=True
)

from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[als])

paramGrid = ParamGridBuilder() \
    .addGrid(als.rank, [48, 50, 55]) \
    .addGrid(als.regParam, [0.00001, 0.0001, 0.0005]) \
    .addGrid(als.alpha, [4.5, 5.0, 6.0]) \
    .build()

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

crossval = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=paramGrid,
    evaluator=evaluator,
    numFolds=2
)

# 训练模型
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
from pyspark.sql import SparkSession
# 创建SparkSession
spark = SparkSession.builder \
    .appName("Convert RDD to DataFrame") \
    .getOrCreate()

# 定义RDD的schema
schema = StructType([
    StructField("user", StringType(), True),
    StructField("business", StringType(), True),
    StructField("rating", IntegerType(), True)
])

adjusted_rdd = user_business_interaction_counts.map(
    lambda x: (x[0][0], x[0][1], x[1])
)
df = spark.createDataFrame(adjusted_rdd, schema)

# 使用StringIndexer转换字符串列为数值索引
indexer_user = StringIndexer(inputCol="user", outputCol="userIndex")
indexer_business = StringIndexer(inputCol="business", outputCol="businessIndex")

# Pipeline to apply transformations
tmp_pipeline = Pipeline(stages=[indexer_user, indexer_business])
df_transformed = tmp_pipeline.fit(df).transform(df).select("userIndex", "businessIndex", "rating")

model = crossval.fit(df_transformed)

# 输出最佳模型信息
bestModel = model.bestModel.stages[0]
print(f"Best Model Params: Rank={bestModel.getRank()}, RegParam={bestModel.getRegParam()}, Alpha={bestModel.getAlpha()}")
print(f"Best Model RMSE: {evaluator.evaluate(bestModel.transform(df))}")
# Out:
# [Stage 130353:>                                                   (0 + 10) / 10]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.8/multiprocessing/pool.py:851, in IMapIterator.next(self, timeout)
#     850 try:
# --> 851     item = self._items.popleft()
#     852 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 67
#      64 tmp_pipeline = Pipeline(stages=[indexer_user, indexer_business])
#      65 df_transformed = tmp_pipeline.fit(df).transform(df).select("userIndex", "businessIndex", "rating")
# ---> 67 model = crossval.fit(df_transformed)
#      69 # 输出最佳模型信息
#      70 bestModel = model.bestModel.stages[0]
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/ml/base.py:161, in Estimator.fit(self, dataset, params)
#     159         return self.copy(params)._fit(dataset)
#     160     else:
# --> 161         return self._fit(dataset)
#     162 else:
#     163     raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#     164                      "but got %s." % type(params))
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/ml/tuning.py:687, in CrossValidator._fit(self, dataset)
#     684 train = datasets[i][0].cache()
#     686 tasks = _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam)
# --> 687 for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     688     metrics[j] += (metric / nFolds)
#     689     if collectSubModelsParam:
#
# File /usr/lib/python3.8/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     854     self._pool = None
#     855     raise StopIteration from None
# --> 856 self._cond.wait(timeout)
#     857 try:
#     858     item = self._items.popleft()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
# [Stage 130421:>                                                   (0 + 10) / 10]

# %%
'''+ LOG TRANS use pyspark pipeline, ml API and sparkDF for simplicity '''

from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.feature import StringIndexer

start_time = time.time()

# 创建ALS模型实例，设置implicitPrefs为True来指定使用隐式反馈
als = ALS(
    userCol="user",
    itemCol="business",
    ratingCol="rating",
    coldStartStrategy="drop",
    nonnegative=True,  # 确保非负参数，这通常对于推荐系统是有意义的
    implicitPrefs=True
)

from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[als])

paramGrid = ParamGridBuilder() \
    .addGrid(als.rank, [51]) \
    .addGrid(als.regParam, [10, 30, 0.005]) \
    .addGrid(als.alpha, [1530.0]) \
    .build()

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

crossval = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=paramGrid,
    evaluator=evaluator,
    numFolds=5
)

# 训练模型
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
from pyspark.sql import SparkSession

# 定义RDD的schema
schema = StructType([
    StructField("user", IntegerType(), True),
    StructField("product", IntegerType(), True),  # Changed from 'business' to 'product'
    StructField("rating", FloatType(), True)
])

from pyspark.mllib.recommendation import Rating
# def log_transform_interaction(interaction_count):
#     """对交互次数应用对数转换并标准化到1到5的评分范围"""
#     return 1 + 4 * (np.log(interaction_count + 1) - np.log(1 + 1)) / (np.log(284 + 1) - np.log(1 + 1))

# # 创建经过对数转换的Rating对象的RDD
# ratings_rdd = user_business_interaction_counts.map(
#     lambda p: Rating(int(user_to_num_bc.value[p[0][0]]), int(business_to_num_bc.value[p[0][1]]), float(np.float64(log_transform_interaction(p[1]))))
#     # lambda p: Rating(int(user_to_num_bc.value[p[0][0]]), int(business_to_num_bc.value[p[0][1]]), float((p[1])))
# )
from MF import test
ratings_rdd = test(sc, '../data/')

spark = SparkSession.builder.appName("ALS Example").getOrCreate()
df = spark.createDataFrame(ratings_rdd, schema)

df = df.withColumnRenamed("product", "business")
model = crossval.fit(df)

# 输出最佳模型信息
bestModel = model.bestModel.stages[0]
print(f"Best Model Params: Rank={bestModel.rank}, RegParam={bestModel._java_obj.parent().getRegParam()}, Alpha={bestModel._java_obj.parent().getAlpha()}")
print(f"Best Model RMSE: {evaluator.evaluate(bestModel.transform(df))}")

print("Duration: ", time.time() - start_time)
## 使用StringIndexer转换字符串列为数值索引
## indexer_user = StringIndexer(inputCol="user", outputCol="userIndex")
## indexer_business = StringIndexer(inputCol="business", outputCol="businessIndex")
## # Pipeline to apply transformations
## tmp_pipeline = Pipeline(stages=[indexer_user, indexer_business])
## df_transformed = tmp_pipeline.fit(df).transform(df).select("userIndex", "businessIndex", "rating")
# Out:
# Best Model Params: Rank=51, RegParam=30.0, Alpha=1530.0
# [Stage 7566:===================================================>  (24 + 1) / 25]
# Best Model RMSE: 0.38096950099939697
# Duration:  425.4502580165863

# %%
df.show(10)
# Out:
# +----+--------+---------+
# |user|business|   rating|
# +----+--------+---------+
# |   4|       3|      1.0|
# |   0|       5|1.5590638|
# |  11|      10|      1.0|
# |  11|       6|1.3270314|
# |  11|       1|      1.0|
# |  11|       2|      1.0|
# |  18|       9|      1.0|
# |  18|       8|      1.0|
# |  18|      16|      1.0|
# |   6|      12|      1.0|
# +----+--------+---------+
# only showing top 10 rows

# %%
# df_transform = df_transformed.select("userIndex", "businessIndex", "rating")
# df_transform.show(5)
# Out:
# +---------+-------------+------+
# |userIndex|businessIndex|rating|
# +---------+-------------+------+
# | 226485.0|     111362.0|     1|
# |  11711.0|      43029.0|     3|
# |   5681.0|      22845.0|     1|
# |   5681.0|      26565.0|     2|
# |   5681.0|       8654.0|     1|
# +---------+-------------+------+
# only showing top 5 rows

# %% [markdown]
# ## RMSE Log.Trans w/ CV=2
# Best Model Params: Rank=50, RegParam=1e-05, Alpha=6.0
# Best Model RMSE: 0.9522162059453022
#
# Best Model Params: Rank=51, RegParam=1e-05, Alpha=12.0
# Best Model RMSE: 0.9126936257722957
# Duration:  1267.1926851272583
#
# Best Model Params: Rank=51, RegParam=1e-05, Alpha=25.0
# Best Model RMSE: 0.8586641084757474
# Duration:  1679.2649910449982
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=45.0
# Best Model RMSE: 0.8056559429426488
# Duration:  814.2358434200287
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=60.0
# Best Model RMSE: 0.7766625014795452
# Duration:  537.503279209137
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=100.0
# Best Model RMSE: 0.720838855207703
# Duration:  530.7137999534607
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=180.0
# Best Model RMSE: 0.6503744859799462
# Duration:  364.15210580825806
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=300.0
# Best Model RMSE: 0.5844215172277072
# Duration:  335.40465235710144
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=600.0
# Best Model RMSE: 0.49035982038807124
# Duration:  324.7230396270752
#
# Best Model Params: Rank=51, RegParam=5e-05, Alpha=1000.0
# Best Model RMSE: 0.4207796793325426
# Duration:  341.753643989563
#
# Best Model Params: Rank=51, RegParam=5e-05, **Alpha=1500.0**
# Best Model RMSE: 0.36787906916177776
# Duration:  369.1352970600128
#
# Best Model Params: Rank=51, RegParam=0.0005, Alpha=1510.0
# Best Model RMSE: 0.3670443406380293
# Duration:  2923.155244588852
#
# **Best Model Params: Rank=51, RegParam=0.5, Alpha=1520.0**
# *Best Model RMSE: 0.36660512851026805*
# Duration:  675.6044607162476
#
# **Best Model Params: Rank=51, RegParam=0.005, Alpha=1530.0**
# *Best Model RMSE: 0.36539879987153356*
# Duration:  316.333025932312
#
# Best Model Params: Rank=51, RegParam=10.0, Alpha=1520.0
# Best Model RMSE: 0.372141467955779
# Duration:  151.50563216209412
#
# Best Model Params: Rank=51, RegParam=30.0, Alpha=1530.0
# Best Model RMSE: 0.38141422660997226
# Duration:  250.79301953315735

# %% [markdown]
# # Completed: After we have the best model, then => U,V and calculate affinity score for each user, biz

# %%
from MF import matrix_factorization_als
start_time = time.time()
data_path = '../data/'  # Update with args[*]

pair_rdd, user_ids_bcast, business_ids_bcast= matrix_factorization_als(sc, data_path)
print("Duration: ", time.time() - start_time)
# Out:
# Duration:  9.486623525619507

# %%
pair_rdd.collect()
# Out:
# [('wf1GqnKQuvH-V3QN80UOOQ', 'fThrN4tfupIGetkrz18JOg'),
#  ('39FT2Ui8KUXwmUt6hnwy-g', 'uW6UHfONAmm8QttPkbMewQ'),
#  ('7weuSPSSqYLUFga6IYP4pg', 'IhNASEZ3XnBHmuuVnWdIwA'),
#  ('CqaIzLiWaa-lMFYBAsYQxw', 'G859H6xfAmVLxbzQgipuoA'),
#  ('yy7shAsNWRbGg-8Y67Dzag', 'rS39YnrhoXmPqHLzCBjeqw'),
#  ('Uk1UKBIAwOqhjZdLm3r9zg', '5CJL_2-XwCGBmOav4mFdYg'),
#  ('x-8ZMKKNycT3782Kqf9loA', 'jgtWfJCJZty_Nctqpdtp3g'),
#  ('0FVcoJko1kfZCrJRfssfIA', 'JVK8szNDoy9MNiYSz_MiAA'),
#  ('LcCRMIDz1JgshpPGYfLDcA', 't19vb_4ML2dg5HZ-MF3muA'),
#  ('C__1BHWTGBNA5s2ZPH289g', 'h_UvnQfe1cuVICly_kIqHg'),
#  ('CLbpPUqP6XpeAfoqScGaJQ', 'QjZFYd5hme7EHegpuJngMQ'),
#  ('zDBOdWtl2PsNY38IeoE5cQ', 'gy-HBIeJGlQHs4RRYDLuHw'),
#  ('w-_md1Qslb7r6098SHydlg', '9p-cpmHaga-EXyc6ZzYCcQ'),
#  ('U4INQZOPSUaj8hMjLlZ3KA', '8tMy7yEeNVYylVVFRlPmdQ'),
#  ('RrvBEf3Dwk57-6s0fJZwFw', 'drNjH8Z63cgp8FWXh2hahA'),
#  ('rKkpHJkJ27xOwnhy_bMkvA', 'WpI5MZC3XzlTpcUOKXzCbA'),
#  ('-xDW3gYiYaoeVASXywTPgw', 'G-5kEa6E6PD5fkBRuA7k9Q'),
#  ('xNKjIktegMyHVSXFznJTRg', '0p27EjcNwTI7Ey4K_MNPww'),
#  ('2O_6Wku6xFCGoPTl8TjMWw', 'LhfKAGpQ12pgvQRqg-2wmw'),
#  ('9MU6L4v83qo9jmutekcWMQ', 'Hz1F5uruPe1kCsf5PIA6Sg'),
#  ('CqeLXgQUpMZNbz4GwBz87w', '3Mx4renubPRnjHUw1n2UkA'),
#  ('CwkEpm0lCai2cJZIp_MMiQ', 'ZDDzKXN_JXe7694zePRuTQ'),
#  ('2krGQJ6P0hm_s6NxA09IMw', 'UPIYuRaZvknINOd1w8kqRQ'),
#  ('4m9NXICYBC5i9t4aTt-I6w', 'F6c3D1o9Z4Tl6cDorb3WgA'),
#  ('UC27mopi9fL9lVoSyonwSQ', 'Nz44ccUso3nq5S2OlQHNlA'),
#  ('a48HhwcmjFLApZhiax41IA', 'PQER4ba8Q0zqB1G2QiXamQ'),
#  ('53bZ_EsXH71L7iFs5MP9_w', 'rtlsfmdufArhk-47sWIf2w'),
#  ('EWkQxKg-KOzujC38Z_40wg', '1M6tA3TqxcpptHW0_hP9Kw'),
#  ('R9TIWPBlMuzzWgYXZBnAlg', 'X6DR-xr0rQKnxl9jeZWFzw'),
#  ('6s-g2vFu12OemhiK3FJuOQ', 'SzB85-8tmDEvoapZSDTBkQ'),
#  ('NrpzAH3EoNhWUR8OysUhBQ', 'LB6ZyCfUzeX9OLdunHhnOQ'),
#  ('4m9NXICYBC5i9t4aTt-I6w', '8xrwjD-Udv7cm_emVcVo3A'),
#  ...]

# %%
def map_and_track_ids(line, user_ids_bcast, business_ids_bcast):
    user_id, biz_id = line
    user_num = user_ids_bcast.value.get(user_id.strip(), -1)
    biz_num = business_ids_bcast.value.get(biz_id.strip(), -1)
    return (user_num, biz_num), (user_id, biz_id)

# %%
test_mapped_rdd = pair_rdd.map(lambda line: map_and_track_ids(line, user_ids_bcast, business_ids_bcast))

# %%
tracked_pairs_rdd = pair_rdd.map(lambda line: map_and_track_ids(line, user_ids_bcast, business_ids_bcast))
valid_pairs_rdd = tracked_pairs_rdd.filter(lambda x: x[0][0] != -1 and x[0][1] != -1)
missing_pairs_rdd = tracked_pairs_rdd.filter(lambda x: x[0][0] == -1 or x[0][1] == -1).map(lambda x: (x[1], -99))

# %%
valid_pairs_rdd.collect()
# Out:
# [((7272, 24589), ('wf1GqnKQuvH-V3QN80UOOQ', 'fThrN4tfupIGetkrz18JOg')),
#  ((218201, 8381), ('39FT2Ui8KUXwmUt6hnwy-g', 'uW6UHfONAmm8QttPkbMewQ')),
#  ((41610, 18468), ('7weuSPSSqYLUFga6IYP4pg', 'IhNASEZ3XnBHmuuVnWdIwA')),
#  ((4313, 10492), ('yy7shAsNWRbGg-8Y67Dzag', 'rS39YnrhoXmPqHLzCBjeqw')),
#  (146962, 88910),
#  (83418, 26485),
#  (41327, 19747),
#  (56902, 29456),
#  (182680, 1728),
#  (35333, 4356),
#  (282075, 74830),
#  (191438, 34804),
#  (35243, 65069),
#  (153251, 19964),
#  (148841, 25552),
#  (43389, 54938),
#  (11717, 31192),
#  (140839, 85950),
#  (138186, 58410),
#  (176556, 50885),
#  (8162, 9084),
#  (97637, 6035),
#  (33668, 12854),
#  (212104, 9774),
#  (10467, 29701),
#  (2726, 9627),
#  (134788, 76231),
#  (38075, 26872),
#  (136357, 89544),
#  (141735, 74865),
#  ...]

# %%
batch_size = 1000
valid_batches = valid_num_id_pairs.mapPartitions(lambda x: [list(x)]).flatMap(lambda x: [x[i:i + batch_size] for i in range(0, len(x), batch_size)])

# %%
valid_batches.collect()
# Out:
# [[(7272, 24589),
#   (218201, 8381),
#   (41610, 18468),
#   (4313, 10492),
#   (46373, 12933),
#   (224889, 58564),
#   (133824, 71929),
#   (10431, 29433),
#   (8389, 7796),
#   (88945, 27564),
#   (47439, 6486),
#   (16148, 50020),
#   (99472, 2743),
#   (44414, 8746),
#   (135680, 6666),
#   (136873, 94087),
#   (37904, 18487),
#   (41516, 27252),
#   (4262, 6221),
#   (722, 268),
#   (36203, 2265),
#   (35678, 18468),
#   (36155, 8267),
#   (197932, 22672),
#   (37433, 7550),
#   (122696, 10038),
#   (112307, 37066),
#   (71185, 35957),
#   (135694, 98489),
#   (12550, 9402),
#   (3600, 2634),
#   (34869, 7338),
#   (1142, 593),
#   (40101, 6800),
#   (136957, 82808),
#   (23305, 8608),
#   (1813, 1015),
#   (38550, 4275),
#   (133772, 90402),
#   (148592, 21242),
#   (146620, 23219),
#   (71122, 52870),
#   (53248, 7114),
#   (286325, 65504),
#   (193710, 95005),
#   (138438, 101649),
#   (136048, 58933),
#   (133713, 317),
#   (111271, 34690),
#   (152926, 64234),
#   (252830, 8936),
#   (136555, 83563),
#   (135918, 57689),
#   (123763, 28776),
#   (44991, 70954),
#   (4277, 15306),
#   (1696, 3260),
#   (10536, 14124),
#   (10137, 4454),
#   (77306, 53164),
#   (134524, 64633),
#   (3672, 17898),
#   (40261, 24986),
#   (37257, 16687),
#   (221382, 27893),
#   (4081, 16072),
#   (40105, 7039),
#   (164492, 58839),
#   (279153, 5735),
#   (81118, 65621),
#   (1211, 3984),
#   (84079, 26002),
#   (20892, 10168),
#   (35850, 33762),
#   (140689, 98272),
#   (21137, 1499),
#   (98094, 12953),
#   (70774, 13275),
#   (154197, 3464),
#   (41307, 3896),
#   (140286, 94231),
#   (36646, 9948),
#   (36418, 9452),
#   (110605, 7654),
#   (126585, 81943),
#   (139256, 90830),
#   (35678, 53012),
#   (45933, 75256),
#   (136588, 86352),
#   (81118, 7526),
#   (184096, 3452),
#   (102246, 65662),
#   (242839, 17842),
#   (35666, 52644),
#   (10542, 13409),
#   (41421, 20264),
#   (46006, 4401),
#   (129720, 32707),
#   (34597, 52607),
#   (10636, 6622),
#   (34014, 37650),
#   (239440, 96366),
#   (4954, 6956),
#   (92926, 9428),
#   (135390, 100576),
#   (53404, 2626),
#   (45405, 6670),
#   (45522, 1433),
#   (1644, 2785),
#   (133555, 88369),
#   (135168, 92461),
#   (197792, 94944),
#   (89664, 40287),
#   (22, 666),
#   (68803, 34031),
#   (36531, 48844),
#   (38667, 7396),
#   (37433, 54986),
#   (77640, 1410),
#   (279341, 62309),
#   (37033, 18434),
#   (177918, 19572),
#   (42052, 57433),
#   (1779, 11),
#   (7958, 2153),
#   (158576, 90581),
#   (180031, 4128),
#   (88602, 19562),
#   (37487, 46847),
#   (38100, 7397),
#   (36532, 44300),
#   (52192, 2307),
#   (136960, 76212),
#   (136721, 20241),
#   (36369, 6139),
#   (150749, 7966),
#   (70141, 8842),
#   (140677, 5874),
#   (71087, 8774),
#   (62142, 19086),
#   (132455, 45980),
#   (35806, 29110),
#   (143812, 77252),
#   (137186, 15413),
#   (153617, 34024),
#   (131785, 58033),
#   (43391, 6814),
#   (134805, 89899),
#   (89142, 6343),
#   (192231, 46431),
#   (133868, 95308),
#   (51989, 10467),
#   (38046, 23956),
#   (9932, 7789),
#   (1679, 3420),
#   (6406, 11840),
#   (162785, 34580),
#   (12550, 36513),
#   (51272, 11983),
#   (80375, 49962),
#   (141517, 100381),
#   (137779, 80046),
#   (126838, 12612),
#   (112037, 7907),
#   (55753, 29113),
#   (67852, 5440),
#   (4291, 11306),
#   (86013, 3889),
#   (51885, 1269),
#   (88447, 33984),
#   (9240, 28067),
#   (7921, 8178),
#   (1813, 3788),
#   (38290, 63659),
#   (75175, 44673),
#   (71986, 48602),
#   (35772, 65356),
#   (40893, 8315),
#   (165496, 77707),
#   (134903, 20919),
#   (42221, 30012),
#   (42062, 19152),
#   (49490, 2123),
#   (2726, 9388),
#   (49841, 3288),
#   (134973, 95455),
#   (133722, 96293),
#   (744, 522),
#   (133523, 46721),
#   (81998, 36915),
#   (135533, 73599),
#   (41155, 42236),
#   (77743, 7996),
#   (138275, 58486),
#   (36747, 51791),
#   (132329, 97141),
#   (2706, 6165),
#   (71225, 19327),
#   (40964, 52334),
#   (870, 1783),
#   (152573, 13032),
#   (144780, 85982),
#   (78796, 4384),
#   (35107, 8486),
#   (56055, 23156),
#   (37433, 20208),
#   (41604, 67530),
#   (47374, 42771),
#   (2751, 10181),
#   (38183, 67774),
#   (34696, 61704),
#   (47365, 18227),
#   (89009, 1323),
#   (272988, 9744),
#   (37888, 9833),
#   (98195, 63307),
#   (40082, 44132),
#   (37276, 57512),
#   (33892, 52379),
#   (1362, 4431),
#   (37433, 24401),
#   (39896, 9631),
#   (36888, 43344),
#   (291617, 16369),
#   (34982, 53228),
#   (46182, 34068),
#   (90123, 8797),
#   (137982, 82559),
#   (189968, 6783),
#   (113936, 61461),
#   (274914, 9437),
#   (224718, 91957),
#   (132429, 90845),
#   (78831, 24471),
#   (141075, 58395),
#   (36157, 9491),
#   (115545, 64539),
#   (261563, 10129),
#   (275355, 95588),
#   (110157, 43066),
#   (278537, 9283),
#   (213523, 86013),
#   (133544, 89565),
#   (40964, 8975),
#   (35037, 49845),
#   (1990, 3827),
#   (138333, 88567),
#   (36733, 19519),
#   (9796, 21974),
#   (41680, 9791),
#   (285096, 62019),
#   (93462, 65980),
#   (50447, 5671),
#   (135136, 59094),
#   (4846, 11456),
#   (174240, 16244),
#   (43050, 4356),
#   (41987, 61645),
#   (34749, 6844),
#   (35312, 14778),
#   (41355, 32348),
#   (4117, 5665),
#   (166604, 50175),
#   (7295, 3835),
#   (858, 2407),
#   (69295, 2272),
#   (34576, 60504),
#   (140189, 17134),
#   (148121, 93232),
#   (41355, 3654),
#   (755, 658),
#   (165875, 58578),
#   (46500, 4607),
#   (35273, 17870),
#   (34965, 17157),
#   (258, 2602),
#   (8644, 6758),
#   (42788, 9562),
#   (8359, 3026),
#   (68371, 54281),
#   (135061, 77287),
#   (1171, 3785),
#   (39327, 14162),
#   (12877, 8077),
#   (23305, 8774),
#   (6383, 12319),
#   (139831, 75688),
#   (67124, 61308),
#   (79602, 83481),
#   (47079, 18901),
#   (41405, 8774),
#   (97167, 5783),
#   (37033, 13478),
#   (39862, 65766),
#   (217263, 26032),
#   (3483, 10136),
#   (132265, 75730),
#   (2518, 4548),
#   (138428, 76435),
#   (43381, 2265),
#   (137848, 90672),
#   (8163, 7991),
#   (130314, 3976),
#   (36638, 66120),
#   (34870, 19720),
#   (130083, 87097),
#   (7074, 5885),
#   (44014, 1423),
#   (4140, 12321),
#   (170352, 8427),
#   (135344, 91109),
#   (134361, 77350),
#   (37064, 62336),
#   (199352, 90184),
#   (115311, 51110),
#   (34427, 69034),
#   (157190, 36784),
#   (1683, 1757),
#   (34137, 4389),
#   (5975, 75929),
#   (136312, 82971),
#   (159488, 59240),
#   (234757, 19577),
#   (4117, 9709),
#   (174999, 67146),
#   (260329, 25140),
#   (133742, 27032),
#   (56252, 13719),
#   (293278, 30735),
#   (132558, 76088),
#   (141008, 58221),
#   (254096, 46950),
#   (104807, 66621),
#   (1512, 838),
#   (135904, 58291),
#   (36369, 19002),
#   (39129, 27489),
#   (46470, 8364),
#   (135272, 98595),
#   (34014, 4625),
#   (133516, 59189),
#   (47731, 39930),
#   (114349, 16858),
#   (75277, 5531),
#   (37487, 19380),
#   (133266, 92203),
#   (80207, 62013),
#   (261388, 62572),
#   (722, 432),
#   (56692, 28633),
#   (71557, 9089),
#   (77123, 4334),
#   (133572, 90696),
#   (10937, 28594),
#   (209868, 7923),
#   (4070, 14128),
#   (83455, 9631),
#   (143048, 74734),
#   (21043, 1085),
#   (47155, 37665),
#   (10772, 8570),
#   (87656, 53331),
#   (36024, 52119),
#   (6489, 6077),
#   (36742, 9430),
#   (50002, 15435),
#   (34772, 30637),
#   (34245, 52966),
#   (3447, 11075),
#   (128808, 92071),
#   (36532, 19058),
#   (78135, 45587),
#   (278419, 7117),
#   (134613, 20259),
#   (43511, 50791),
#   (129570, 88452),
#   (70200, 2509),
#   (167326, 12843),
#   (136821, 91402),
#   (129570, 80804),
#   (5975, 10193),
#   (60102, 53185),
#   (129635, 7697),
#   (43542, 8953),
#   (76019, 62604),
#   (4764, 9005),
#   (244562, 63051),
#   (128654, 83541),
#   (1187, 868),
#   (5894, 13253),
#   (41404, 63429),
#   (236702, 39854),
#   (136281, 88768),
#   (212654, 16946),
#   (137856, 56),
#   (189138, 2167),
#   (181236, 26230),
#   (10766, 28512),
#   (97637, 18666),
#   (43218, 9587),
#   (34555, 55251),
#   (42160, 6184),
#   (53710, 9379),
#   (187017, 62812),
#   (1056, 261),
#   (176176, 9473),
#   (35919, 9444),
#   (35861, 68823),
#   (8162, 4345),
#   (34995, 65107),
#   (37397, 20161),
#   (48094, 26478),
#   (34527, 20337),
#   (33787, 27207),
#   (140823, 58619),
#   (82694, 55126),
#   (7452, 18564),
#   (6098, 3952),
#   (43090, 118162),
#   (43504, 2497),
#   (8445, 19342),
#   (35785, 6254),
#   (140601, 96499),
#   (179902, 72308),
#   (4142, 10828),
#   (133628, 77329),
#   (4060, 7305),
#   (40611, 6311),
#   (40229, 19230),
#   (54134, 21425),
#   (5840, 15428),
#   (3171, 12256),
#   (34898, 23558),
#   (257399, 96811),
#   (1617, 22748),
#   (47113, 1320),
#   (293481, 52166),
#   (8170, 25016),
#   (146608, 25786),
#   (250118, 6987),
#   (115767, 1085),
#   (190598, 62436),
#   (42314, 6727),
#   (36532, 62385),
#   (35919, 41915),
#   (30032, 48979),
#   (36532, 29980),
#   (35181, 23529),
#   (35395, 9443),
#   (52206, 11159),
#   (139611, 6969),
#   (44118, 18206),
#   (7716, 47586),
#   (163036, 2423),
#   (71437, 61488),
#   (74926, 57260),
#   (36516, 8051),
#   (136767, 53084),
#   (75265, 20354),
#   (70307, 2909),
#   (36024, 9470),
#   (139096, 72226),
#   (42948, 7727),
#   (55396, 13532),
#   (9240, 23694),
#   (46774, 7019),
#   (6104, 15182),
#   (86637, 5516),
#   (141786, 91647),
#   (34714, 57974),
#   (234340, 53325),
#   (266998, 92810),
#   (147949, 3357),
#   (41253, 57288),
#   (4281, 53537),
#   (134805, 88539),
#   (261922, 21620),
#   (135153, 58661),
#   (4834, 9558),
#   (146345, 47084),
#   (94835, 13921),
#   (134428, 89544),
#   (45902, 115260),
#   (3936, 10353),
#   (135282, 82120),
#   (45047, 15522),
#   (244968, 24394),
#   (78612, 67484),
#   (130186, 83061),
#   (133369, 83664),
#   (35144, 26366),
#   (138435, 81681),
#   (47696, 48054),
#   (42959, 60929),
#   (136006, 76874),
#   (173983, 57337),
#   (40714, 109211),
#   (23592, 1355),
#   (68267, 37329),
#   (220086, 82505),
#   (138436, 89630),
#   (48459, 19244),
#   (81633, 63580),
#   (42299, 19039),
#   (320, 1132),
#   (2714, 546),
#   (48270, 6684),
#   (271666, 16406),
#   (10444, 23320),
#   (3073, 16762),
#   (38495, 7958),
#   (89009, 1499),
#   (20724, 16508),
#   (132794, 77559),
#   (41404, 50681),
#   (139222, 28918),
#   (100928, 10004),
#   (292955, 70994),
#   (139704, 81947),
#   (288878, 565),
#   (13170, 8161),
#   (36395, 49063),
#   (41253, 9735),
#   (163517, 9492),
#   (39591, 8408),
#   (37516, 20692),
#   (213523, 1215),
#   (21440, 20802),
#   (37361, 61896),
#   (226198, 5768),
#   (44619, 4335),
#   (89279, 60996),
#   (136496, 101795),
#   (135119, 101289),
#   (989, 2719),
#   (37879, 6360),
#   (10267, 19386),
#   (3047, 9768),
#   (246824, 98473),
#   (115045, 79741),
#   (129701, 98746),
#   (41722, 36592),
#   (140006, 11013),
#   (8364, 25920),
#   (40662, 19961),
#   (133204, 20108),
#   (110247, 63231),
#   (134347, 67909),
#   (242, 2304),
#   (53242, 10440),
#   (1563, 1083),
#   (1150, 1604),
#   (135663, 5899),
#   (182974, 14528),
#   (150571, 57993),
#   (74388, 9041),
#   (140006, 81402),
#   (81674, 60380),
#   (47447, 8551),
#   (114851, 40931),
#   (35017, 37329),
#   (7274, 24629),
#   (36532, 27302),
#   (37126, 19539),
#   (134890, 81774),
#   (135221, 97528),
#   (51085, 1710),
#   (132650, 77517),
#   (135856, 87808),
#   (34870, 63969),
#   (138642, 19890),
#   (18049, 7075),
#   (136133, 1291),
#   (303288, 102184),
#   (35785, 9491),
#   (185915, 88346),
#   (34640, 9430),
#   (4059, 12237),
#   (256795, 13468),
#   (256, 661),
#   (7270, 23361),
#   (133204, 90072),
#   (36418, 1386),
#   (4858, 1284),
#   (133684, 83003),
#   (1454, 506),
#   (210506, 37305),
#   (243313, 9),
#   (4495, 10771),
#   (133345, 82724),
#   (134848, 71492),
#   (45482, 34948),
#   (218, 34),
#   (86492, 81681),
#   (27255, 6987),
#   (50423, 712),
#   (37506, 2909),
#   (41118, 44280),
#   (39653, 14475),
#   (7983, 7538),
#   (34189, 59056),
#   (40964, 5516),
#   (162338, 20755),
#   (282682, 19044),
#   (123261, 292),
#   (21440, 49155),
#   (1469, 3761),
#   (68312, 21660),
#   (42948, 4169),
#   (95444, 95),
#   (43659, 26571),
#   (44594, 46051),
#   (65123, 64935),
#   (42314, 62792),
#   (230308, 58549),
#   (37512, 33575),
#   (135696, 93305),
#   (133905, 25502),
#   (8817, 22750),
#   (137784, 7852),
#   (6987, 22114),
#   (144290, 97556),
#   (138436, 87353),
#   (134692, 93373),
#   (69582, 17128),
#   (134069, 83064),
#   (211580, 17295),
#   (54845, 21602),
#   (295, 2908),
#   (55753, 28759),
#   (56347, 28759),
#   (82654, 160),
#   (136746, 89059),
#   (35057, 8379),
#   (207483, 6343),
#   (190598, 13729),
#   (130927, 88186),
#   (4764, 9300),
#   (3592, 12188),
#   (120189, 18870),
#   (46086, 5231),
#   (166261, 20837),
#   (34829, 19167),
#   (136821, 98978),
#   (1767, 37),
#   (41353, 20095),
#   (293600, 66623),
#   (2199, 9653),
#   (146618, 26106),
#   (3677, 1215),
#   (135051, 88448),
#   (44456, 62054),
#   (2229, 807),
#   (72851, 67642),
#   (74000, 48709),
#   (153902, 7293),
#   (48470, 16564),
#   (93462, 49010),
#   (40427, 26571),
#   (95475, 41043),
#   (42819, 17568),
#   (47270, 36892),
#   (136708, 80225),
#   (37114, 56094),
#   (138889, 59010),
#   (36816, 67958),
#   (8707, 6362),
#   (46566, 59455),
#   (37276, 27239),
#   (39826, 7308),
#   (140003, 95165),
#   (127560, 14734),
#   (7637, 19739),
#   (49041, 4614),
#   (37394, 1437),
#   (43687, 53075),
#   (96727, 70286),
#   (240331, 22400),
#   (187983, 3410),
#   (74555, 9686),
#   (79697, 9292),
#   (43050, 68195),
#   (182667, 86488),
#   (41880, 70977),
#   (147314, 52264),
#   (78399, 9345),
#   (36157, 43334),
#   (41564, 8760),
#   (129124, 6346),
#   (138161, 36185),
#   (5604, 87068),
#   (188402, 77259),
#   (137138, 98419),
#   (78766, 73464),
#   (118164, 20362),
#   (143299, 95973),
#   (48677, 9443),
#   (34966, 52706),
#   (116172, 26889),
#   (41155, 7980),
#   (237676, 70539),
#   (4733, 16349),
#   (144367, 17334),
#   (82227, 71062),
#   (62142, 50688),
#   (252830, 44552),
#   (297844, 8470),
#   (130158, 80586),
#   (86367, 58007),
#   (1779, 947),
#   (75283, 8072),
#   (143475, 93449),
#   (43171, 57589),
#   (40729, 70150),
#   (56692, 30168),
#   (133894, 58229),
#   (193309, 97496),
#   (289456, 80823),
#   (38545, 63285),
#   (36760, 7914),
#   (47242, 65225),
#   (141719, 99981),
#   (94742, 8393),
#   (138642, 86697),
#   (100227, 55769),
#   (129570, 90264),
#   (34921, 36446),
#   (49179, 4795),
#   (4070, 13954),
#   (110159, 36185),
#   (40893, 44541),
#   (133317, 53759),
#   (38652, 44485),
#   (39087, 52484),
#   (7852, 18854),
#   (93314, 18262),
#   (56902, 28819),
#   (44048, 56936),
#   (134943, 5881),
#   (147956, 59009),
#   (112525, 53088),
#   (155380, 53909),
#   (7960, 13078),
#   (7179, 32178),
#   (131188, 88832),
#   (73372, 8364),
#   (719, 28801),
#   (133925, 90436),
#   (67476, 57991),
#   (163517, 48448),
#   (138793, 7367),
#   (136065, 19112),
#   (133536, 59044),
#   (141438, 21425),
#   (33787, 61729),
#   (34011, 4627),
#   (3274, 15533),
#   (46446, 20996),
#   (3274, 9709),
#   (12107, 6945),
#   (110159, 9543),
#   (554, 3304),
#   (39786, 39650),
#   (6252, 1308),
#   (79830, 63608),
#   (52626, 9605),
#   (44874, 80549),
#   (52758, 11814),
#   (36873, 20673),
#   (38419, 8045),
#   (34086, 55073),
#   (37126, 34047),
#   (34371, 48553),
#   (189105, 74977),
#   (231340, 2509),
#   (35902, 8366),
#   (11235, 14110),
#   (3198, 12372),
#   (3457, 10271),
#   (74015, 6800),
#   (139451, 83527),
#   (10547, 28465),
#   (204651, 6858),
#   (38719, 9444),
#   (4858, 10349),
#   (103345, 67326),
#   (142243, 3873),
#   (137682, 1470),
#   (136312, 79430),
#   (44875, 49591),
#   (7654, 22056),
#   (37547, 5631),
#   (85009, 9493),
#   (47960, 18393),
#   (3556, 16406),
#   (7270, 4683),
#   (130302, 26063),
#   (213271, 98521),
#   (217290, 102755),
#   (35144, 67817),
#   (79808, 67437),
#   (34921, 37665),
#   (112014, 1029),
#   (46522, 3972),
#   (213989, 906),
#   (35107, 58717),
#   (142182, 58117),
#   (43705, 4276),
#   (2199, 4813),
#   (37879, 20788),
#   (69295, 6792),
#   (37464, 41131),
#   (43006, 52573),
#   (2199, 2374),
#   (5266, 10827),
#   (178951, 46939),
#   (37012, 34804),
#   (91199, 4221),
#   (134697, 83414),
#   (8065, 2399),
#   (67831, 3554),
#   (35937, 64377),
#   (36532, 70737),
#   (130927, 74366),
#   (21137, 19794),
#   (129752, 89700),
#   (254186, 92375),
#   (136996, 86271),
#   (111871, 7239),
#   (3598, 11331),
#   (223401, 47027),
#   (46446, 70210),
#   (9506, 9059),
#   (175687, 27454),
#   (46035, 47686),
#   (133835, 77026),
#   (41118, 64374),
#   (2118, 5771),
#   (3146, 11496),
#   (133317, 80805),
#   (73176, 62629),
#   (48007, 609),
#   (142887, 53323),
#   (87434, 18119),
#   (204651, 71459),
#   (50230, 80715),
#   (43765, 18227),
#   (158431, 25901),
#   (57637, 31365),
#   (137522, 15420),
#   (48213, 53088),
#   (39736, 20233),
#   (2878, 516),
#   (121562, 85062),
#   (156678, 19327),
#   (144410, 100808),
#   (108774, 7498),
#   (178136, 25880),
#   (211680, 47784),
#   (6149, 13473),
#   (3172, 11919),
#   (2917, 8296),
#   (43391, 18903),
#   (42650, 52605),
#   (141526, 58867),
#   (7510, 16982),
#   (44261, 68191),
#   (21657, 9),
#   (56912, 30014),
#   (180667, 7306),
#   (3560, 17443),
#   (35809, 62253),
#   (34640, 16291),
#   (37464, 36527),
#   (1952, 6257),
#   (134400, 58364),
#   (53562, 2080),
#   (45622, 65618),
#   (138753, 98747),
#   (139096, 90539),
#   (43155, 63974),
#   (35906, 22852),
#   (36873, 6289),
#   (136891, 104276),
#   (9483, 22948),
#   (135678, 91799),
#   (288817, 93631),
#   (137968, 80743),
#   (139980, 10242),
#   (293045, 69501),
#   (9817, 27549),
#   (54213, 7631),
#   (34906, 34024),
#   (131051, 59339),
#   (35919, 37273),
#   (143656, 76453),
#   (38933, 63251),
#   (134821, 25960),
#   (41537, 54638),
#   (139045, 104109),
#   (184989, 18151),
#   (7419, 17177),
#   (36532, 6727),
#   (77439, 35495),
#   (102706, 57765),
#   (136530, 7025),
#   (48525, 7422),
#   (99627, 16531),
#   (119532, 20226),
#   (3917, 10890),
#   (653, 421),
#   (34996, 16608),
#   (53269, 14153),
#   (185804, 33860),
#   (36532, 19690),
#   (42926, 29388),
#   (130784, 4453),
#   (153196, 98457),
#   (1362, 1786),
#   (37361, 26571),
#   (45007, 62831),
#   (77908, 52534),
#   (47160, 68083),
#   (475, 206),
#   (97, 2620),
#   (133592, 83350),
#   (139800, 19955),
#   (138729, 7360),
#   (45399, 62838),
#   (147167, 50688),
#   (35144, 48720),
#   (2607, 275),
#   (38393, 26557),
#   (139821, 8093),
#   (45525, 4614),
#   (194022, 22577),
#   (154458, 67838),
#   (179395, 90946),
#   (46108, 9309),
#   (175119, 51195),
#   (43109, 45488),
#   (136048, 71459),
#   (35882, 34648),
#   (19052, 37303),
#   (49720, 7570),
#   (48775, 74556),
#   (44414, 9800),
#   (11361, 30975),
#   (67194, 8592),
#   (114898, 19716),
#   (37236, 8629),
#   (5239, 10715),
#   (38326, 8774),
#   (112690, 6792),
#   (83695, 750),
#   (7510, 5506),
#   (35433, 18750),
#   (34569, 63703),
#   (69710, 66266),
#   (126345, 9562),
#   (41496, 26239),
#   (184930, 63898),
#   (136006, 90469),
#   (43391, 51807),
#   (79397, 27333),
#   (3090, 10053),
#   (77118, 6769),
#   (44341, 22160),
#   (80076, 6897),
#   (135694, 94832),
#   (78153, 2462),
#   (130201, 91520),
#   (37397, 57260),
#   (997, 40109),
#   (146962, 88910),
#   (83418, 26485),
#   (41327, 19747),
#   (56902, 29456),
#   (182680, 1728),
#   (35333, 4356),
#   (282075, 74830),
#   (191438, 34804),
#   (35243, 65069),
#   (153251, 19964),
#   (148841, 25552),
#   (43389, 54938),
#   (11717, 31192),
#   (140839, 85950),
#   (138186, 58410),
#   (176556, 50885),
#   (8162, 9084),
#   (97637, 6035),
#   (33668, 12854),
#   (212104, 9774),
#   (10467, 29701),
#   (2726, 9627),
#   (134788, 76231),
#   (38075, 26872),
#   (136357, 89544),
#   (141735, 74865)],
#  [(138889, 46953),
#   (53563, 13672),
#   (4011, 11499),
#   (69675, 7780),
#   (71291, 62169),
#   (101631, 2265),
#   (4621, 11481),
#   (158681, 75799),
#   (35799, 19181),
#   (44678, 34706),
#   (4057, 12237),
#   (778, 2739),
#   (43050, 5100),
#   (292122, 20271),
#   (137146, 83950),
#   (7785, 6362),
#   (141075, 97419),
#   (49983, 552),
#   (289241, 35699),
#   (76119, 20538),
#   (39865, 8727),
#   (31350, 3693),
#   (48597, 47749),
#   (77857, 26506),
#   (11357, 29148),
#   (4764, 11261),
#   (4011, 11368),
#   (2257, 660),
#   (37236, 19380),
#   (85009, 8339),
#   (140757, 90079),
#   (2745, 9787),
#   (136326, 59429),
#   (139716, 80124),
#   (88654, 19523),
#   (137506, 77026),
#   (20933, 9616),
#   (54134, 94240),
#   (37740, 62854),
#   (43429, 61923),
#   (82659, 52069),
#   (3452, 11847),
#   (33874, 54986),
#   (103568, 35401),
#   (753, 309),
#   (9104, 14397),
#   (44155, 6289),
#   (141161, 82713),
#   (34687, 80591),
#   (40862, 9268),
#   (4029, 11774),
#   (134787, 15525),
#   (113561, 67142),
#   (40852, 18572),
#   (45622, 51576),
#   (310, 5376),
#   (37377, 66128),
#   (135384, 81268),
#   (120189, 6800),
#   (138757, 5166),
#   (95440, 8774),
#   (80399, 69769),
#   (95262, 2536),
#   (137173, 58033),
#   (41660, 7556),
#   (27510, 72443),
#   (133516, 58578),
#   (39327, 19969),
#   (304, 421),
#   (128192, 6949),
#   (36532, 57765),
#   (48575, 6901),
#   (1772, 712),
#   (258345, 100637),
#   (131678, 92920),
#   (148056, 29721),
#   (165913, 91333),
#   (40096, 18773),
#   (77625, 1445),
#   (208602, 58350),
#   (88654, 69501),
#   (118171, 52601),
#   (1779, 757),
#   (209976, 22133),
#   (3483, 6723),
#   (717, 2988),
#   (70908, 60352),
#   (36371, 48514),
#   (47242, 25397),
#   (37250, 62301),
#   (41732, 47783),
#   (51228, 11892),
#   (133994, 58180),
#   (37276, 17568),
#   (271096, 100984),
#   (8398, 5920),
#   (8102, 8847),
#   (33913, 18520),
#   (21500, 2033),
#   (54036, 7817),
#   (102349, 24217),
#   (143993, 92852),
#   (139246, 92800),
#   (35058, 7068),
#   (285067, 1257),
#   (151390, 16694),
#   (49564, 458),
#   (36532, 50117),
#   (9945, 18124),
#   (211580, 4319),
#   (265752, 74858),
#   (110159, 19641),
#   (69675, 18151),
#   (164376, 6863),
#   (34336, 8246),
#   (95092, 2562),
#   (37206, 8698),
#   (36618, 39491),
#   (95545, 15289),
#   (153783, 6695),
#   (135079, 91448),
#   (3597, 13522),
#   (134890, 58084),
#   (134740, 90145),
#   (48450, 16508),
#   (220767, 74995),
#   (161076, 92757),
#   (320, 499),
#   (37740, 61619),
#   (217734, 82411),
#   (35902, 65713),
#   (134382, 92545),
#   (119532, 26909),
#   (34023, 25477),
#   (127947, 87967),
#   (115390, 52541),
#   (136357, 85211),
#   (126393, 14952),
#   (39174, 3973),
#   (7716, 91109),
#   (3997, 14045),
#   (198507, 62884),
#   (212366, 20790),
#   (37285, 18358),
#   (135191, 18851),
#   (136266, 59234),
#   (129075, 21236),
#   (114267, 19230),
#   (34696, 60100),
#   (170407, 9776),
#   (35101, 50784),
#   (135681, 7011),
#   (134469, 70081),
#   (158700, 30359),
#   (37340, 9373),
#   (46446, 1496),
#   (36794, 57392),
#   (196563, 71443),
#   (139045, 91795),
#   (35471, 48221),
#   (92784, 4022),
#   (261563, 64237),
#   (140805, 85597),
#   (78618, 19515),
#   (38463, 9437),
#   (5101, 18981),
#   (128693, 1675),
#   (69675, 12152),
#   (56336, 7836),
#   (136551, 97286),
#   (44358, 7895),
#   (0, 1550),
#   (143656, 86697),
#   (34629, 61036),
#   (119400, 3315),
#   (11220, 29128),
#   (198905, 58347),
#   (134354, 77741),
#   (38959, 8248),
#   (110159, 48448),
#   (72368, 60771),
#   (72780, 1126),
#   (1055, 445),
#   (176, 4954),
#   (137529, 81387),
#   (77351, 63507),
#   (47082, 9449),
#   (46818, 7308),
#   (42776, 5909),
#   (121609, 2915),
#   (49564, 2409),
#   (114797, 1323),
#   (45262, 9536),
#   (31895, 6139),
#   (140296, 93589),
#   (233581, 9013),
#   (75257, 51941),
#   (7804, 6116),
#   (4070, 7114),
#   (21296, 41815),
#   (165447, 45495),
#   (131042, 86805),
#   (33941, 21581),
#   (11162, 28825),
#   (37285, 1349),
#   (4431, 16344),
#   (67729, 45777),
#   (87574, 91936),
#   (34870, 61765),
#   (50448, 1568),
#   (171418, 77357),
#   (36063, 7283),
#   (47242, 65260),
#   (122343, 21900),
#   (81751, 65484),
#   (8353, 22964),
#   (42823, 48556),
#   (96727, 16318),
#   (115849, 48552),
#   (36969, 63188),
#   (48232, 66745),
#   (220994, 111069),
#   (34133, 64130),
#   (10215, 28050),
#   (40009, 54630),
#   (194175, 9455),
#   (168692, 85908),
#   (207582, 48652),
#   (9479, 6316),
#   (164734, 88141),
#   (165751, 27564),
#   (34245, 36770),
#   (37613, 5909),
#   (56105, 27745),
#   (3914, 6828),
#   (70803, 4307),
#   (136312, 83295),
#   (178038, 46412),
#   (34051, 32638),
#   (40497, 27988),
#   (2562, 7144),
#   (41290, 5584),
#   (36919, 3874),
#   (13835, 29813),
#   (10857, 29343),
#   (129400, 76498),
#   (4821, 10222),
#   (140677, 76446),
#   (50618, 9774),
#   (44795, 47456),
#   (131042, 87393),
#   (14296, 53016),
#   (283428, 58627),
#   (40729, 37828),
#   (135643, 76254),
#   (11124, 8528),
#   (136399, 51887),
#   (82819, 4424),
#   (135300, 76517),
#   (7784, 7063),
#   (79291, 6346),
#   (166021, 76846),
#   (38894, 47913),
#   (135522, 81518),
#   (160658, 78527),
#   (80723, 50574),
#   (194805, 52293),
#   (164734, 59093),
#   (7510, 7632),
#   (130645, 7089),
#   (81476, 51775),
#   (152848, 52866),
#   (144328, 11027),
#   (142432, 17000),
#   (45899, 64376),
#   (38250, 67642),
#   (102312, 63040),
#   (528, 175),
#   (137667, 75739),
#   (49783, 1496),
#   (4868, 10958),
#   (221010, 20226),
#   (112841, 65203),
#   (98156, 48826),
#   (744, 777),
#   (3239, 10708),
#   (275934, 27995),
#   (3666, 11814),
#   (136891, 92234),
#   (78064, 61582),
#   (134255, 87918),
#   (6933, 24728),
#   (161529, 65317),
#   (178532, 68535),
#   (42307, 25424),
#   (36945, 20996),
#   (4858, 9740),
#   (72461, 52104),
#   (4041, 21639),
#   (133572, 71531),
#   (136676, 97141),
#   (23461, 62340),
#   (50790, 11283),
#   (7227, 27746),
#   (7925, 9034),
#   (54134, 58166),
#   (140585, 3634),
#   (81118, 21516),
#   (119863, 6673),
#   (1010, 3300),
#   (37251, 6820),
#   (237313, 53494),
#   (291617, 2063),
#   (48770, 1988),
#   (726, 4882),
#   (202189, 81911),
#   (97637, 93449),
#   (35614, 37401),
#   (220767, 16864),
#   (111050, 53379),
#   (141351, 16891),
#   (4273, 11350),
#   (130809, 71852),
#   (37157, 9303),
#   (70522, 31999),
#   (4829, 10747),
#   (40180, 51791),
#   (38442, 36940),
#   (135153, 78147),
#   (134925, 26462),
#   (138746, 93521),
#   (9379, 9477),
#   (140910, 96505),
#   (48615, 45645),
#   (146345, 73854),
#   (115391, 17026),
#   (4764, 14472),
#   (133240, 47593),
#   (129124, 90058),
#   (67415, 19961),
#   (36742, 48570),
#   (139537, 89346),
#   (47830, 9582),
#   (153491, 5675),
#   (68058, 7556),
#   (44619, 52732),
#   (130314, 93254),
#   (135158, 47572),
#   (36532, 65789),
#   (3600, 13571),
#   (39129, 8364),
#   (130605, 11608),
#   (67194, 7719),
#   (4495, 13308),
#   (37555, 19035),
#   (76703, 9238),
#   (238246, 61809),
#   (3274, 12315),
#   (40477, 49927),
#   (180031, 1156),
#   (133037, 8867),
#   (37047, 61923),
#   (215947, 59163),
#   (1478, 882),
#   (36532, 24401),
#   (37684, 51602),
#   (135192, 21000),
#   (220267, 83517),
#   (294809, 99801),
#   (35181, 8844),
#   (8117, 8178),
#   (2582, 6496),
#   (131187, 84058),
#   (35870, 20397),
#   (45418, 1126),
#   (40899, 7942),
#   (147314, 78084),
#   (118838, 103027),
#   (40318, 6904),
#   (34587, 51941),
#   (95768, 37314),
#   (135696, 58528),
#   (48319, 8339),
#   (1277, 2648),
#   (135681, 83464),
#   (166021, 77112),
#   (34687, 37305),
#   (71972, 10205),
#   (162002, 19572),
#   (70141, 7320),
#   (186344, 21978),
#   (11032, 27987),
#   (180223, 8493),
#   (40406, 19285),
#   (280584, 3459),
#   (203945, 1168),
#   (527, 1945),
#   (168279, 16128),
#   (52208, 11994),
#   (136588, 16231),
#   (72127, 71781),
#   (5110, 10404),
#   (181541, 6635),
#   (136312, 17021),
#   (1374, 1802),
#   (99014, 4614),
#   (131660, 87294),
#   (36628, 19550),
#   (9099, 7195),
#   (30734, 26865),
#   (46816, 19674),
#   (44874, 65930),
#   (30344, 18978),
#   (161782, 2620),
#   (87324, 67222),
#   (185855, 12795),
#   (34714, 53105),
#   (161143, 83757),
#   (114851, 25226),
#   (47240, 7241),
#   (167558, 12146),
#   (4140, 11400),
#   (34112, 56297),
#   (9532, 24130),
#   (134739, 77121),
#   (126838, 9894),
#   (45102, 27200),
#   (45827, 19774),
#   (179599, 98574),
#   (9808, 8169),
#   (78053, 64480),
#   (51592, 10231),
#   (136197, 92838),
#   (134225, 75815),
#   (121305, 53661),
#   (45725, 6684),
#   (3483, 9612),
#   (4748, 13757),
#   (44793, 29402),
#   (138438, 74861),
#   (74025, 53325),
#   (33874, 15522),
#   (137784, 22101),
#   (39230, 66191),
#   (144750, 96778),
#   (178391, 117271),
#   (44788, 6684),
#   (38856, 62656),
#   (257334, 74323),
#   (36138, 16445),
#   (157648, 83661),
#   (119262, 11492),
#   (152207, 58431),
#   (136496, 59255),
#   (1368, 28714),
#   (129548, 15008),
#   (286194, 7697),
#   (45739, 382),
#   (36888, 7949),
#   (36646, 67332),
#   (43391, 44144),
#   (7852, 1543),
#   (146581, 102644),
#   (93136, 18493),
#   (34046, 39674),
#   (3523, 10085),
#   (292122, 19265),
#   (144528, 88493),
#   (138753, 91222),
#   (65061, 64843),
#   (237285, 720),
#   (135856, 89338),
#   (132595, 91703),
#   (139194, 82947),
#   (210288, 14414),
#   (7015, 7458),
#   (653, 2043),
#   (35100, 54326),
#   (5374, 18887),
#   (35057, 6346),
#   (34946, 8678),
#   (2764, 415),
#   (7453, 7687),
#   (137669, 96724),
#   (37487, 25140),
#   (3874, 4468),
#   (87507, 4035),
#   (4653, 16100),
#   (34696, 9374),
#   (44058, 26818),
#   (99915, 73071),
#   (290791, 9055),
#   (10657, 28889),
#   (77653, 52783),
#   (32448, 62970),
#   (72814, 8436),
#   (109278, 21588),
#   (122343, 21424),
#   (54134, 58347),
#   (155417, 1334),
#   (205358, 97089),
#   (135168, 87655),
#   (56174, 5677),
#   (30032, 17265),
#   (196005, 90280),
#   (139194, 80412),
#   (187003, 91617),
#   (7484, 6460),
#   (129348, 89387),
#   (184546, 52236),
#   (231938, 48145),
#   (137243, 95807),
#   (112314, 52996),
#   (1590, 265),
#   (116917, 19871),
#   (173910, 19179),
#   (140823, 80124),
#   (71123, 26713),
#   (180393, 6845),
#   (98505, 63166),
#   (3681, 69),
#   (81988, 58777),
#   (7270, 2080),
#   (175687, 59148),
#   (12354, 60281),
#   (989, 1025),
#   (38416, 25598),
#   (239479, 98130),
#   (126836, 7789),
#   (179598, 88654),
#   (141005, 89846),
#   (130201, 81519),
#   (249361, 6051),
#   (133266, 84135),
#   (35004, 49343),
#   (227457, 98187),
#   (36978, 2497),
#   (101803, 8573),
#   (78618, 4401),
#   (132371, 76531),
#   (142064, 104147),
#   (134771, 7916),
#   (34629, 6741),
#   (141117, 25801),
#   (3006, 12303),
#   (40082, 20692),
#   (8272, 6668),
#   (139222, 46431),
#   (132040, 16257),
#   (36378, 23887),
#   (142432, 8617),
#   (81988, 53900),
#   (134153, 76657),
#   (125214, 33524),
#   (138710, 85172),
#   (197341, 105490),
#   (133835, 79818),
#   (69000, 53143),
#   (33874, 24241),
#   (117970, 14137),
#   (137352, 94029),
#   (143118, 86216),
#   (37555, 61202),
#   (41896, 21516),
#   (136326, 90388),
#   (87219, 19477),
#   (129862, 25901),
#   (138162, 58425),
#   (46726, 62167),
#   (129183, 88627),
#   (47302, 84596),
#   (149042, 11652),
#   (210324, 8050),
#   (40961, 1440),
#   (38569, 49641),
#   (46960, 52760),
#   (41500, 54985),
#   (247991, 20785),
#   (6809, 7282),
#   (137642, 91388),
#   (3760, 9379),
#   (10692, 8449),
#   (34927, 51145),
#   (75205, 23887),
#   (152439, 10054),
#   (54131, 7073),
#   (82686, 36892),
#   (45291, 55227),
#   (178951, 73732),
#   (46576, 6325),
#   (115184, 55473),
#   (135414, 58229),
#   (179670, 56),
#   (235376, 10128),
#   (134655, 76080),
#   (45160, 69758),
#   (34252, 8228),
#   (141785, 80284),
#   (138642, 89121),
#   (10444, 3379),
#   (35534, 52658),
#   (135158, 99526),
#   (39715, 54326),
#   (132429, 10435),
#   (42247, 24507),
#   (221610, 48399),
#   (155483, 90446),
#   (102154, 68828),
#   (140928, 26166),
#   (182974, 76453),
#   (40159, 7012),
#   (37257, 9342),
#   (132801, 82713),
#   (3729, 12818),
#   (39348, 8842),
#   (178038, 19172),
#   (142581, 93575),
#   (42311, 61785),
#   (38677, 3687),
#   (98931, 19059),
#   (230954, 82423),
#   (138681, 88304),
#   (40906, 8274),
#   (167326, 7025),
#   (212721, 83517),
#   (137144, 3634),
#   (1590, 2007),
#   (42393, 8842),
#   (133595, 29662),
#   (133523, 8637),
#   (41155, 7994),
#   (209776, 64198),
#   (78262, 49591),
#   (130402, 4333),
#   (136807, 79238),
#   (139800, 16677),
#   (36584, 1012),
#   (47302, 1299),
#   (153196, 58647),
#   (6062, 11691),
#   (281229, 14414),
#   (158127, 47027),
#   (39129, 16545),
#   (4406, 11224),
#   (135616, 94964),
#   (112473, 1402),
#   (45692, 16318),
#   (71045, 62058),
#   (41103, 55794),
#   (132322, 20902),
#   (34965, 3874),
#   (34742, 17907),
#   (78967, 19720),
#   (134960, 96382),
#   (68705, 51656),
#   (7960, 24962),
#   (86389, 45467),
#   (83753, 8294),
#   (88501, 5531),
#   (138642, 58713),
#   (82824, 69910),
#   (37164, 64586),
#   (34611, 48729),
#   (40899, 19114),
#   (44533, 30145),
#   (36063, 16208),
#   (139740, 74047),
#   (35321, 8489),
#   (142581, 53047),
#   (39250, 61072),
#   (169441, 2427),
#   (168909, 64118),
#   (35381, 47994),
#   (114267, 9375),
#   (9019, 5273),
#   (286968, 10190),
#   (136576, 96745),
#   (719, 1404),
#   (193494, 3979),
#   (35226, 18517),
#   (6528, 3672),
#   (39357, 36777),
#   (130785, 6343),
#   (112712, 2544),
#   (133495, 58110),
#   (25903, 9504),
#   (134910, 19997),
#   (220086, 77147),
#   (46522, 8260),
#   (133516, 101106),
#   (2084, 6147),
#   (135272, 58207),
#   (82035, 6794),
#   (4774, 12958),
#   (131137, 51908),
#   (42332, 20355),
#   (71816, 5967),
#   (104391, 6720),
#   (76966, 19674),
#   (164178, 4340),
#   (13390, 6177),
#   (1348, 7072),
#   (34721, 71644),
#   (6346, 12646),
#   (6758, 11333),
#   (127782, 1869),
#   (40074, 7229),
#   (121576, 49106),
#   (6724, 13475),
#   (137332, 72191),
#   (140527, 71531),
#   (30032, 18206),
#   (10902, 28817),
#   (112051, 67905),
#   (37879, 53988),
#   (35112, 4461),
#   (133875, 83191),
#   (132519, 94113),
#   (34921, 20804),
#   (95444, 4282),
#   (276367, 48497),
#   (40345, 16414),
#   (37100, 7403),
#   (250278, 18799),
#   (7942, 22393),
#   (97869, 86382),
#   (137642, 84541),
#   (129862, 19768),
#   (35882, 7923),
#   (626, 971),
#   (54691, 13645),
#   (138642, 26040),
#   (165125, 2196),
#   (138091, 87006),
#   (95368, 19544),
#   (35767, 73515),
#   (281346, 9650),
#   (98394, 2544),
#   (4100, 9321),
#   (37938, 59384),
#   (136440, 95947),
#   (6686, 75070),
#   (35828, 8296),
#   (139137, 57949),
#   (300430, 26391),
#   (204742, 87659),
#   (54134, 77322),
#   (36378, 6621),
#   (36054, 20788),
#   (265057, 91995),
#   (304, 1411),
#   (3452, 21852),
#   (201840, 41815),
#   (34051, 58976),
#   (35739, 7491),
#   (45268, 64000),
#   (4081, 9774),
#   (133947, 59401),
#   (88624, 9473),
#   (36169, 6931),
#   (44875, 18766),
#   (134452, 82411),
#   (74324, 61719),
#   (37993, 61364),
#   (92784, 1156),
#   (252315, 10038),
#   (48568, 52984),
#   (160130, 16670),
#   (65123, 18915),
#   (121, 469),
#   (132208, 58510),
#   (277165, 1502),
#   (38474, 61098),
#   (143334, 90219),
#   (7618, 58012),
#   (37740, 4405),
#   (158532, 10477),
#   (150978, 63944),
#   (16148, 68103),
#   (39129, 9103),
#   (35144, 59062),
#   (97981, 71736),
#   (1374, 777),
#   (34046, 18358),
#   (137828, 85900),
#   (81545, 36866),
#   (47153, 8905),
#   (235353, 78132),
#   (37351, 67754),
#   (130519, 92059),
#   (273744, 70797),
#   (220500, 61237),
#   (142957, 5881),
#   (133236, 90871),
#   (37072, 37294),
#   (151359, 79662),
#   (42496, 9493),
#   (112525, 15999),
#   (40474, 19163),
#   (48309, 18434),
#   (7716, 20224),
#   (53208, 7688),
#   (117760, 4319),
#   (54310, 10997),
#   (77661, 18894),
#   (135416, 5797),
#   (41620, 53620),
#   (36532, 16159),
#   (181541, 36885),
#   (133592, 79502),
#   (46759, 60779),
#   (69295, 17207),
#   (141075, 77357),
#   (46446, 48680),
#   (112888, 27109),
#   (152, 421),
#   (36157, 62216),
#   (140296, 89874),
#   (46516, 63659),
#   (131859, 88941),
#   (115545, 49083),
#   (331, 608),
#   (55873, 41705),
#   (38773, 6184),
#   (139948, 90180),
#   (56161, 13058),
#   (42091, 19285),
#   (7881, 7035),
#   (149843, 70819),
#   (44141, 61753),
#   (137243, 91586),
#   (114457, 9801),
#   (6904, 19318),
#   (43605, 27326),
#   (12877, 2497),
#   (136746, 89044),
#   (37879, 6318),
#   (174973, 19843),
#   (38119, 60527),
#   (161364, 71060),
#   (6992, 25147),
#   (35415, 61389),
#   (54284, 8063),
#   (134960, 6339),
#   (127486, 115210),
#   (856, 4193),
#   (45047, 39664),
#   (137217, 86880),
#   (233581, 23),
#   (275769, 6231),
#   (77667, 60943),
#   (221859, 1496),
#   (45413, 62728),
#   (253469, 7269),
#   (137799, 6666),
#   (135153, 14920),
#   (44619, 48560),
#   (180335, 1445),
#   (23967, 6769),
#   (237415, 64748),
#   (45793, 9914),
#   (135910, 80806),
#   (50091, 53382),
#   (1106, 1989),
#   (55064, 21991),
#   (138875, 88304),
#   (87507, 26769),
#   (79062, 20872),
#   (8451, 9875),
#   (137044, 58895),
#   (1478, 175),
#   (138438, 81649),
#   (7618, 84244),
#   (45545, 66451),
#   (130012, 15713),
#   (89279, 3687),
#   (3592, 10074),
#   (133618, 59360),
#   (127868, 6620),
#   (222045, 99137),
#   (35245, 45467),
#   (4752, 11492),
#   (34921, 55473),
#   (46384, 44386),
#   (278088, 23604),
#   (180667, 43379),
#   (130809, 99656),
#   (39230, 55411),
#   (141008, 81402),
#   (37433, 19571),
#   (2199, 636),
#   (36157, 9568),
#   (136120, 63045),
#   (68184, 52379),
#   (139021, 15686),
#   (4140, 11162),
#   (36532, 53634),
#   (36161, 13169),
#   (111304, 9666),
#   (34051, 3687),
#   (141848, 90552),
#   (39129, 18936),
#   (37033, 3284),
#   (5975, 13855),
#   (137905, 59038),
#   (36024, 20762),
#   (119927, 61732),
#   (33941, 52982),
#   (102207, 18358),
#   (157224, 76846),
#   (16148, 10061),
#   (52000, 10240),
#   (140608, 96659),
#   (139222, 25780),
#   (6758, 10394),
#   (42837, 64263),
#   (100099, 7019),
#   (47941, 64537),
#   (98394, 1402),
#   (82522, 8493),
#   (35037, 60713),
#   (49902, 67813),
#   (94985, 1444),
#   (70071, 19770),
#   (54134, 84279),
#   (51553, 9335),
#   (7023, 22262),
#   (40477, 8762),
#   (137779, 102787),
#   (138319, 51887),
#   (188992, 21754),
#   (34965, 5262),
#   (6718, 22624),
#   (134522, 20739),
#   (4429, 21475),
#   (38239, 66254),
#   (70700, 51073),
#   (72400, 9151),
#   (35388, 20354),
#   (69861, 19342),
#   (70217, 17357),
#   (43804, 72102),
#   (54310, 11665),
#   (40413, 25182),
#   (50236, 74369),
#   (3997, 13184),
#   (7274, 26045),
#   (35850, 26270),
#   (184950, 77026),
#   (137947, 84062),
#   (154268, 19720),
#   (7937, 3459),
#   (68771, 1126),
#   (133490, 89626),
#   (27404, 6720),
#   (44181, 23850),
#   (105272, 61260),
#   (144750, 67909),
#   (138537, 58207),
#   (112965, 11357),
#   (607, 3434),
#   (136503, 99857),
#   (128654, 83127),
#   (134663, 92150),
#   (130429, 88911),
#   (123763, 79162),
#   (34869, 55833),
#   (10772, 8110),
#   (46470, 9342),
#   (201095, 53086),
#   (50080, 3803),
#   (39941, 19104),
#   (35012, 19532),
#   (36532, 63967),
#   (73518, 16369),
#   (11183, 28321),
#   (130605, 10333),
#   (36035, 48334),
#   (6676, 13837),
#   (3745, 12378),
#   (190847, 16953),
#   (53342, 74323),
#   (132231, 59304),
#   (115311, 25783),
#   (37231, 26562),
#   (52157, 111047),
#   (51440, 8984),
#   (130314, 17932),
#   (162941, 9323),
#   (42531, 54819),
#   (135208, 76056),
#   (178942, 18232),
#   (34823, 18307),
#   (48635, 19058),
#   (171418, 79238),
#   (43264, 13373),
#   (138685, 98335),
#   (69578, 72073),
#   (37483, 12926),
#   (171824, 16146)],
#  [(134295, 80715),
#   (46818, 49209),
#   (154727, 58493),
#   (180385, 18393),
#   (82512, 18951),
#   (301525, 16897),
#   (161068, 22051),
#   (137619, 83407),
#   (54691, 487),
#   (121609, 1375),
#   (45165, 8704),
#   (178492, 67058),
#   (132257, 71890),
#   (44414, 8628),
#   (45622, 6904),
#   (43515, 64124),
#   (11226, 30125),
#   (131240, 85085),
#   (4029, 11193),
#   (138435, 73772),
#   (9483, 21122),
#   (180223, 5902),
#   (132437, 82422),
#   (21394, 71369),
#   (1590, 3921),
#   (37072, 68086),
#   (1187, 246),
#   (40624, 4276),
#   (55361, 28227),
#   (47830, 10211),
#   (37711, 20271),
#   (46818, 59236),
#   (68375, 26085),
#   (68907, 54020),
#   (161636, 84080),
#   (130834, 8545),
#   (36397, 3802),
#   (6293, 10228),
#   (34016, 61732),
#   (71989, 59382),
#   (211123, 88881),
#   (117760, 9666),
#   (52204, 14486),
#   (210663, 79818),
#   (99097, 20559),
#   (4368, 10569),
#   (238468, 56290),
#   (34051, 16591),
#   (133057, 80973),
#   (5362, 9),
#   (134826, 75710),
#   (42533, 19342),
#   (34023, 23965),
#   (37361, 7823),
#   (1550, 3417),
#   (220564, 58641),
#   (137346, 99336),
#   (98836, 3530),
#   (81278, 4333),
#   (44464, 65964),
#   (134349, 103926),
#   (98548, 21943),
#   (52208, 9832),
#   (117917, 53809),
#   (52243, 12343),
#   (50452, 10235),
#   (52192, 65316),
#   (133738, 53079),
#   (34854, 26986),
#   (39670, 47664),
#   (38666, 16577),
#   (98026, 9486),
#   (142432, 93473),
#   (34869, 8601),
#   (182988, 13176),
#   (35112, 19004),
#   (122001, 59469),
#   (134628, 75730),
#   (78399, 8762),
#   (34051, 34059),
#   (155417, 9444),
#   (3677, 11595),
#   (78073, 7005),
#   (94408, 89874),
#   (91785, 5410),
#   (82558, 28826),
#   (9864, 22473),
#   (40096, 9284),
#   (218970, 4355),
#   (36378, 1341),
#   (229765, 47507),
#   (99125, 41946),
#   (7637, 23224),
#   (5776, 9859),
#   (44114, 26893),
#   (92819, 78527),
#   (55710, 16271),
#   (7770, 75125),
#   (46825, 45791),
#   (42970, 8870),
#   (42500, 61753),
#   (37642, 47276),
#   (11394, 30577),
#   (35057, 30591),
#   (136444, 95029),
#   (137558, 87690),
#   (137704, 101360),
#   (151601, 11030),
#   (34753, 48317),
#   (205737, 6240),
#   (134127, 90191),
#   (3745, 12372),
#   (4321, 10444),
#   (34245, 6985),
#   (87319, 50679),
#   (4764, 10855),
#   (87536, 1763),
#   (2084, 268),
#   (219129, 101468),
#   (73372, 20313),
#   (98629, 11329),
#   (46825, 61260),
#   (7250, 76328),
#   (137840, 99129),
#   (138681, 58262),
#   (4209, 15320),
#   (34583, 53060),
#   (37271, 18978),
#   (34920, 6688),
#   (36839, 45467),
#   (5279, 4447),
#   (37136, 62403),
#   (212366, 59236),
#   (3447, 5665),
#   (239697, 16272),
#   (53208, 25271),
#   (97937, 9473),
#   (41327, 26478),
#   (96913, 14175),
#   (40879, 8571),
#   (39640, 4453),
#   (139948, 75054),
#   (133099, 8731),
#   (4111, 74232),
#   (134710, 20434),
#   (134204, 81387),
#   (70522, 55418),
#   (134263, 83638),
#   (111770, 64595),
#   (50513, 10410),
#   (133988, 92474),
#   (138019, 81362),
#   (138120, 75799),
#   (175687, 1459),
#   (134225, 93898),
#   (136576, 92513),
#   (138019, 89862),
#   (42288, 9491),
#   (147776, 83370),
#   (1472, 494),
#   (129348, 90104),
#   (2726, 65290),
#   (239647, 10052),
#   (40795, 9996),
#   (36320, 9589),
#   (35534, 18814),
#   (35678, 31335),
#   (44795, 41927),
#   (132666, 88654),
#   (54598, 21108),
#   (8621, 1991),
#   (115767, 25424),
#   (57042, 28496),
#   (169116, 28289),
#   (1099, 6372),
#   (82182, 62921),
#   (217734, 95967),
#   (52206, 11893),
#   (137642, 8635),
#   (142243, 74436),
#   (75602, 8642),
#   (272716, 36864),
#   (153902, 11345),
#   (44190, 4333),
#   (34568, 15964),
#   (7956, 7520),
#   (186278, 5881),
#   (138337, 93695),
#   (35828, 7654),
#   (42225, 5531),
#   (44533, 23727),
#   (217664, 95765),
#   (90912, 1380),
#   (129537, 87200),
#   (69703, 20098),
#   (45100, 22469),
#   (229765, 62195),
#   (35760, 45616),
#   (8626, 6645),
#   (164734, 74262),
#   (130152, 88091),
#   (253038, 102976),
#   (34427, 19483),
#   (135904, 58636),
#   (5032, 1262),
#   (3234, 9695),
#   (71705, 67145),
#   (4764, 12312),
#   (50775, 7114),
#   (3481, 12702),
#   (5614, 6654),
#   (163517, 6938),
#   (39432, 51632),
#   (37805, 18072),
#   (1106, 516),
#   (34736, 62001),
#   (42691, 37889),
#   (47113, 83512),
#   (53269, 11616),
#   (67769, 60678),
#   (46726, 30462),
#   (43080, 8636),
#   (139948, 98086),
#   (56664, 26405),
#   (44344, 30650),
#   (54105, 9036),
#   (7270, 23645),
#   (40477, 7780),
#   (39438, 66059),
#   (132364, 94321),
#   (132280, 46863),
#   (45902, 5768),
#   (3107, 12384),
#   (4147, 9005),
#   (271096, 58641),
#   (6753, 23554),
#   (4885, 12402),
#   (121609, 6552),
#   (127982, 93698),
#   (67638, 57765),
#   (9479, 25732),
#   (142816, 87768),
#   (167242, 11986),
#   (114448, 48859),
#   (31350, 50688),
#   (211123, 88854),
#   (265027, 8655),
#   (141786, 58503),
#   (135588, 21063),
#   (132637, 82526),
#   (37000, 33762),
#   (41935, 68942),
#   (203135, 12854),
#   (54509, 7710),
#   (36919, 52736),
#   (304704, 8635),
#   (182585, 4334),
#   (198923, 34190),
#   (55554, 46777),
#   (8556, 6638),
#   (130737, 59157),
#   (134878, 100769),
#   (8465, 6654),
#   (34245, 9304),
#   (2393, 2012),
#   (135074, 86497),
#   (132445, 58420),
#   (37250, 62617),
#   (28829, 57707),
#   (43478, 8364),
#   (42417, 6907),
#   (43857, 18558),
#   (229544, 18487),
#   (36723, 63546),
#   (220564, 59395),
#   (3481, 14181),
#   (206814, 59198),
#   (85358, 2562),
#   (37873, 26270),
#   (6252, 6723),
#   (44513, 22697),
#   (5608, 10388),
#   (37597, 20075),
#   (134826, 80341),
#   (4222, 9809),
#   (7037, 5927),
#   (78053, 1462),
#   (80300, 82564),
#   (68286, 2555),
#   (135168, 17014),
#   (20409, 18515),
#   (39357, 31046),
#   (40082, 26503),
#   (302147, 90254),
#   (34408, 61506),
#   (135061, 80281),
#   (1095, 1064),
#   (53269, 11301),
#   (190019, 48163),
#   (119116, 9510),
#   (69558, 92185),
#   (140234, 52692),
#   (39432, 51602),
#   (73176, 2460),
#   (44202, 26078),
#   (5678, 9800),
#   (277441, 18210),
#   (71581, 8571),
#   (181167, 24000),
#   (4589, 14352),
#   (135220, 100680),
#   (184698, 50013),
#   (50179, 2660),
#   (47574, 31606),
#   (79351, 8601),
#   (134961, 87942),
#   (149485, 11477),
#   (177536, 15064),
#   (134055, 94626),
#   (10697, 28894),
#   (82110, 8992),
#   (205147, 16670),
#   (72680, 67496),
#   (23461, 26478),
#   (133771, 8638),
#   (74245, 19930),
#   (129935, 80326),
#   (8272, 2080),
#   (65061, 53119),
#   (122184, 51821),
#   (45047, 8629),
#   (102706, 54355),
#   (86791, 8050),
#   (130302, 82421),
#   (77123, 6868),
#   (75985, 56610),
#   (3942, 4382),
#   (134873, 81912),
#   (78666, 52984),
#   (259686, 19962),
#   (133940, 58096),
#   (301151, 6868),
#   (48751, 6831),
#   (79675, 16333),
#   (179902, 88590),
#   (34466, 48427),
#   (51515, 3288),
#   (39670, 24242),
#   (36919, 59207),
#   (139611, 7437),
#   (127366, 18558),
#   (129211, 16327),
#   (51627, 11813),
#   (10899, 29001),
#   (1982, 3606),
#   (73400, 70635),
#   (103117, 12335),
#   (169765, 18189),
#   (47394, 40524),
#   (10727, 29101),
#   (5374, 8636),
#   (88652, 50227),
#   (218798, 86301),
#   (35174, 19929),
#   (3397, 10838),
#   (2481, 1597),
#   (127782, 2151),
#   (4848, 2265),
#   (141992, 59131),
#   (227110, 98447),
#   (138204, 101362),
#   (76161, 19232),
#   (3122, 11753),
#   (5901, 87677),
#   (34354, 19218),
#   (37805, 4614),
#   (35799, 66801),
#   (12877, 19239),
#   (175042, 27143),
#   (134732, 58439),
#   (36245, 1380),
#   (858, 2710),
#   (111182, 13949),
#   (35033, 26571),
#   (71358, 61049),
#   (131326, 21233),
#   (112953, 9041),
#   (271712, 28099),
#   (231938, 4169),
#   (36532, 71562),
#   (132429, 88905),
#   (192651, 721),
#   (40477, 3985),
#   (9431, 61171),
#   (238203, 43745),
#   (149462, 3091),
#   (134732, 58315),
#   (48535, 27926),
#   (179897, 6289),
#   (73518, 8019),
#   (135426, 76498),
#   (33913, 61392),
#   (129530, 25521),
#   (37663, 50591),
#   (27369, 14463),
#   (808, 2354),
#   (50230, 89338),
#   (8162, 8076),
#   (58458, 19144),
#   (77164, 8045),
#   (41421, 26078),
#   (296230, 2612),
#   (82035, 4384),
#   (48635, 1517),
#   (189404, 41043),
#   (38046, 26825),
#   (8621, 13444),
#   (72209, 10004),
#   (134288, 77329),
#   (33675, 48699),
#   (137682, 77398),
#   (35722, 7556),
#   (137840, 58103),
#   (81494, 61732),
#   (133208, 87935),
#   (38068, 23017),
#   (138841, 91838),
#   (140423, 20841),
#   (137247, 29662),
#   (195092, 82423),
#   (40378, 7262),
#   (185554, 81055),
#   (265850, 7914),
#   (200932, 23106),
#   (9379, 52884),
#   (36945, 37665),
#   (7936, 24204),
#   (47392, 7787),
#   (153491, 13417),
#   (37101, 19504),
#   (140749, 20266),
#   (178136, 57146),
#   (3889, 12810),
#   (120210, 5631),
#   (71437, 116082),
#   (140602, 87425),
#   (35279, 6908),
#   (43391, 7301),
#   (229298, 89662),
#   (70651, 8551),
#   (1566, 574),
#   (11553, 8846),
#   (77515, 6800),
#   (38285, 10219),
#   (43765, 6582),
#   (128654, 83372),
#   (38027, 6621),
#   (45888, 39107),
#   (210366, 23324),
#   (44309, 3889),
#   (139096, 78369),
#   (141056, 47593),
#   (5091, 9605),
#   (1326, 6270),
#   (12053, 13507),
#   (137243, 105273),
#   (41152, 41109),
#   (46725, 66623),
#   (138120, 59345),
#   (41198, 16145),
#   (145734, 27204),
#   (257239, 88831),
#   (182223, 41493),
#   (100155, 49989),
#   (46818, 57974),
#   (142329, 102939),
#   (1418, 2384),
#   (36157, 14778),
#   (70654, 48715),
#   (73773, 80533),
#   (133495, 91088),
#   (129424, 90966),
#   (35272, 8266),
#   (283834, 6297),
#   (1348, 947),
#   (135174, 88098),
#   (135282, 8257),
#   (2917, 19989),
#   (135272, 58550),
#   (134826, 77825),
#   (8257, 6945),
#   (20933, 16208),
#   (1645, 1541),
#   (68069, 114398),
#   (44181, 61676),
#   (39896, 70481),
#   (109877, 7935),
#   (143192, 91487),
#   (5887, 11821),
#   (35388, 68664),
#   (1366, 851),
#   (39941, 8381),
#   (37236, 64748),
#   (39024, 4276),
#   (34674, 7563),
#   (141854, 58171),
#   (67435, 1085),
#   (221185, 84764),
#   (134960, 79798),
#   (89780, 6991),
#   (4550, 1331),
#   (153196, 96208),
#   (138595, 85254),
#   (72258, 6247),
#   (152805, 7005),
#   (7728, 3459),
#   (41564, 56221),
#   (137689, 58576),
#   (2097, 2255),
#   (47393, 34699),
#   (37236, 18468),
#   (241292, 100105),
#   (73540, 4778),
#   (40353, 53909),
#   (104038, 23956),
#   (1770, 781),
#   (47859, 20161),
#   (43381, 6794),
#   (31350, 45599),
#   (187326, 19530),
#   (36388, 22216),
#   (6162, 10697),
#   (46182, 7401),
#   (232065, 64972),
#   (37322, 67615),
#   (78666, 8075),
#   (2401, 896),
#   (69644, 4345),
#   (96366, 19144),
#   (590, 1400),
#   (139210, 92852),
#   (45522, 9289),
#   (132009, 20100),
#   (158216, 77329),
#   (10918, 8518),
#   (82654, 2031),
#   (134606, 78094),
#   (11162, 29237),
#   (39918, 28778),
#   (257399, 82303),
#   (34946, 1457),
#   (45899, 60779),
#   (37895, 9504),
#   (55091, 29059),
#   (12347, 41102),
#   (133738, 26096),
#   (156163, 2717),
#   (212922, 45284),
#   (21279, 10096),
#   (38153, 4614),
#   (119006, 18054),
#   (42322, 3979),
#   (128654, 82224),
#   (45574, 8486),
#   (41174, 8310),
#   (135866, 75262),
#   (31350, 19216),
#   (170319, 53083),
#   (68275, 64107),
#   (2968, 10055),
#   (41327, 52279),
#   (45399, 60821),
#   (34687, 62430),
#   (42332, 19623),
#   (163901, 6360),
#   (193785, 12708),
#   (161529, 20278),
#   (53449, 24247),
#   (129424, 91073),
#   (116159, 66576),
#   (252535, 29662),
#   (244511, 26106),
#   (138204, 102618),
#   (39722, 16584),
#   (142180, 58769),
#   (129822, 73418),
#   (112794, 8379),
#   (134890, 79502),
#   (99472, 64814),
#   (50219, 9772),
#   (168450, 21096),
#   (65123, 19380),
#   (35923, 7262),
#   (89684, 6343),
#   (110159, 7297),
#   (44862, 48474),
#   (140749, 90813),
#   (100567, 45367),
#   (93312, 5705),
#   (35879, 19216),
#   (2639, 3713),
#   (135390, 96665),
#   (37322, 19539),
#   (259686, 25780),
#   (134230, 58285),
#   (67638, 60539),
#   (140302, 91922),
#   (3729, 5470),
#   (130523, 93100),
#   (111770, 8371),
#   (1779, 2785),
#   (8465, 3519),
#   (39722, 9543),
#   (75277, 46716),
#   (36532, 69632),
#   (34958, 48969),
#   (33927, 6184),
#   (16148, 62475),
#   (19052, 51969),
#   (134153, 53323),
#   (285067, 1305),
#   (151486, 105037),
#   (72031, 6240),
#   (37663, 26478),
#   (155274, 110158),
#   (133727, 89306),
#   (37592, 52891),
#   (109278, 1496),
#   (4668, 17539),
#   (38205, 36506),
#   (3041, 76383),
#   (35675, 62114),
#   (3239, 10750),
#   (5091, 10315),
#   (6008, 9980),
#   (131568, 88550),
#   (97759, 4275),
#   (140608, 47509),
#   (42374, 53256),
#   (40477, 33769),
#   (75602, 18251),
#   (4058, 11652),
#   (89883, 66313),
#   (983, 419),
#   (50452, 12213),
#   (39834, 109265),
#   (10298, 3008),
#   (70865, 72636),
#   (136891, 100794),
#   (187480, 23894),
#   (186992, 2974),
#   (141074, 91639),
#   (68155, 61334),
#   (198336, 8581),
#   (35893, 9582),
#   (102207, 19058),
#   (68070, 48859),
#   (35587, 63562),
#   (72275, 24500),
#   (133695, 58371),
#   (69558, 58227),
#   (221199, 89827),
#   (69897, 7338),
#   (158377, 15767),
#   (10542, 8570),
#   (4858, 4325),
#   (46594, 63389),
#   (39699, 8260),
#   (39063, 6283),
#   (56688, 26938),
#   (143770, 94832),
#   (4140, 10888),
#   (135272, 58529),
#   (40506, 36296),
#   (35678, 61803),
#   (34051, 20400),
#   (48459, 61289),
#   (51885, 14404),
#   (115184, 57466),
#   (4813, 11871),
# ...
#   (73934, 1496),
#   (4097, 10085),
#   (40371, 7004),
#   (132226, 89504),
#   (86367, 82066),
#   (110, 4743),
#   (79975, 48680),
#   (41155, 9295),
#   (36498, 53327),
#   (4839, 1772),
#   (389, 1945),
#   (38842, 28166),
#   (218299, 59248),
#   (104122, 9761),
#   (132257, 96271),
#   (39699, 19438),
#   (131506, 95165),
#   (117917, 1445),
#   (136439, 3634),
#   (38690, 53094),
#   (785, 2368),
#   (41503, 7392),
#   (145335, 10209),
#   (34597, 71942),
#   (180335, 16334),
#   (136173, 58846),
#   (41610, 7287),
#   (133947, 92437),
#   (53035, 26034),
#   (42823, 64211),
#   (119262, 11159),
#   (227802, 18107),
#   (134522, 90241),
#   (43605, 58724),
#   (204571, 47847),
#   (83013, 37287),
#   (14783, 6800),
#   (10772, 29911),
#   (3522, 14411),
#   (80535, 19866),
#   (139365, 74026),
#   (38842, 66889),
#   (138162, 7437),
#   (151401, 8617),
#   (88778, 34024),
#   (1374, 1641),
#   (136440, 75669),
#   (151495, 18873),
#   (136649, 89702),
#   (6758, 7374),
#   (133603, 25766),
#   (77090, 46228),
#   (133875, 92852),
#   (177233, 16667),
#   (37126, 60100),
#   (131067, 86451),
#   (131120, 89306),
#   (3434, 75112),
#   (54134, 52945),
#   (37433, 8732),
#   (35799, 26550),
#   (1401, 1128),
#   (41355, 16173),
#   (138642, 83522),
#   (104373, 27648),
#   (265145, 90597),
#   (833, 245),
#   (50724, 609),
#   (4774, 109969),
#   (71948, 20021),
#   (35110, 61865),
#   (54786, 2092),
#   (233581, 7003),
#   (76361, 36547),
#   (4253, 10242),
#   (136006, 104891),
#   (138438, 100142),
#   (10460, 29569),
#   (3806, 120850),
#   (151790, 95933),
#   (3665, 9272),
#   (35666, 3357),
#   (187003, 78608),
#   (34674, 6285),
#   (35891, 10204),
#   (85236, 2319),
#   (185087, 14463),
#   (38466, 67734),
#   (1181, 1957),
#   (135856, 20563),
#   (140621, 58399),
#   (219916, 24001),
#   (131592, 88549),
#   (269188, 48976),
#   (93462, 19878),
#   (92075, 8910),
#   (133674, 77392),
#   (2393, 868),
#   (44414, 29623),
#   (38931, 52995),
#   (69675, 20837),
#   (45291, 9562),
#   (211383, 58214),
#   (11357, 13533),
#   (136157, 89121),
#   (137642, 2970),
#   (140288, 85003),
#   (37285, 27391),
#   (37613, 17071),
#   (7840, 7282),
#   (122184, 64976),
#   (7038, 17531),
#   (35516, 63662),
#   (35655, 46880),
#   (74104, 4778),
#   (34608, 29660),
#   (77908, 34580),
#   (224414, 94374),
#   (176576, 8588),
#   (141225, 93545),
#   (142505, 21793),
#   (9734, 1499),
#   (164501, 9188),
#   (76154, 64525),
#   (134910, 80063),
#   (44533, 3284),
#   (461, 1982),
#   (161076, 87907),
#   (125268, 6635),
#   (54941, 7617),
#   (167326, 13043),
#   (6686, 6019),
#   (147956, 90867),
#   (46818, 18757),
#   (135541, 76517),
#   (67476, 88664),
#   (133240, 59248),
#   (104113, 28786),
#   (4029, 12752),
#   (4550, 11250),
#   (278504, 2634),
#   (45760, 2042),
#   (134851, 98232),
#   (124113, 10176),
#   (43977, 19244),
#   (98898, 3797),
#   (36524, 62330),
#   (258067, 16132),
#   (192765, 9654),
#   (35596, 62114),
#   (38728, 7389),
#   (12550, 27564),
#   (858, 2007),
#   (39129, 65775),
#   (3750, 11686),
#   (200514, 25671),
#   (135099, 58462),
#   (72305, 68513),
#   (41257, 71280),
#   (52995, 21529),
#   (34305, 61182),
#   (201059, 25376),
#   (77306, 65536),
#   (37260, 26879),
#   (138642, 82087),
#   (75793, 72109),
#   (2027, 4964),
#   (38495, 32638),
#   (87141, 52754),
#   (50924, 1008),
#   (68275, 62215),
#   (6252, 10715),
#   (55396, 29699),
#   (41253, 7923),
#   (137453, 52964),
#   (173843, 70487),
#   (35401, 48201),
#   (249646, 95590),
#   (140098, 85975),
#   (288119, 77238),
#   (38285, 56801),
#   (136746, 16217),
#   (70778, 7780),
#   (195376, 20790),
#   (11250, 14418),
#   (133240, 80281),
#   (7274, 20702),
#   (4121, 10600),
#   (131442, 2613),
#   (10697, 76912),
#   (102706, 36838),
#   (43659, 67441),
#   (39893, 6738),
#   (4070, 10231),
#   (77430, 53038),
#   (60482, 8019),
#   (91269, 20966),
#   (250749, 19293),
#   (170199, 58133),
#   (258345, 98574),
#   (129803, 89622),
#   (138972, 83209),
#   (218970, 2368),
#   (136205, 99900),
#   (32996, 71085),
#   (38876, 43802),
#   (55937, 25823),
#   (69282, 40937),
#   (36917, 58286),
#   (94083, 21660),
#   (41198, 37329),
#   (133726, 77203),
#   (40717, 67958),
#   (124316, 8486),
#   (34897, 6297),
#   (122578, 256),
#   (34681, 24993),
#   (116015, 8189),
#   (7456, 8192),
#   (136399, 58473),
#   (6675, 11637),
#   (135163, 88997),
#   (40371, 19218),
#   (280295, 28814),
#   (148880, 777),
#   (217290, 2337),
#   (11465, 13565),
#   (132329, 95588),
#   (134288, 96639),
#   (6406, 11886),
#   (71620, 48216),
#   (36063, 6556),
#   (10997, 28702),
#   (135710, 17000),
#   (6277, 11467),
#   (1499, 579),
#   (45152, 10038),
#   (141906, 83905),
#   (4846, 12965),
#   (110658, 53531),
#   (39129, 50221),
#   (135611, 19446),
#   (99949, 32624),
#   (92627, 10205),
#   (42526, 6360),
#   (43659, 18743),
#   (185738, 52973),
#   (53208, 7817),
#   (135519, 58741),
#   (416, 571),
#   (8921, 23135),
#   (131711, 101292),
#   (37033, 47482),
#   (39057, 6290),
#   (271903, 62476),
#   (43605, 52959),
#   (5940, 11808),
#   (138015, 6149),
#   (70428, 61915),
#   (89279, 7209),
#   (34144, 43442),
#   (48615, 62295),
#   (285096, 60478),
#   (31350, 68268),
#   (133793, 97841),
#   (236702, 61637),
#   (136746, 86490),
#   (185554, 77329),
#   (81386, 8315),
#   (186586, 57150),
#   (74104, 34431),
#   (53045, 11608),
#   (9976, 25820),
#   (45047, 32348),
#   (3994, 16441),
#   (36124, 80957),
#   (88778, 37324),
#   (5695, 9665),
#   (2751, 11903),
#   (43391, 20151),
#   (132009, 87393),
#   (135153, 77692),
#   (181541, 34804),
#   (6933, 6335),
#   (39669, 9914),
#   (47731, 9630),
#   (44058, 61393),
#   (43251, 9969),
#   (36532, 19167),
#   (69000, 52448),
#   (87536, 675),
#   (79589, 2916),
#   (163062, 1573),
#   (43960, 9492),
#   (133975, 91809),
#   (78666, 18189),
#   (714, 2481),
#   (40477, 8072),
#   (215826, 43830),
#   (36001, 1360),
#   (153928, 41441),
#   (38870, 43066),
#   (34869, 50404),
#   (78206, 6664),
#   (40450, 73099),
#   (211680, 2357),
#   (35144, 19902),
#   (137828, 15096),
#   (165516, 7327),
#   (2726, 36866),
#   (43168, 26870),
#   (43391, 9295),
#   (4846, 15986),
#   (3884, 8470),
#   (54294, 24711),
#   (6724, 11886),
#   (37205, 8058),
#   (39547, 45777),
#   (44817, 61732),
#   (95150, 62947),
#   (74210, 65418),
#   (3565, 12585),
#   (4172, 10761),
#   (7211, 2080),
#   (35049, 18358),
#   (45760, 57828),
#   (89793, 5531),
#   (3146, 9439),
#   (38785, 53327),
#   (41351, 44203),
#   (4589, 8306),
#   (218299, 77026),
#   (191365, 46999),
#   (35997, 48906),
#   (200405, 24867),
#   (51265, 10911),
#   (129862, 87638),
#   (137704, 84996),
#   (140538, 97359),
#   (84079, 63051),
#   (34927, 6591),
#   (233065, 93869),
#   (73176, 6960),
#   (130201, 76652),
#   (36035, 7306),
#   (4210, 10388),
#   (34137, 6861),
#   (41155, 36784),
#   (134740, 107588),
#   (186344, 20355),
#   (82004, 62322),
#   (140006, 85963),
#   (79587, 65112),
#   (11746, 17265),
#   (40378, 18455),
#   (218512, 9700),
#   (36794, 44104),
#   (187800, 9543),
#   (141223, 78627),
#   (8226, 24524),
#   (270068, 64666),
#   (71948, 67216),
#   (136281, 87006),
#   (34825, 64126),
#   (65123, 1012),
#   (133695, 76846),
#   (81319, 18473),
#   (131268, 83343),
#   (137173, 80341),
#   (138158, 97936),
#   (135607, 58340),
#   (129286, 14675),
#   (4126, 1215),
#   (236326, 8009),
#   (5940, 10485),
#   (69689, 45645),
#   (35778, 18452),
#   (4262, 9439),
#   (39591, 69247),
#   (115545, 33323),
#   (129570, 18072),
#   (16148, 54547),
#   (4222, 17232),
#   (264179, 65632),
#   (142461, 26117),
#   (20018, 6769),
#   (103186, 8684),
#   (140749, 98107),
#   (136891, 85950),
#   (4105, 14468),
#   (34597, 34580),
#   (9532, 24064),
#   (34427, 10386),
#   (77908, 16486),
#   (212928, 20305),
#   (7203, 15746),
#   (88982, 52355),
#   (185014, 82456),
#   (45503, 4283),
#   (136925, 71852),
#   (222310, 5518),
#   (42430, 26506),
#   (55554, 77300),
#   (134113, 104325),
#   (135541, 100114),
#   (78135, 23918),
#   (48309, 7966),
#   (38239, 51576),
#   (4375, 75008),
#   (158988, 9987),
#   (44344, 62169),
#   (37565, 63402),
#   (4119, 15038),
#   (130193, 73603),
#   (209026, 56257),
#   (164498, 15400),
#   (52128, 11633),
#   (41058, 52630),
#   (231871, 25786),
#   (75119, 46115),
#   (242839, 7752),
#   (51147, 9013),
#   (45933, 6904),
#   (40197, 64334),
#   (54134, 82193),
#   (40450, 17907),
#   (135309, 96717),
#   (134524, 25056),
#   (135533, 96678),
#   (68803, 62195),
#   (50860, 10230),
#   (3006, 10022),
#   (40105, 63575),
#   (84656, 10626),
#   (98931, 7948),
#   (235081, 46847),
#   (54900, 27490),
#   (85697, 2229),
#   (105272, 7012),
#   (136343, 83890),
#   (42572, 19654),
#   (252830, 24242),
#   (239995, 27716),
#   (99627, 19368),
#   (6162, 11570),
#   (51592, 9650),
#   (135399, 16463),
#   (119525, 3678),
#   (858, 798),
#   (21440, 26804),
#   (48974, 20523),
#   (71122, 36513),
#   (151495, 60779),
#   (87472, 2265),
#   (132329, 87648),
#   (35279, 36947),
#   (7211, 3959),
#   (7270, 24455),
#   (69027, 53025),
#   (51678, 13522),
#   (57637, 13422),
#   (7018, 7688),
#   (34354, 8865),
#   (291893, 9511),
#   (137506, 21242),
#   (1055, 622),
#   (11390, 11857),
#   (112037, 59236),
#   (189922, 81217),
#   (36816, 60777),
#   (134153, 46954),
#   (111654, 44541),
#   (3772, 9335),
#   (69000, 48859),
#   (44118, 1444),
#   (146987, 423),
#   (251374, 87793),
#   (120942, 19167),
#   (141302, 83300),
#   (168031, 11053),
#   (12347, 8260),
#   (5110, 11166),
#   (38687, 7201),
#   (49747, 777),
#   (177918, 67146),
#   (90730, 10205),
#   (35806, 54368),
#   (37205, 26106),
#   (81998, 51833),
#   (56102, 28857),
#   (133558, 90402),
#   (178308, 74935),
#   (35875, 9543),
#   (136974, 8635),
#   (34958, 32401),
#   (255501, 58150),
#   (116109, 30437),
#   (144528, 85265),
#   (34189, 54938),
#   (86013, 19539),
#   (34077, 8725),
#   (38350, 8704),
#   (29033, 1440),
#   (43991, 61245),
#   (283096, 2785),
#   (140126, 25574),
#   (218491, 62509),
#   (36971, 8839),
#   (137506, 85828),
#   (35401, 8161),
#   (94985, 43314),
#   (133771, 92702),
#   (134319, 47452),
#   (7654, 1803),
#   (2656, 595),
#   (65123, 56290),
#   (36742, 20348),
#   (41050, 6918),
#   (153617, 7004),
#   (39931, 17309),
#   (137427, 90275),
#   (69703, 54403),
#   (50080, 5040),
#   (2713, 2063),
#   (35875, 63474),
#   (69027, 52356),
#   (9817, 109187),
#   (135208, 6865),
#   (20665, 16187),
#   (35226, 48729),
#   (41638, 23755),
#   (9379, 63250),
#   (1056, 2803),
#   (75744, 19750),
#   (128808, 5899),
#   (134714, 26032),
#   (135426, 91402),
#   (134917, 74105),
#   (37047, 37665),
#   (169044, 729),
#   (4682, 5440),
#   (71146, 118222),
#   (41996, 3687),
#   (88667, 45961),
#   (118795, 27330),
#   (184789, 5848),
#   (35144, 26914),
#   (43091, 23748),
#   (81118, 26597),
#   (3218, 9601),
#   (149926, 14581),
#   (151825, 2196),
#   (303288, 91043),
#   (40099, 35791),
#   (137352, 95453),
#   (111050, 50117),
#   (256, 2),
#   (6841, 18061),
#   (37836, 8072),
#   (89825, 19577),
#   (82498, 13772),
#   (82571, 33844),
#   (34044, 62026),
#   (186108, 6784),
#   (46516, 27564),
#   (37047, 1085),
#   (36138, 52714),
#   (214210, 63580),
#   (36795, 8960),
#   (34897, 62427),
#   (40879, 6904),
#   (47293, 74279),
#   (130414, 83883),
#   (69872, 19342),
#   (147875, 2483),
#   (247850, 14128),
#   (46290, 51221),
#   (4011, 13522),
#   (214210, 6240),
#   (4764, 10697),
#   (37179, 5531),
#   (12550, 7569),
#   (3760, 9),
#   (166097, 7698),
#   (40905, 70482),
#   (122696, 6582),
#   (35902, 43379),
#   (177951, 17789),
#   (38845, 42098),
#   (82425, 62653),
#   (9425, 5399),
#   (77962, 19459),
#   (78216, 2536),
#   (67450, 18508),
#   (136911, 79350),
#   (270068, 19861),
#   (26232, 18483),
#   (131073, 71531),
#   (2916, 37),
#   (36204, 66067),
#   (130986, 19530),
#   (138283, 100374),
#   (37033, 19774),
#   (35766, 10190),
#   (50091, 37352),
#   (295, 3554),
#   (38719, 52474),
#   (137828, 103602),
#   (36689, 41214),
#   (99915, 24507),
#   (136647, 58846),
#   (85729, 11710),
#   (134710, 100951),
#   (135111, 8658),
#   (113561, 18978),
#   (276345, 20491),
#   (259808, 104460),
#   (10730, 19386),
#   (11350, 13677),
#   (34403, 63507),
#   (203651, 25202),
#   (9204, 26316),
#   (40905, 9303),
#   (81715, 27592),
#   (139072, 89119),
#   (34953, 6727),
#   (260136, 12370),
#   (158754, 88077),
#   (34900, 50427),
#   (80893, 58907),
#   (129635, 59275),
#   (20114, 3001),
#   (8272, 6116),
#   (71464, 40972),
#   (218908, 46341),
#   (132558, 89899),
#   (46576, 67144),
#   (200922, 83056),
#   (37276, 13921),
#   (86886, 5516),
#   (11583, 9421),
#   (87949, 20454),
#   (35885, 9304),
#   (45997, 4384),
#   (36054, 6938),
#   (191040, 2230),
#   (133516, 84541),
#   (134255, 91639),
#   (9552, 2399),
#   (140851, 95152),
#   (133377, 21425),
#   (37209, 52863),
#   (8533, 4173),
#   (185206, 53060),
#   (5975, 9642),
#   (68787, 6942),
#   (42373, 7406),
#   (129211, 82936),
#   (185915, 101174),
#   (2968, 15248),
#   (69648, 26889),
#   (88945, 21203),
#   (87472, 65687),
#   (136767, 76648),
#   (134960, 86187),
#   (33874, 43150),
#   (99019, 113292),
#   (136746, 85230),
#   (37904, 48662),
#   (140355, 57991),
#   (210195, 58676),
#   (270052, 90145),
#   (12877, 57752),
#   (116015, 58777),
#   (141313, 32707),
#   (256, 1811),
#   (75602, 7124),
#   (5628, 19322),
#   (212, 36),
#   (69641, 56257),
#   (46816, 9582),
#   (103387, 109969),
#   (34366, 63778),
#   (37100, 9309),
#   (283407, 45356),
#   (43786, 8358),
#   (1472, 3928),
#   (184546, 61098),
#   (43222, 18151),
#   (44181, 19519),
#   (67901, 2555),
#   (40717, 52861),
#   (37276, 36368),
#   (38711, 7283),
#   (86367, 8614),
#   (197213, 81235),
#   (8883, 25566),
#   (87282, 3687),
#   (57042, 9294),
#   (165875, 85909),
#   (54938, 322),
#   (44955, 34026),
#   (47473, 67699),
#   (77338, 5231),
#   (12406, 62904),
#   (21931, 58638),
#   (9288, 2014),
#   (132413, 95450),
#   (45368, 19167),
#   (3989, 58861),
#   (140747, 83003),
#   (3355, 10279),
#   (46392, 71193),
#   (83655, 5317),
#   (295840, 9939),
#   (42945, 37665),
#   (30631, 25477),
#   (98156, 62974),
#   (71190, 19107),
#   (10821, 28880),
#   (43447, 21186),
#   (79931, 62216),
#   (132028, 76979),
#   (129004, 88506),
#   (95262, 48403),
#   (80469, 7719),
#   (135117, 58486),
#   (50790, 11124),
#   (235669, 18421),
#   (200405, 18124),
#   (37487, 4614),
#   (36247, 60684),
#   (249837, 59318),
#   (38039, 21203),
#   (96744, 9766),
#   (38406, 26120),
#   (36917, 34580),
#   (143170, 58495),
#   (242314, 37049),
#   (141633, 77324),
#   (139112, 83496),
#   (48201, 74158),
#   (179952, 52605),
#   (42858, 10205),
#   (35014, 9541),
#   (137855, 5881),
#   (10820, 27980),
#   (255875, 27168),
#   (20409, 52112),
#   (14754, 49125),
#   (86492, 97408),
#   (45757, 32338),
#   (140688, 98584),
#   (139974, 26347),
#   (163455, 52475),
#   (238307, 52448),
#   (4682, 2594),
#   (42788, 20355),
#   (10467, 83864),
#   (5088, 10626),
#   (36016, 64586),
#   (34312, 60874),
#   (47751, 81219),
#   (3597, 6221),
#   (142017, 71531),
#   (65061, 20109),
#   (77489, 18468),
#   (186223, 19735),
#   (47751, 15064),
#   (129752, 84168),
#   (34051, 18232),
#   (12877, 7619),
#   (130402, 7019),
#   (70208, 6684),
#   (53416, 11036),
#   (1696, 3594),
#   (187800, 7994),
#   (192588, 79245),
#   (45438, 1431),
#   (134710, 52716),
#   (146223, 87926),
#   (8362, 23129),
#   (48790, 52531),
#   (8445, 44102),
#   (4992, 11601),
#   (3275, 26353),
#   (34210, 8216),
#   (55064, 2021),
#   (121, 805),
#   (79386, 33762),
#   (40318, 61474),
#   (84515, 6582),
#   (141526, 92616),
#   (34371, 19774),
#   (135953, 97471),
#   (200477, 91693),
#   (87419, 41927),
#   (20884, 8364),
#   (21430, 66409),
#   (4375, 12417),
#   (147956, 92640),
#   (136266, 8617),
#   (130732, 16615),
#   (45888, 19770),
#   (38158, 20313),
#   (132080, 8430),
#   (11465, 13484),
#   (42915, 27412),
#   (193494, 67667),
#   (154393, 64475),
#   (54284, 1528),
#   (20409, 44984),
#   (141438, 76485),
#   (42572, 6670),
#   (53353, 15234),
#   (55554, 75164),
#   (2027, 6459),
#   (39175, 65766),
#   (3274, 14851),
#   (72659, 19428),
#   (140910, 78160),
#   (91248, 3284),
#   (272716, 49329),
#   (3760, 12646),
#   (112007, 6684),
#   (154169, 15899),
#   (2929, 2354),
#   (139216, 14921),
#   (5633, 10099),
#   (39425, 21044),
#   (37236, 7089),
#   (129533, 90264),
#   (41077, 23918),
#   (44929, 69513),
#   (33892, 1320),
#   (131188, 2192),
#   (266945, 69223),
#   (11980, 87916),
#   (232065, 52166),
#   (129124, 87056),
#   (111304, 52925),
#   (221199, 76453),
#   (73070, 7569),
#   (85362, 17362),
#   (212928, 89299),
#   (199816, 4871),
#   (42855, 3896),
#   (38463, 46757),
#   (18296, 19908),
#   (159989, 102410),
#   (3997, 13979),
#   (212721, 46002),
#   (34568, 61001),
#   (132329, 75906),
#   (178136, 57392),
#   (134721, 95005)],
#  [(79724, 16659),
#   (282682, 19179),
#   (47952, 19789),
#   (219935, 2944),
#   (139410, 92871),
#   (3870, 14593),
#   (135474, 19932),
#   (80416, 7392),
#   (142243, 95455),
#   (118838, 92390),
#   (90974, 19380),
#   (222852, 11005),
#   (46214, 31293),
#   (247006, 89664),
#   (20409, 19779),
#   (4483, 10287),
#   (82260, 64833),
#   (170120, 17334),
#   (283096, 345),
#   (46639, 1380),
#   (130834, 16684),
#   (34965, 1126),
#   (159754, 33524),
#   (218696, 70649),
#   (127571, 28591),
#   (111989, 19693),
#   (288834, 86565),
#   (139821, 90298),
#   (41155, 24401),
#   (50738, 504),
#   (195036, 9794),
#   (128445, 34699),
#   (44765, 8075),
#   (247076, 8660),
#   (4070, 9853)]]

# %% [markdown]
# # Completed: Get affinity score, *final_scores_rdd*,  for each (user, business) in the yelp_train/val.csv
# Note: but since we use rdd to get affinity score and dealt w/ cold-start,
#
# we may have to re-order rows to align w/ what's in the original csv file at the end if grading script is stupid

# %%
from MF import matrix_factorization_als
start_time = time.time()
data_path = '../data/'  # Update with args[*]

# mapped_scores_rdd, mapped_missing_scores_rdd = matrix_factorization_als(sc, data_path)
final_scores_rdd, user_features_rdd, biz_features_rdd, valid_pairs_rdd, missing_pairs_rdd, reverse_user_ids_bcast, reverse_business_ids_bcast = matrix_factorization_als(sc, data_path)
print("Duration: ", time.time() - start_time)
# Out:
# Duration:  10.706738471984863

# %%
final_scores_rdd.collect()
# Out:
# [(('wf1GqnKQuvH-V3QN80UOOQ', 'fThrN4tfupIGetkrz18JOg'), 0.9736873615973883),
#  (('4frlPHL8mLWW5vG0TOksDA', 'pYUoaak6lIHX_8clvk5Raw'), 0.4135465795319243),
#  (('B8WruADju0mx5FlkLfYYfw', 'dIZcPB3CtNjMn4O_p8QFxw'), 1.0646958338477424),
#  (('sMhvlIPGLUlRA7QsWlqBOg', 'Iadni8K9IgCJe2yB3fpgTw'), 0.223514261721595),
#  (('bJTKxBIvb_AR8d4SuLPV8g', 'oMgDbkk0hlPYFUmwAOVjgQ'), 1.00513904769514),
#  (('54zqyneshZvyWymZLE6mJw', 'zI-CqEm-qmkTY3WdhPlXgQ'), -0.10023661888864299),
#  (('nOr3_aq60yivqgcso_iDMw', '9Fm-OVlt1fXIHcp5QJisuQ'), 0.5310554628701951),
#  (('65yB0ydGXOZ_-T6J_GbKfw', '7U-yh8dvsvhd87i2crfOAw'), 1.0222980267304287),
#  (('1dM27ursYQBTH2NR2ggtSw', 'I6EDDi4-Eq_XlFghcDCUhw'), 0.5429172062589911),
#  (('OVtuIGyUhewxfTl4No9Rwg', 'wiEQrYSNofc10q7Pm26b0w'), 0.11010403381952978),
#  (('JUT0U3HTSB3kz9Wh7N0GqA', 'LqEiVAAXdG734Z0YZMrZdg'), 0.685099236799024),
#  (('vWP8-aQX0rYJszqkWVL7Ew', 'D_24gRsnae7guxJE8gLgtw'), 0.8737581990251614),
#  (('iQ0TzrwN4BgflE8Aozv_IA', '2CkqCWvbV1VoO5aGSvaQRQ'), 0.8394440239629098),
#  (('sDlRFzGHzfpFHaxvJ1JtTg', 'T5nTtSCSRoEYMsZPhF61wg'), 0.2844070546140744),
#  (('S10Q9h_W-MKyog8IdcCNCQ', 'zzUj3ej4vm_DtvRxNvWDEw'), 0.6602417221848527),
#  (('wkSdo0bE6cXGuDR7VpZ9Ww', 'x8UvTkKx9WApRsMxQ3ZPtQ'), 0.7279667145855839),
#  ...]

# %%
count = final_scores_rdd.count()
print("Length of final_scores_rdd:", count)
# Out:
# [Stage 228:============================>                            (2 + 2) / 4]
# Length of final_scores_rdd: 142044

# %%
# 定义一个函数来检查元组中是否存在"Unknown"字符串
def check_unknown(tuple):
    for item in tuple:
        if "Unknown" in item:
            return True
    return False

# 使用filter操作来过滤包含"Unknown"字符串的元组
unknown_tuples = final_scores_rdd.filter(lambda x: check_unknown(x[0]))

# 检查是否有包含"Unknown"字符串的元组
if unknown_tuples.isEmpty():
    print("No tuples contain 'Unknown' strings.")
else:
    print("Tuples containing 'Unknown' strings:", unknown_tuples.collect())
# Out:
# No tuples contain 'Unknown' strings.

# %% [markdown]
# ## process necessary user, bus vectors embedding from the original, also deal w/ missing (cold start)

# %%
# Extract user and business IDs from valid pairs
valid_user_ids = valid_pairs_rdd.map(lambda x: x[0][0]).distinct()
valid_business_ids = valid_pairs_rdd.map(lambda x: x[0][1]).distinct()

# Broadcast these IDs
valid_user_ids_bcast = sc.broadcast(valid_user_ids.collect())
valid_business_ids_bcast = sc.broadcast(valid_business_ids.collect())

# Filter feature RDDs using the valid IDs
valid_user_features_rdd = user_features_rdd.filter(lambda x: x[0] in valid_user_ids_bcast.value)
valid_biz_features_rdd = biz_features_rdd.filter(lambda x: x[0] in valid_business_ids_bcast.value)

default_vector = [0.0] * len(user_features_rdd.first()[1])  # Assuming all vectors have the same length, and assume 0.0 for now
default_vector_bcast = sc.broadcast(default_vector)

# %%
# Separate handling for missing user and business features
missing_user_features_rdd = missing_pairs_rdd.map(lambda x: (x[0][0], default_vector_bcast.value))
missing_biz_features_rdd = missing_pairs_rdd.map(lambda x: (x[0][1], default_vector_bcast.value))

# %%
# # Final merging and handling
# final_user_features_rdd = valid_user_features_rdd.union(missing_user_features_rdd)
# final_biz_features_rdd = valid_biz_features_rdd.union(missing_biz_features_rdd)

# %%
def map_num_to_string_id(features_tuple, reverse_id_bcast):
    """
    Maps a tuple of (numerical_id, features) to (string_id, features) using a broadcasted reverse ID map.
    """
    num_id, features = features_tuple
    str_id = reverse_id_bcast.value.get(num_id, "Unknown")  # Use "Unknown" if no mapping exists
    return (str_id, features)

# Map numerical IDs in valid_user_features_rdd to string IDs
valid_user_features_with_str_ids_rdd = valid_user_features_rdd.map(
    lambda x: map_num_to_string_id(x, reverse_user_ids_bcast))

valid_biz_features_with_str_ids_rdd = valid_biz_features_rdd.map(
    lambda x: map_num_to_string_id(x, reverse_business_ids_bcast))

# Now both RDDs use string IDs, merge them
final_user_features_rdd = valid_user_features_with_str_ids_rdd.union(missing_user_features_rdd)
final_biz_features_rdd = valid_biz_features_with_str_ids_rdd.union(missing_biz_features_rdd)

# %% [markdown]
# # ENCAPSULATED

# %%
from MF import matrix_factorization_als
start_time = time.time()
data_path = '../data/'  # Update with args[*]

# mapped_scores_rdd, mapped_missing_scores_rdd = matrix_factorization_als(sc, data_path)
final_scores_rdd, final_user_features_rdd, final_biz_features_rdd = matrix_factorization_als(sc, data_path)
print("Duration: ", time.time() - start_time)
# Out:
# Duration:  11.22281265258789

# %%
final_scores_rdd.take(5), final_user_features_rdd.take(1)
# Out:
# ([(('wf1GqnKQuvH-V3QN80UOOQ', 'fThrN4tfupIGetkrz18JOg'), 0.8052944470981547),
#   (('39FT2Ui8KUXwmUt6hnwy-g', 'uW6UHfONAmm8QttPkbMewQ'), 0.701897309016126),
#   (('7weuSPSSqYLUFga6IYP4pg', 'IhNASEZ3XnBHmuuVnWdIwA'), 1.0344100346922414),
#   (('yy7shAsNWRbGg-8Y67Dzag', 'rS39YnrhoXmPqHLzCBjeqw'), 0.8211280792885481),
#   (('x-8ZMKKNycT3782Kqf9loA', 'jgtWfJCJZty_Nctqpdtp3g'), 0.7778656058837244)],
#  [('ulQ8Nyj7jCUR8M83SUMoRQ',
#    array('d', [-0.341767817735672, -0.6615524291992188, 1.9749647378921509, -1.9038962125778198, -2.1017773151397705, 1.3063570261001587, 1.71941077709198, -2.796144962310791, -1.369841456413269, 0.5570476055145264]))])

# %%
final_biz_features_rdd.take(1)
# Out:
# [('azE1DNVQFBU8boVbaJhj7w',
#   array('d', [-0.028799572959542274, -0.006738672964274883, 0.05829034745693207, 0.08992240577936172, -0.026271861046552658, 0.10994374006986618, 0.08646126836538315, -0.09953965991735458, -0.05454787611961365, 0.040256477892398834]))]

# %% [markdown]
# ### SANITY ANALYSIS

# %%
# final_user_features_with_strings_rdd.filter(lambda x: x[1] == default_vector).collect()

# %%
default_vector = [0.0] * 10  # Example default vector

def check_for_defaults_and_unknowns(features_rdd, default_vector):
    """
    This function checks for rows with default vectors and "Unknown" IDs.
    It returns the count of rows with default vectors and rows with "Unknown" IDs.
    """
    # Count rows with default vectors
    default_count = features_rdd.filter(lambda x: x[1] == default_vector).count()
    
    # Count rows with "Unknown" IDs
    unknown_count = features_rdd.filter(lambda x: x[0] == "Unknown").count()
    
    return default_count, unknown_count

# Perform the checks for user and business feature RDDs
user_defaults, user_unknowns = check_for_defaults_and_unknowns(final_user_features_rdd, default_vector)
biz_defaults, biz_unknowns = check_for_defaults_and_unknowns(final_biz_features_rdd, default_vector)

# %%
# Print the results
print(f"User Defaults: {user_defaults}, User Unknowns: {user_unknowns}")
print(f"Business Defaults: {biz_defaults}, Business Unknowns: {biz_unknowns}")
# Out:
# User Defaults: 26044, User Unknowns: 0
# Business Defaults: 26044, Business Unknowns: 0

# %% [markdown]
# # CONCLUSION:
#
# - 我们非常高效地利用RDD，通过ALS得到tip.json中的用户和商家的特征向量，用分块矩阵乘法(block matrix multiplication)来计算实际需要考虑的用户和商户之间的亲和力得分。这个亲和力得分可以后续作为特征，让XGBRegressor学习。
#
# - 后续，如果直接使用用户和商家的特征向量作为输入特征，您将引入更多的维度到模型中。这可能会增强模型的预测能力，因为这些特征向量编码了关于用户和商户的重要信息，但同时也可能增加过拟合的风险，特别是在特征维数很高时。
#
# - 仅使用亲和力得分: 亲和力得分本身是一个从特征向量中派生的特征，反映了用户和商户之间的潜在关系。仅使用这一个得分可以减少模型的复杂性，降低过拟合的风险，并可能加快训练速度。
#
#
# ## 理论依据
# - 特征向量中可能包含亲和力得分未能完全捕捉的信息。如果您的场景下，用户的个性化需求和商户的独特属性对预测任务尤为关键，那么提供完整的特征向量可能会有助于模型捕捉到这些复杂的关系。
#
# - 信息覆盖: 特征向量中可能包含亲和力得分未能完全捕捉的信息。如果在现在的场景下，用户的个性化需求和商户的独特属性对预测任务尤为关键，那么提供完整的特征向量可能会有助于模型捕捉到这些复杂的关系。

# %%
# # numpy.core._exceptions._ArrayMemoryError: Unable to allocate 23.0 GiB for an array with shape (25406, 121526) and data type float64
# print("Affinity scores example:", affinity_scores_rdd.take(5))

# %%
# print("Affinity scores example:", affinity_scores_rdd.take(5))
# print("User ID mapping example:", list(user_ids_bcast.value.items())[:5])
# print("Business ID mapping example:", list(business_ids_bcast.value.items())[:5])
# Out:
# Affinity scores example: [((0, 0), -2.214342565985518e-05), ((0, 12), 0.2920612750297914), ((0, 24), 0.20821277066745858), ((0, 36), 0.7875571581378863), ((0, 48), 0.71932584997959)]
# User ID mapping example: [('ulQ8Nyj7jCUR8M83SUMoRQ', 0), ('0l1I3fu22Aec8S5VG6NiqQ', 7), ('rGuevqz7WCka0f4UfkHurQ', 14), ('Xe-Dlatnkz9A9l8oyDgU9Q', 21), ('okOV6LqE3bTy5ZIMVm3VOQ', 28)]
# Business ID mapping example: [('tJRDll5yqpZwehenzE2cSg', 0), ('k7WRPbDd7rztjHcGGkEjlw', 7), ('8qNOI6Q1-rJrvWWD5Btz6w', 14), ('c5NHHW0sNm7eaQBwvQJkkw', 21), ('JzB7NITHQ7gVHGVZ1ntgIQ', 28)]

# %% [markdown]
# # Archived: pre- sores_rdd Processing and Analysis

# %%
from pyspark import SparkContext
import numpy as np

# 计算商户总数
total_business_count = len(business_ids_bcast.value)

# 统计每个用户的得分记录数量
user_scores_count = affinity_scores_rdd.map(lambda x: (x[0][0], 1)).reduceByKey(lambda a, b: a + b)

# 检查每个用户的得分记录是否等于商户总数
consistent_users = user_scores_count.filter(lambda x: x[1] == total_business_count)

# 查看不一致的用户（即得分记录数不等于商户总数的用户）
inconsistent_users = user_scores_count.filter(lambda x: x[1] != total_business_count)

# 打印结果
print("Total business count: ", total_business_count)
print("Consistent users (example):", consistent_users.take(5))
print("Inconsistent users (example):", inconsistent_users.take(5))
# Out:
# Total business count:  121526
# Consistent users (example): [(0, 121526), (1, 121526), (2, 121526), (3, 121526), (4, 121526)]
# Inconsistent users (example): []

# %%
print("Affinity scores example:", affinity_scores_rdd.take(10))
# Out:
# Affinity scores example: [((0, 0), -2.8818499995775303e-05), ((0, 12), 0.2931362566499758), ((0, 24), 0.004529009503575848), ((0, 36), 0.7364946269746667), ((0, 48), 0.9833278893913743), ((0, 60), 0.13164626736620358), ((0, 72), 0.48885588272566216), ((0, 84), 0.12957128602783802), ((0, 96), 0.12957128602783802), ((0, 108), 0.3366717157502644)]

# %%
# Example: Calculate basic statistics for affinity scores
stats = affinity_scores_rdd.map(lambda x: x[1]).stats()
print("Mean score:", stats.mean())
print("Standard deviation:", stats.stdev())
print("Max score:", stats.max())
print("Min score:", stats.min())
# Out:
# [Stage 690:>                                                      (0 + 12) / 12]
# Mean score: 0.013045328180013544
# Standard deviation: 0.13186665950782575
# Max score: 5.212019810222868
# Min score: -3.6185841196981885

# %%
# Example: Recommend Top 3 affnitive businesses for each user
top3_recommendations = affinity_scores_rdd.map(lambda x: (x[0][0], (x[0][1], x[1]))).groupByKey().mapValues(lambda x: sorted(list(x), key=lambda y: y[1], reverse=True)[:3])
print("Top 3 recommendations for 3 users (example):", top3_recommendations.take(3))
# Out:
# Top 3 recommendations for each user (example): [(0, [(4283, 2.243898320028813), (21471, 2.0370684428248973), (9960, 2.0364196777220305)]), (1, [(4778, 7.99976580004422e-05), (3693, 6.048461886035935e-05), (17157, 5.739607357349828e-05)]), (2, [(3654, 0.24115612690854257), (9960, 0.2343048873974668), (26571, 0.21922514224579626)])]

# %%
val_df = pd.read_csv('../yelp_val.csv')
affinity_dict = affinity_scores_rdd.collectAsMap()

# %%
user_to_num_dict = user_ids_bcast.value
biz_to_num_dict = business_ids_bcast.value

num_to_user_dict = {v: k for k, v in user_to_num_dict.items()}
num_to_biz_dict = {v: k for k, v in biz_to_num_dict.items()}

# %%
num_to_user_dict
# Out:
# {0: 'ulQ8Nyj7jCUR8M83SUMoRQ',
#  7: '0l1I3fu22Aec8S5VG6NiqQ',
#  14: 'rGuevqz7WCka0f4UfkHurQ',
#  21: 'Xe-Dlatnkz9A9l8oyDgU9Q',
#  28: 'okOV6LqE3bTy5ZIMVm3VOQ',
#  35: 'Xc2afntnM3flsP-pPZxXPg',
#  42: 'rp007n5XVLGJwIOTh9U0-g',
#  49: 'YrDbyRFyan6nx5aXb_N8Hg',
#  56: 'rr_r5cE5Mz44TIPjOHk1Qg',
#  63: 'nx_htQFv1Ck4iCCyfJl7_g',
#  70: 'PimD6QJQpDk_pn0zR1GwZQ',
#  77: 'BH4c0UxaFy4j7tER57qi6Q',
#  84: '3FjdHwnoz-vfw6hBBtckqg',
#  91: 'L1VaWJjSZELhqyaMoDU5tw',
#  98: 'wFL_ALur5nfnG12QXAgSEQ',
#  105: 'ChvMiLRa2T4gaI0k5nbTyw',
#  112: '8ijJRp3DjaaaT7TfB3pFxA',
#  119: 'zlTw3kIe7UcFk831WBRIXw',
#  126: 'dpZguGGV9C4zC0KgEIfaTQ',
#  133: 'mNy3YPlyaOsD6FDUtU7mxA',
#  140: '4yG4J05aKzE2zov0Jr37kg',
#  147: '4Qu99ylIiwdNUu10P65inA',
#  154: 'AM3pzipo_ssKE4FWNkALuA',
#  161: 'yUmEBt_NayUxGhKBnH094Q',
#  168: 'JiPMk9WmbJu-VfTRAKpZpw',
#  175: '0l9V2VrhdWDgNR-7TpSAdg',
#  182: 'H5d_nFqzwrREE-YduK2ABg',
#  189: 'B0N2Ynjr9yHMMlgSVDGOfg',
#  196: 'n3opKJcy8lYSxR5E1ppWmA',
#  203: '4GPJCaHHAzPgmT1QGIVHSw',
#  210: 'KV92qxvltVlZ_vHDUqO3sg',
#  217: 'wTI-obUmpg8MGqTzVpKJXQ',
#  224: 'wrUYC0wc987XBBAoskOCHA',
#  231: 'V1EGD952i3qqrfMn3OoMfg',
#  238: 'GGi143WxKCSkVKo6R3GsAw',
#  245: 'YrlNGnrofZHseVYxrLrvJA',
#  252: '8PFZs6fsRwMafqaJV2nOoA',
#  259: 'p4NSx2CnjOL1Z7YD3XiyBw',
#  266: 'mnM7iMTPuKOsHmhQOb2pYQ',
#  273: 'wF4_c5luZZM0-z-d-EtCCQ',
#  280: '6eSUWPC_mTuSf8Fgg6hugA',
#  287: 'Vc2LF9WWbzQ7LWdyOIMZEA',
#  294: 'jFmQNoRjKx26kbP1EwenBw',
#  301: 'yXMcfH0qS2yhKINCRNI4nw',
#  308: 's0rJ5eoGcI-gyJCmybsMDg',
#  315: 'kTRckWrfY3UTVHqiY0Ubnw',
#  322: '8cMr5H3Ii8Qt_KGJ9gxGFg',
#  329: 'iwKPKqhX3lSYXelDup83Ew',
#  336: 'EOS1aH7ZASKaE2BfbQjeJg',
#  343: 'T4bKpy8-BT27L_nfWdlVqQ',
#  350: 'WgEKUJoh5msZlOlTCKnKtg',
#  357: '5cuAGCmSZrT510080HNGWA',
#  364: '_O5ajREINPG9zeyhW5Dmqg',
#  371: '0tFC0h8RpL7Jx98QENO1lg',
#  378: 'ln2AbDl7nKbdAoGI2CePJw',
#  385: 'fFsTsnITTIvvEOz4_mkUXw',
#  392: 'fDYtu9b4Ln5JmtfT778o3w',
#  399: 'cPQQozKkn7D9MArUc3OcDA',
#  406: 'JsK6QCEk3il9P2O8PsMOHw',
#  413: 'ioOD1kG2KFaLYQONRJPmdA',
#  420: 'ixeALmgJ1aBAYIh0F3cnJQ',
#  427: 'M3l41fkOhS8qGD-LnRJLYQ',
#  434: '9CHa7062XhAKkyyXOZUqkA',
#  441: 'fE9-Rl0dQOGt8wZ3PE67iA',
#  448: '9NQ35FgdymriiyoRGoQQRg',
#  455: 'g23xx_BkRti4H-zmbhnEKg',
#  462: 'TAgaLKYA_xhqSqjYgtzQ5g',
#  469: 'S4hj8UEPHlogMwlxKKPNFA',
#  476: 'BOXmNc9VykHjj4bYZ4z2hQ',
#  483: 'C01rKnHeu_ArbM8VoMc0Eg',
#  490: 'NhT_9VJfYi4dEkLgRTGS4g',
#  497: 'Penk216CGDDykwdV_kn3dg',
#  504: 'hJpwVBBRwHAVuoKeElKdOw',
#  511: '5_2Wf6jP0b6ZDmABIOliYw',
#  518: '1IMIleITV1O2nlHV7KiieA',
#  525: 'k1lnHphq03hCdCNaaFWUCQ',
#  532: '3_vA1a2QlK6jUcPsRkHdyg',
#  539: 'MNE_9HYhzpC-nj-UPoa_0g',
#  546: '4fEpNF8gshezo4KxpyovvQ',
#  553: '9mch1jJ1xTNLdXAIxd_QPA',
#  560: '4dk6ki0f4GKpgzAqdupOvw',
#  567: 'b6uEk7LgrDodS5vfOP0CsQ',
#  574: 'iy8I67iN8D3eNm169Pz85Q',
#  581: 'FOqxbPyEEP5Yfu5Qiy_XUA',
#  588: '3QA3rBaoWGumDKwhwkRYXg',
#  595: 'jlpapIPWURjBUg3V31AjKw',
#  602: '7wgij2i4WgB_ihsZzBFk1A',
#  609: 'IjXnO3aSmaw4Rt1hfoVV_g',
#  616: 'V2ZaPYyOklgXaGIdXhxY8g',
#  623: '9wJpUz0mzWdK1bBXqloTUA',
#  630: 'tZfZmFJ2CSppO_A5-cTZZQ',
#  637: 'WaPj0-ej7P46m7Y5GVaLmw',
#  644: 'xRgvSeueXfZ1O6xBteN0gA',
#  651: 'dWtDzHRi1Vzr25Ppuy_35w',
#  658: 'FNqnfNLw3JZagNw3pJwY1A',
#  665: 'GmLN3gkrr_K_82sFJkhiCw',
#  672: 'Krvri0dh0Kqc8MORxGBHAA',
#  679: '3mR28S5jJQS-SwvzOPGo5A',
#  686: 'nZ9tPAVODoJaDAN811xTMA',
#  693: 'dCKxJFWjnFUjMEi3Or8ejA',
#  700: 'mAPVwLzqRXXShLRJZ8M8yQ',
#  707: 'PRiyL-Tyh3CMsy_XLEJKZA',
#  714: 'uLWWpi62JJLnTh7UciJFHg',
#  721: 'U92V-gp13uMZL-sl_naTHA',
#  728: '-cKYZ1a7xuIY39sjbrWqdA',
#  735: 'ZbJ_IVVjY-k2y4-g273qKg',
#  742: 'RpuHjlLqJBIQoszxwBokzw',
#  749: 'CIKD9oMj-qTZ3zDdgFW5_Q',
#  756: 'uiopY6Oj0ySlLRyl9mewBQ',
#  763: 'DYqujEDnSMgwL7sFTRSv8w',
#  770: 'hJFSuk7W0stwyGX0bpMhjw',
#  777: 'Rfy598B1ElBFv8uH4cVLJg',
#  784: '1j0WmQD3iCAqVhsaMuRMwg',
#  791: 'JIGkB39I-ZvOrV9S3ZYUGA',
#  798: 'HrpZLVrQh-sf9SUZfbm52w',
#  805: 'Z7Qi2nz1tKvomVOCYqaZSQ',
#  812: '1JPWqtmMrvqTFDcdOPZLfg',
#  819: '6QTZG8ryn2YqsWSDnrGTAQ',
#  826: 'oxqSnp-VDROoN_spH9EShw',
#  833: 'oWKM-KpfsyNrwfYsdfTLVw',
#  840: '5VNvWC4xG19wFCQfauEPig',
#  847: 'NNL1zLTP2J_SOputgoPYeQ',
#  854: 'nuRxdToGWjZCiFW6PmXf8Q',
#  861: 'Y2ao6uBWQXWYHh5XfyIzDw',
#  868: 'eiiS0rrIN6orvf4PmsKe-Q',
#  875: 'ocjIQe8x1FhVQuKXllletQ',
#  882: 'ieIBRew44USZgP-XsOXJ4g',
#  889: 'WBgCnzfOCA02JcYTp6APyg',
#  896: 'w4dcWDJ6KXv7fp8s-jhnXg',
#  903: 'Oi1qbcz2m2SnwUeztGYcnQ',
#  910: 'fZODCwrx-QB0bZc2UXq_Bw',
#  917: 'aT_kjMJ6wtHH94rbad5aUA',
#  924: '7yA1eM8IyKFa8zJxQfUFng',
#  931: 'Zm0oEW1mSmc0zvPIPk1Ziw',
#  938: '-2PpbzMBzwBMppsZd1FQVA',
#  945: 'XXBy1qXvig6xAyQZR6aRSA',
#  952: 'nKqqytfqc_I_-nDZBOFw7A',
#  959: 'bSvNU2vABlaBi1ooF4KNJg',
#  966: 'OM7G4pA1H1VKr92CCS6meg',
#  973: 'SQKRGzDa7qd8qHb13Z2-Hg',
#  980: 'IpXWAbu7VACBS8Z6MH2CfA',
#  987: 'L1uXjCD2WJTgfpFwHvCdeA',
#  994: 'v8cRR9t8upx8Z8Uri1SgeA',
#  1001: 'O3rcmXMUJBYOgZuA4Xbd3w',
#  1008: 'S5-MnYzdZSeraLnx6SJItQ',
#  1015: '_T9z0uOMZLpwaCx93AJY8A',
#  1022: 'yALq7sIAMLyxcd2M5JML6w',
#  1029: 'z7FlAqHkUfMzGUtPKFWG4g',
#  1036: 'QKH9r2I0fk9r9Q8c-n5aFQ',
#  1043: 'j8Uve04anrZh8XEc7foxuQ',
#  1050: 'TGzTlfp-eOW5Yll1_iEPjQ',
#  1057: 'Q_Jb1GP_KoIdiR8-lfNwag',
#  1064: 'cJTDnt8BmdXwgpjB28dsPQ',
#  1071: 'Yp-LUogNWwV7JraSBpL9tQ',
#  1078: 'CsiWU_Y-zmN4jElnOhB9IA',
#  1085: 'XWEbLpANMuEajGXWZ3_CEQ',
#  1092: 'dzSit2MTSrr9s-FVCnzeYA',
#  1099: 'CXwHjHxwGDzRTgvU_NdLIQ',
#  1106: '2ZZNOoMQ7WFvFoxDUFw1wg',
#  1113: 'LVChK4kvG_mdRdEsk34PkA',
#  1120: 'Hz6WY-6g312gwzvUq4EAiA',
#  1127: 'pAN4JFwaWVfjEdss7z043g',
#  1134: 'e9gcBrC64HvCeBB-TuPFSw',
#  1141: 'dhQOA8-FdpA6D0hNhXEYIw',
#  1148: 'H8sRXjHnkupYqUKbyCDKYw',
#  1155: 'ywykUZatRZjZgsomdHtwcw',
#  1162: 'z_DEx22qVoGr8xlysckU-w',
#  1169: 'SRFOLeoBcN8GcL24DSH5YA',
#  1176: '2v9iQ6V3w1s2WeavqqGt-g',
#  1183: 'SValXJw9y0-blobI_woHrQ',
#  1190: 'IHhzsGkjaKpQ8ehAhSDzlw',
#  1197: 'P00oYQnh-1r-3kiUNAUeIA',
#  1204: '90xPUscApJ9qh1iPptGmRQ',
#  1211: 'j55llTI5f_Xth68rqJpqUQ',
#  1218: 'jaij3nmMTFFguC67URtcxA',
#  1225: 'DsN3cXiWoQ-tyzvbu7gMQg',
#  1232: '8RJ6Hayajx5BCVfT18q3Eg',
#  1239: 'Mgqz-8RAU3914P0eWfY1VQ',
#  1246: 'AHRrG3T1gJpHvtpZ-K0G_g',
#  1253: 'blw3J8-L5tijnh2KTA4kDA',
#  1260: 'H4e9rk3r1aOm_9ouGMPXTQ',
#  1267: 'v8DTz8SQRMlFdWrpCMp4Hg',
#  1274: 'GYqWcuzy6h0cTn78HVJB2w',
#  1281: 'UurKzT0KykeIOrDaoPdauQ',
#  1288: 'N-pi-twvDI08ubRth9q0kw',
#  1295: 'aa6FT4IduLVx0Al08uvyKw',
#  1302: 'IPwDcYi_GhskOehEN7MrwQ',
#  1309: 'WN-4DUGD6k0OI6KfoJMhhg',
#  1316: 'BmZkobZFt9tkhbDFX8J1uQ',
#  1323: 'vPbjvPHzWPlNuddB8XdiEw',
#  1330: '3_9MvkaRtLMTnKqSz-aoQg',
#  1337: '4I75CfHLoj4dFwx4f7CoeQ',
#  1344: 'VbLZSyr39Xx9oox3r-YOmg',
#  1351: 's53lg6FLUHubh2WQAStz6w',
#  1358: 'x_0Udim6psMz5Y8-vlkpJg',
#  1365: 'YprTELbKHxsxfykcM_Sv0Q',
#  1372: 'u9GEGme1Fe4DbdfxR2Ef0g',
#  1379: 'bsqLkyax5T7BOaiaJiTRpw',
#  1386: 'vXNhOmHb0MuCjpeHVAIuhw',
#  1393: 'D72gdogOqIB-9K91AQIfuw',
#  1400: 'pXFbXy_8S36V5kzicY15uQ',
#  1407: '6SeqxZTbiXwKtRGPO4Qzjw',
#  1414: '-ONyyxFUhDatBG3vw6PkUw',
#  1421: 'DYPSGiTDKahqb01DkESqvA',
#  1428: 'hAR2Znsh-_hpaS4PbV1yGQ',
#  1435: 'QmXoXAVxnQA42P8VePotOw',
#  1442: 'X1nvKXUJ5Lp3W9Oe-_JrMQ',
#  1449: 'HhWxXOo5K162gh1K-iy5UA',
#  1456: '9Cv_jQI7SXgbItIsxaDP5Q',
#  1463: 'ecvzxm-LKNNci1huClxfqQ',
#  1470: 'r40gfv7zEMo1IIm9qNoOJA',
#  1477: '6s8pzEG392M-zHvayaIBRw',
#  1484: 'Y5R1kbdRvSk6XC9adW-bCQ',
#  1491: 'mlPlZWO0mHYI4iTmVKAcYw',
#  1498: 'SfkCNaq_JLYkutheYo_sIg',
#  1505: '1SKl4GkKxKmLU-0yz4PZpg',
#  1512: 'vaNvEgtznFwSPDNkbM7hjA',
#  1519: 'PUsPU46o_5dZdIPamJwOoQ',
#  1526: 'FfkLrUxTFS9P90wT8Aa-PA',
#  1533: 'VyNzsc09nWLrnHm5nD4FRA',
#  1540: 'VbInRYXYkzzWZ9CM6LkOuQ',
#  1547: 'b14IUX4f9lRPYg3cNXNA_w',
#  1554: 'kXFaC4ZdnE1gOb-p37LJdQ',
#  1561: 's3bY53dDTJomRRusjsRwcA',
#  1568: 'TbtesSnU5j_UKB5MvcY3PQ',
#  1575: 'Ei-xuVCGAcqgKEw15nehcg',
#  1582: 'al8UgsimMRI3T-Sv5i1UCQ',
#  1589: '4I0GgbhVYkgjxtAl2Ty02Q',
#  1596: 'u91TWbYBB1b1x57sha7oYQ',
#  1603: 'bIYloexBNWqfdqogPkj6LA',
#  1610: 'WRYEcZ10N6eCqeCQ4D9e3g',
#  1617: 'NfU0zDaTMEQ4-X9dbQWd9A',
#  1624: 'aLRiZwY8oXZt5b2irOidgA',
#  1631: 'AZ1uCg6A7WacSpFyGjFOYQ',
#  1638: 'IJWuwPHM0-q0VVSc5eOX1w',
#  1645: 'E8w6O_CXuluNeo4K1JMIbQ',
#  1652: 'EGoJc2wf7hCl7Sd4boB2eA',
#  1659: 'koJypUmFGpyKIeLsuMXwJA',
#  1666: 'Cnbt3hjIqd5LnmqHzHV6nA',
#  1673: 'KV8dsBfUaIxVWGKBs-h9dg',
#  1680: '7tGhgH1PT9iNtL5EOcy3kQ',
#  1687: 'YAC7mZQ0wkuuz5K-iwAH_Q',
#  1694: 'Z4VFIl3amIZJ9bb8aKL1Lg',
#  1701: 'zesQ28ZSEF0P6vueSne0gg',
#  1708: '1ueutKtIYlc6FDxb1IbqdQ',
#  1715: 'ji8Yqkux5ETnVzUUmSvMSg',
#  1722: 'YUEVwkaBsLlnmBG-Zb1gSQ',
#  1729: 'qMPlPcFzow0faNl2d89Dvg',
#  1736: 'oeTv1RGzQ81LdR9YlXQlKA',
#  1743: '1HtGcjZehXY8odctlBSIiQ',
#  1750: 'ZsTb1atwFpmCPqB94S1OUQ',
#  1757: '9BlfCP8UE741JivjeBIkyA',
#  1764: 'EDxATx-1OJkohVt0ZTDflg',
#  1771: 'L-t0gY-dd-QDD9JtmEHqqg',
#  1778: 'fmgXGi9LndwKmg7u-tatAQ',
#  1785: 'q2nBrogxjBLzJbGVP0iKig',
#  1792: 'Fm7O5DmNg_JveRwFgjSnxw',
#  1799: 'JIciuT_hGiSB7G6DsUgGqQ',
#  1806: 'gjJWLfu7piL05f1EF5eWHA',
#  1813: 'hLVq7VSJBHZwqurwWoCmpg',
#  1820: 'FtFn6AtRxICqyZRYgL2yRg',
#  1827: 'vbDobyH0Sg6iFn5SGGtSBg',
#  1834: 'PD3X7S70zXHeOx1NjeicjQ',
#  1841: 'FbepZ4KMUjGk0CAnzGyCxA',
#  1848: 'le3Xn9Mheb1hNxWurF7RSw',
#  1855: '0obrr0L01fZZlTW3fMnkLw',
#  1862: 'Yti-uiY4BP9gR-G_DsqNBA',
#  1869: 'zwOiJvD09N1dNf-ts7wscw',
#  1876: '2riSqttvBjWLLoupg9EA3Q',
#  1883: 'obDniOx83CJxLtgENZevqg',
#  1890: '5n9gUkWtIh-aBe2dt3ienw',
#  1897: 'GQmU7HKuv0WduoEA7xWSLA',
#  1904: 'mJUy8-QmtBlIvr2IJAtIiA',
#  1911: '1SqlSzJV_L9Sy96i7DFoOw',
#  1918: '4BxqD2tXP7JyEfYL_f0ySA',
#  1925: 'qRTwZbjl_kcVhFUBwovwIg',
#  1932: 'hNtnP_8SzDk0D3o1Wn5bfQ',
#  1939: 'J0S3bAUBRd_ZiRdiw0L30g',
#  1946: 'thNDNL_rr3VFo30IRDsBgA',
#  1953: 'YKXSmvWn95LfXn3FOPo_hA',
#  1960: 'wo_NdM3CsWK3-bVkhyFyEw',
#  1967: 'x_piDvkqL-xKJcsfUCINLw',
#  1974: 'MIM4KVRbNJ7xVk9ouk9x8Q',
#  1981: 'C5zw3SPSLplL-lw0QFIBtw',
#  1988: 'W2Vhv3VSBscCYPXZ6Zwo5Q',
#  1995: 'qE4rIlZ4QmCTiDTKbG5PpA',
#  2002: 'ZSoruGLYTNQ6yDhH4WoFiQ',
#  2009: 'djbM_u07NgmJNzCSUM3Cmw',
#  2016: 'BkVL0m9p8atwS7EQcDLekw',
#  2023: '9x2Tj2EhmWkwaWq3ShJVBw',
#  2030: 'lZzDBWzyDBFbpHoUVk_ubw',
#  2037: 'Wna7IxItjsO1dV32D5tsLw',
#  2044: 'SKZiaiUA3vFFLea0q9t5NQ',
#  2051: '45mRoEbA_IvHIyUHpiABBw',
#  2058: 'D9TLBN0SyY8Izq5WbAKGFg',
#  2065: 'AUeTkT-D_rxK_mmybEa5UA',
#  2072: '-lH7y5tOBoAWvF4vjDznqg',
#  2079: '4r33dXcE1oYZxjONrhxTiA',
#  2086: 'J8b-DLaDcgTwoh6NeOuaFg',
#  2093: 'xmmFUAOynoSBe__UrHBCWQ',
#  2100: 'ReO3bzLT21tezQHnAmXEnA',
#  2107: 'QbnOFLb5P-mRDh_wfZzd1A',
#  2114: 'YZ8ifu4BoaEGZYmZwLfZWg',
#  2121: 'kGjkAuRlipIji0m9Y_rr1Q',
#  2128: 'e0LI7c4HFyz2WvCBwbQF_Q',
#  2135: '-_cynccf5G-yBSRTyCj_Rg',
#  2142: 'B4rH7qZ4s6dNXSwu-XWBSQ',
#  2149: 'scWpkoTYwsFeGAtITSgEXw',
#  2156: 'MnnNXn1miJz2KutWcIQruA',
#  2163: 'dio1wgQIsoo-yHK_-ijgWg',
#  2170: 'SS0jDAfwpednEVkeVwu4OQ',
#  2177: 'ZXTh09hOK8-08Lvnv9I-DQ',
#  2184: 'vzSRigjMdX6Qm0xVhjyROg',
#  2191: 'WCuysau0kiDCei4xFPw2Rw',
#  2198: '87lq1fg5NdoFG8bUzMw6YQ',
#  2205: 'B05gFd26mFIbU0np7Nl2pg',
#  2212: 'V14xXEWC4nD_bY-lPtRedw',
#  2219: 'epk4MpOdtrg201bDATDUQw',
#  2226: 'nXMMoDzXRByQiWH9cf-FAQ',
#  2233: 'zvFj8J1fjh7CSLK8dvrTcQ',
#  2240: '8xUpswxnj8wPRUEBMEQ96A',
#  2247: 'PVoczxmG7UyCZXwsYbx4Qw',
#  2254: 'iH_fFp5HO4DI1DmZM4vQcA',
#  2261: 'aKHmQdmnvN0NHF8MXiA4ng',
#  2268: 'pq6SX85MwHW7dMRo_RhDHQ',
#  2275: 'QbRTg1tRZaCwExRwePcYmA',
#  2282: 'KCHbs_KET1F4bbTlrrt5bQ',
#  2289: 'EHIeYdQRcGy55omXS36GHg',
#  2296: 'LljJl6zfbvzLZ0xlpS7GDQ',
#  2303: 'e2goTuVddLIT9Yz_6X6hCg',
#  2310: 'Iujmey8hki6h834Eznycnw',
#  2317: '1gVejKQiYhHjz7ybDsenqQ',
#  2324: 'u8DtSxuV8thakT_X85S5Jw',
#  2331: 'yRt1Re2IHd9ks-xan7LW-w',
#  2338: 'nu8HvHsf_jRFAquDboZy9w',
#  2345: 'tBLhRAz5DeRur2ffxuPYFw',
#  2352: '_65Iaqh-Ouf1rv7suZeSIQ',
#  2359: 'eg39QzbMqx7oMj1_19t33w',
#  2366: 'U-FY_uZs1set1LFs7YL12w',
#  2373: 'OutaDWw3KRLGo5N3S_L-CA',
#  2380: 'QODAExK-m3Y3WqOuswuYuw',
#  2387: 'BOh3_pP0Di-txZomArm4yg',
#  2394: 'bMQsfT9zuFYBR8cetnkoNA',
#  2401: 'O4s9lPLMbT981mu5JMCFYQ',
#  2408: 'DLotTTOogjpT1JiJBHOnJA',
#  2415: 'sPRb6e7wTYi0c55_V7FcXQ',
#  2422: 'iUVfOKI59DFGHWKLpmXHFw',
#  2429: 'sZ2Zzu9JwgXZSqhrtxPHsw',
#  2436: 'U0WraZ_ezmt84GyOAUWgQA',
#  2443: 'joN2h3YIn99bsBsTJ0UffQ',
#  2450: 'DtzguIRjy-oRbrwVidAxQQ',
#  2457: 'eWCnWsdFaxIZstBwf1WULQ',
#  2464: 'JKUmKbh_bV7SY4ds4a7sLw',
#  2471: 'ai7atAX4aFzuK5j8Ia7EpA',
#  2478: '0aR5EUkDwyprwC2We9cKeQ',
#  2485: 'Q9f9gH-w2g_Hau7z0bEbLw',
#  2492: 'KZBlUvyzm_3oM27BMNhPOQ',
#  2499: 'jXX-G_goCYZZrLSDY8qXdg',
#  2506: 'zo9Yd1b_JFX7yjBDUXmjQg',
#  2513: 'jOVcYOqVJXIYZBCuIyytww',
#  2520: 'Fw4w4eTk5SZVA6GL1Fj2hw',
#  2527: '5t6PveYLc_h5mvg2MKRafA',
#  2534: 'B3AaTIzaud1dd1nEs-89Fg',
#  2541: '-I0PjA7XABOmNUOazVuHxQ',
#  2548: 'rqfhkAmSQKWzjqBFlt0YPQ',
#  2555: 'GdMOa-WYCbZPDy7H_aVIBw',
#  2562: '85uM-cor3VXCUyVFEe0YNg',
#  2569: 'PGI3xQ8cl9Z81BA0kgbRhw',
#  2576: 'G80txUlKPzFLTxmRucE9VQ',
#  2583: '_DyGIB-XpLHHIK9s9VlVsw',
#  2590: 'FqU1_EyfmBPt3m58E3Z-Jg',
#  2597: 'bMvyfWmps1Cc_AOgZLCZrg',
#  2604: '0WPJobk8cFbDXjHyOrwntQ',
#  2611: 'oNFd2G_Sr0RQCK4NIOWt_Q',
#  2618: '1cLsV3rtVyJQOHJ-GEST5w',
#  2625: 'bryAPtwnnMYjbzoOWHzbWg',
#  2632: 'Q9DAJCpeKdzS6WuMvWOX4w',
#  2639: 'mT-sJNwB2Vt3DYcwF7w74w',
#  2646: 'dtrUXmFRf6_Y9f0hZ_a8lw',
#  2653: 'V1vTydFwCOxA4ltmEBgetw',
#  2660: 'ZrPqpeaMvq4Hqmtd4sWbQg',
#  2667: 'j6tqaxxd-qTVeF7q62sbjQ',
#  2674: 'qq3u3dfhjXtyKI2d_fB15A',
#  2681: 'fU8qJksd9F-Sh-6ZnoNhAw',
#  2688: 'g_gTwHdQUFkt8VetO1YZ_Q',
#  2695: 'qAQjfwspeg9WvCewHLrxOQ',
#  2702: '8dVpQp0EjrI5zLLCfpl_wQ',
#  2709: 'awHQKhfLpoGNQ2K2lIL9dg',
#  2716: 'g6lDe51BufInUXTKZ6ktYA',
#  2723: 'Jet0QZQqYFQkvyzLZbFBQQ',
#  2730: 'HWXWaxpmtwe_1ooJVfNi9w',
#  2737: 'c14PAVzMMRjK36FG_NvU1Q',
#  2744: 'K5iW9kMfQU2YP3i0ukQbkg',
#  2751: 'SlgpAnj2gQd44EM_Uq6DkQ',
#  2758: 'HKrwO5TB6uAW4coLJxS47A',
#  2765: 'aKgqB9v8btuRB7tQtSdYZw',
#  2772: 'RYtU3cDC-TfCw3biYvZmkA',
#  2779: 'Ek4fKT2PxX9ILuhP2Hb3Vg',
#  2786: 'eleHB9ez_G458u1Xt9uFAw',
#  2793: 'RwDPFFYNWQqbkfsPo7Q1mg',
#  2800: 'TEGdAyYN8zrKc0EB61L9DA',
#  2807: 'aALbJFdzg8FXF9dnLBLJ5w',
#  2814: 'JV-5lA0ULJoP7FXrAVeNFg',
#  2821: '9VDrCkfj0I_MDSDPgsPKFA',
#  2828: '3xBFFH866WoySDG7uuwBSQ',
#  2835: 'jS52urhDarQnyTo0cxrX8Q',
#  2842: 'v8VyBrpJaP8z4mQcSPeNWg',
#  2849: 'DIRS_JzG_ueBnXDTOO4W8g',
#  2856: '15Cjp9YgVZqaNRzFDKh0lA',
#  2863: 'aZCdJSkdfkzeM__o6VQQ7A',
#  2870: 'afYeUUMLMa4RKGMOHBB0-w',
#  2877: 'j72c8XdtMD5sA-t97OFZFg',
#  2884: 'EXetHqCXfXQOGPQXZ9lvkQ',
#  2891: '8_s8um4YX6lyyUrxG9aHUQ',
#  2898: 'FEbt4jvpT6O9T_ktaIaOQw',
#  2905: 'ZNZhsvoCO6xJUpej08RW-w',
#  2912: 'izI_LZBFLaoem68RuyikXw',
#  2919: 'joJy2j0ZOiU3cSIDJ1egkw',
#  2926: 'eSlvR2rZ3HB1xNeQIPse8A',
#  2933: 'VvRPkQOFoIqD7dp-PH3vTw',
#  2940: 'epIbSOGzpcF_xwmqD6eDdA',
#  2947: 'ADvSJWpDG3Sh2OLOYe7eSg',
#  2954: '0cRU-xaO0uWYdJDAVpDznQ',
#  2961: '8BA9P27NAYJ-R7L09XUXJw',
#  2968: 'Z7pFsGpIyLzMTZsXjTFF1A',
#  2975: 'aAwXN1aS5eOXRUiccpRukg',
#  2982: 'HNTQqCmN_k_lECCOhC3baA',
#  2989: 'X9lSd72re8xNAcMzJ9I9hg',
#  2996: 'SnmGKBlVhgz1tyx4nAm6Eg',
#  3003: 'P_7Ceau8knJq9rEb4expEw',
#  3010: 'Fk5dYvL1BjhNVqcSdIDBew',
#  3017: 'SSkfJXnEjhA5NjMdHbjwfA',
#  3024: 'DsWg3leomfasGs3j0rOfbQ',
#  3031: 'dpyvUkvuxAgA24wXHxAbRw',
#  3038: '1uChNMe5JXP3EC7YPwctYw',
#  3045: 'VbyBKyEO8ILmadlALHsBzA',
#  3052: '5IHj1L4mfxKCSBbf0LWIzQ',
#  3059: 'y0_shndt5hpQsXGshDhfDQ',
#  3066: 'HqDTvL9sU9r7tlXivGSYOg',
#  3073: 'qjYXOBnladFYhciGBSgAMw',
#  3080: 'OovRcCtQT87WIzuJY9cp6Q',
#  3087: 'sBkFofI9P0_u4Zh6ksyJnA',
#  3094: 'udevN-OBJnESlQmKYxZnYg',
#  3101: '-yIdtawKgmNjW6yAo4R49w',
#  3108: 'RzIC3VngUV8b-CpSIuQ7AA',
#  3115: '4ir2-8gnz28qCbsdjpTtRA',
#  3122: 'Q83R2UssCoErEJX36wrlvg',
#  3129: 'hGrUu8UMfnefdQeBnESBsw',
#  3136: 'dCFJdIcWA87mVobQc4t_ew',
#  3143: 'IdKOPHUaHMv06MPt11DVeA',
#  3150: '1PDXOmuenP8SCVodR9bd2g',
#  3157: 'sfMNWbOZMCOGO03aCKwADw',
#  3164: 'NrNm5biDLHNjkTFcfwXtPA',
#  3171: 'jKx0XOTrnT6gHiiRZ-UVKg',
#  3178: 'StlvK2n8eHI0j_KawcL39A',
#  3185: 'dnmsNEXJrTv_GLngHNsrcA',
#  3192: 'dHJCnmx4DnN-JRbCRr31cQ',
#  3199: 'ZPXs39EVaaNeWOX6foKOLQ',
#  3206: 'v63K1BrRX2dsJbhGEtOKBQ',
#  3213: 'R9XWVIIn5pI7ZGf-NX8ukA',
#  3220: '22Y8hc4NYWPa2D6ffodddg',
#  3227: 'IjRzR1P47ZllqrJCUTAE3A',
#  3234: 'PVyZXgOkVtnU6966FDFhuw',
#  3241: 'clrFm6dpALb4x1aDQ0w0Dg',
#  3248: 'GSc-cusclqJ8hyHvzJuDuQ',
#  3255: '2lrzmgAoJgnYIACG9cKdfw',
#  3262: 'UfkcUiu4PVvYfikmLQy5lQ',
#  3269: 'MIaar-b5anmFFOF7BkEHow',
#  3276: 'U5DkhqQfcX12r1Uzy2BD-Q',
#  3283: 'IUgLSJRBYOUn19mcuOIpNA',
#  3290: 'Oz12y2PNx_A_kPaXXbvcew',
#  3297: '0T_ELTWm2SrAqxEECcxyuQ',
#  3304: '84HUMOp2GxsQ3NkPHBUusw',
#  3311: 'CTUqeP0Z7kgi5Tvsx-mU7A',
#  3318: 'xmvPBsdEDmJ0_cfxYSL8YA',
#  3325: 'KdbyvbGT3Fj6c_J16UkRyg',
#  3332: 'DPcGKtJKRqJG7Ji42KyuzA',
#  3339: 'q0JG7nRp0lBUa2doJQcyeA',
#  3346: 'ku4Xcb-4msmAoAgGaDIIbQ',
#  3353: 'UzyB82hjBRXjQxbzPIIQhQ',
#  3360: 'L0lkvUmlXl1YRqkfZQ6AYQ',
#  3367: 'QibXhsqPLNprUPRDNXmNqA',
#  3374: '38VM6rglF52NmC5ITCZzqQ',
#  3381: 'nzGSm7_3EvJiNg2k_RSZRQ',
#  3388: '_3sotDWtZQG_4U8GagI53g',
#  3395: 'cD01IqU9QVsCub7grUNjiA',
#  3402: 'sJesPcMaviZZQgjBn-Z4eg',
#  3409: '7894uPHf40YKriYnp-0jqg',
#  3416: 'NhhVSiGr_kRX1YrejD9FqA',
#  3423: 'QK3HdRq6KQql_04SoPES_Q',
#  3430: 'YGwQt2cRhQKI6DikcotVFg',
#  3437: 'MeJI77jgRpYkAdOH5kbNLg',
#  3444: '3zg7oCsgFLE0AbDihopozA',
#  3451: 'iEyyoNNGVvIXwsQhGWlreg',
#  3458: 'qsfgmjRAAqoe4zqHFSt-8g',
#  3465: '0g9Q8hnRjXv3Decrh1Whbw',
#  3472: 'uKAo_4IVYm2ZH1v6TisWxQ',
#  3479: '1hlpiZa3tCwgzf549dYsDA',
#  3486: '7-6JhKdW3CnxmIkeEyUGTA',
#  3493: 'nUjZZgkdvJ-_heVWtse7qw',
#  3500: '93BEoermmCu40-n7ivFYLg',
#  3507: 'xcrhRdqBuUyIk4GmxP3qCg',
#  3514: 'MXrNeQ7ydZAS6hH2nLWV6A',
#  3521: 'jXaJgrAFNbkqanFulcVt9A',
#  3528: 'C1WGfbELTMy-eFqSKN56FA',
#  3535: '64CURd7vWIVsyZUrIYTuGw',
#  3542: '-hBrIgWki-kE1GV_LnGs7Q',
#  3549: 'H081InrAE-ncVEnGTuyzjg',
#  3556: 'U0WU9d6gpMNkO_tPXK58Sg',
#  3563: 'TpDUE7uikk6T6O8oKH1LiQ',
#  3570: 'qIqyFDjLTJ59ofjBIxgQCQ',
#  3577: '4_ZjNlTiGzcONupQhCjmoA',
#  3584: 'YceR328o5YZUh9kIWFdAOA',
#  3591: '2AaKt0569M3ZjfQ4W7-OFw',
#  3598: '7PiRdxYF-Uvzn2fHqdtU1Q',
#  3605: 'eQ5qftDuQ0ZHt-FKBHvbBA',
#  3612: 'OvcmeU9yt5jrdWqUTtUvBQ',
#  3619: 'nWYLiYUC9FMfuZn4CabvqQ',
#  3626: '8Zts7elT6qOI3cZbghmcoQ',
#  3633: 'tVmV9G3ThSx5O1Oh1qCJrA',
#  3640: 'G3T54FEEpW9LeAw3iYgq9A',
#  3647: 'dNLbc8AQAXePOA8ro_OQwA',
#  3654: 'ZdosS-sZ243RT1IuCOPMig',
#  3661: '1lTN0MNy6zCjnkMI8x9i_g',
#  3668: 'WNymRl0p1uITlvU36ZXijw',
#  3675: '4xeJjuT2bM73B92F476LXQ',
#  3682: 'I9-odfGhqygS_wRZH6Qvcg',
#  3689: 'AOnhWZcrDVsaLo6XXFAA-Q',
#  3696: 'OpiL-y_qrqp1TPzMxOMBFw',
#  3703: 'PzAaecZxyxJfMaPeEt5r0A',
#  3710: 'awz9AiUF_vHdgWfv6_B-TQ',
#  3717: 'LS6hfVdVcV79FqNMgvn96Q',
#  3724: 'lxQqg3WqhVSGHHt3h4cusw',
#  3731: 'ibeb2OxOucjw8hYzTIQFIw',
#  3738: 't3RUgootsj5d_BpcMtgnsA',
#  3745: 'r7RdCrF0SpzFoUWFb_8oyA',
#  3752: 'tJ8J-WTbnSEAkMrFgBwk5w',
#  3759: 'NCyxFLr7iiFqAcEHw_h_7Q',
#  3766: 'mWo-q1z-NtHWpmzHcaDcGQ',
#  3773: 'kA3VWEeIPlwgS55ewIr_ow',
#  3780: 'ylP1xOrimSXJY9D2wuBaUg',
#  3787: 'VMeTWyjL2eYJIbkZ8oe9Vw',
#  3794: 'rvqWuGxF2EuPB8au_ViRTw',
#  3801: 'dq-Oqe0XcEqfZlaypbj5NQ',
#  3808: '2ZGvBZm2mAuJ7s3YXEtM-g',
#  3815: 'P_IOYfjCLHDwYXdDkw1kxw',
#  3822: 'xr3LYCWwYaTH4rhwCz1Pkw',
#  3829: 'uaV7GmhdbgL5Rey0I_OuiA',
#  3836: 'ebtL8NBaw-83Cq0GRXU5dA',
#  3843: 'emtxMBECZUFRYVXR5Bvbhw',
#  3850: 'OQT9DjfBrzrwOEdVJjuYIA',
#  3857: 'FtzawEb35-ATDl0pebm7Mg',
#  3864: 'sqRYiuL7n4ZaKllpfDLixg',
#  3871: 'JoPr97nBzsvlUliEGRQT5w',
#  3878: 'uiqW8NTaJO-2uZDLymDOow',
#  3885: 'bkOwhZlkTUb3ogbY7Jpzkw',
#  3892: 'dwLEOBFzTVaIFyrUItuYqw',
#  3899: 'cA64mID-MyZXgp0SiExD8w',
#  3906: 'qW9yK3f0vX3RhKI7yd311w',
#  3913: 'bvMt5iluQQ86Ohdi5v0wbw',
#  3920: '3JrCsaeiYPwQVLlDzAEheg',
#  3927: 'qYARSGbbUuQ1F5ptNiJEKg',
#  3934: 'jaG8WU_zlRqdz441i3Y8AQ',
#  3941: 'Co0AQQuv6U0h9D94J1bmjg',
#  3948: 'qTu-MjBxLJSK4HugfdPPRw',
#  3955: '8TssurXnnaOpzld_yABvtw',
#  3962: 'ETUJafSUn-B3CWu9_pu1Pg',
#  3969: 'Z5pSr4XxB7F3AbF0BLO_sg',
#  3976: 'rzGHHrho30FM0KfJlhzBIg',
#  3983: 'IEtUJoyDiELj699aKi0pXw',
#  3990: 'C6p0kvnu2rvqyM1WN-EbrQ',
#  3997: '5CgjjDAic2-FAvCtiHpytA',
#  4004: 'zed8BTmqmNnMvyOw7TycxQ',
#  4011: 'Reuq65EOFI938Yg8xgff9g',
#  4018: 'rP973kGSCKewbZTsy2bZJA',
#  4025: 'zWfEQR7hXOrD02DEuNeGTg',
#  4032: 'ukQNbnxHQn3CQkcLIBd7eQ',
#  4039: 'yyKgRI3LLBXIAk8tI27cdg',
#  4046: 'xCcLViSSdXZJv0O3hk_gqw',
#  4053: 'E5HVMuqqpylTqfLcgTkqKg',
#  4060: 'yCaDISH0R8e5U376zDWTpQ',
#  4067: 'qmale2-UkL1cWTPwPaDTrw',
#  4074: 'kBRPv5eDYTKJ69xCVl5tTg',
#  4081: 'xq1zRJz5VHgEKiCaI51_Gw',
#  4088: 'I2VrWcUSzNSjVw8Whsb4uQ',
#  4095: 'lzbOiFu190qEhX9tQLFW6A',
#  4102: 'boR1hACwTVXljyGaFw-yFA',
#  4109: '0-gPdZWDQ5o3kYCmKj2UnA',
#  4116: '3mSdfBgfBAsIV91GOCkHzw',
#  4123: '9VsUfMdfdATg7Pzf_Ypk3w',
#  4130: 'FUS9xjFl1cWtJCoP1R8Xow',
#  4137: '9QEUvV4gwDMSIZQMCTcR2Q',
#  4144: 'SIqENP8MSWUaaN78usHnOA',
#  4151: 'lDDQi_BX7I2CPE-nOb9ogQ',
#  4158: 'ABRH3A37M24GrCR3-bX1Pw',
#  4165: '2cOLxZd7O4e2rvEM1einsw',
#  4172: 'NVVknS1I51z8wY5NNrJ6vQ',
#  4179: 'pqxhV9NyzfYY2Av9Je9-RA',
#  4186: 'RM2xSzBVbPSxJqsXEwK4rQ',
#  4193: '8_Hs9Bh5tgFdc_1ycxHChg',
#  4200: 'pR16xbRTNKAa4IDBM8NjDw',
#  4207: 'wLg-ueLXkVcXcD5qx7r6hg',
#  4214: 'KWc1obX1Ye7bboWBMJkcXg',
#  4221: 'fvV-kLP-ndpmpU7uZsZEZw',
#  4228: 'zC2sg6Z5nkaMeiKC6_5Hzw',
#  4235: 'VbfaQcyRqSZ0rGvhgg-3Fw',
#  4242: 'Vjm32QmEbLcUqpFAH95trw',
#  4249: 'Kj53Wh4erZCgMDGTPolDvw',
#  4256: 'I_ls40jlVbr4YZLteJ0Lmw',
#  4263: 'ouxUJh1toYNdH1Y3hhnMpg',
#  4270: '7A5--ipQdE8zUm7SRrG2ww',
#  4277: '0QREkWHGO8-Z_70qx1BIWw',
#  4284: 'Grd_3yK9ycK-hBhymjgyeA',
#  4291: 'kyZ2FNiDYn5Soufpz2c3Mw',
#  4298: 'Wz6nekYXj4wZ39UKgaVHJA',
#  4305: 'KlvNEorrzZIDm9V67CNzuA',
#  4312: 'uQZI4J2rIIPs2I9qHqaWKg',
#  4319: 'RyhUqGv0sIhWS1yb0zJOqQ',
#  4326: 'NyyxzPuzZmv9GVVH4Zptow',
#  4333: '7x2d_TxjgMTlumoyChCLkw',
#  4340: 'hYPVPwbAdcaPeqJ2N_PAcA',
#  4347: 'SVWvQsmCNHjk-b9QP2BUtQ',
#  4354: '8cLH4t2j_ge9Ht33D2g7WA',
#  4361: 'FmHjhpxLQx43UaD9mjJFFg',
#  4368: 'zZYHZwmBl9Af4pI-aLXBFA',
#  4375: 'E43QxgV87Ij6KxMCHcijKw',
#  4382: 'C5ClwOOu95gmlBfsDeG5pg',
#  4389: 'DcTVRhyy6ZSj_a10P3yscQ',
#  4396: '2PP1n6_SKYKWiY8JARYkbw',
#  4403: 'clXKco_bCYG3ajR6R-L1KQ',
#  4410: 'rj10hcbfLHAF7SB9CXEkRA',
#  4417: 'euUZ8BN5l8O3FdNGwxZrOQ',
#  4424: 'OeezFcKDr-FvSNTnzDBPzw',
#  4431: 'ZLN5ty_Vp6vQycBAJyN-3A',
#  4438: 'O0DgWmrk4a1cPlZpARdNXA',
#  4445: 'KRkt7qU_k15w8DoVfXQ-0g',
#  4452: 'S1Am9rfV8pfdbAcA-UBKnQ',
#  4459: 'VIf9HbtAKcKs4llfD3GQPA',
#  4466: '2BM3AD7QHRp-ymJLQJsXxQ',
#  4473: 'TwizG1ActRTSxwBqMhMVfg',
#  4480: '0ZgeyfSnVH3fEMBoSiAl6g',
#  4487: 'D8C8p-9f6c5l7p3c48YwHg',
#  4494: 'y6_fthbJHzZekf-XKK8ZSg',
#  4501: 'FHRVmEO-93b8DZCl3hPJtQ',
#  4508: 'TqzW_U3nZcgOTFZzgSXpxQ',
#  4515: 'dtiVg9IMFJ-i4KejIUlCsQ',
#  4522: '-LjNJTYtnv_eGSlF5WcR3Q',
#  4529: 'Vm3mW0sCvB13QOmZRaSwrQ',
#  4536: 'hVidDZUvOiy3xl0v3WKJlg',
#  4543: 'a4Z8X3ic5P1YDtNzMlxCMg',
#  4550: 'htiVdsiY_rBmJc65aZ3YAA',
#  4557: 'UC2wuZKj0iWfRstljsynxw',
#  4564: 'm_Fno_sUwygMD5NvkIuWgQ',
#  4571: 'R6-3KTxBU37RB5KQDNLJCA',
#  4578: '0T2nu8kJYE7C0XN04tFU-Q',
#  4585: '1JZbzlvPevm7iEfhI5GqZg',
#  4592: 'jpRJaf8nN_9w0mBkQWdL-Q',
#  4599: 'rKauXXwI02tvKsM_B21plg',
#  4606: 'myBGjHJ9EhE9pyeodWw2Mg',
#  4613: '2oO7VB1YLfh_1B4sbdXhlg',
#  4620: 'KtnaKuXHJVLrvxGeTHGd2Q',
#  4627: 'kiOPOpZq0sXw5uiOtNCRIQ',
#  4634: 'W-UPhJjeMuP6JkqwNOI8Ow',
#  4641: 'YW3aBGlhAgljFjF6fMJtcg',
#  4648: 'uh8KQ07gPi6dQRJSzppu8Q',
#  4655: 'G4WIJVjrD0AJdrkHwOY-0Q',
#  4662: '0PLXe_gj5FwMTuiYqJnsXw',
#  4669: '4nVbQ3xx5nGvmVmW5Dj9Iw',
#  4676: 'ffTj7fe86Clv1L2ZPDedig',
#  4683: 'RstRql55rgDQQDvl4uXbDw',
#  4690: 'Vzp9gtV2SgBZEOnckCAExg',
#  4697: 'y71g4qzQ7Cf0aZUv2ZRDlw',
#  4704: 'AIi5FESQqCFPd07WJa2knw',
#  4711: 'LrW1IlMqL8G529jaqM6M-Q',
#  4718: 'fAPfgpJo_0xvU98ocYrubA',
#  4725: 'ncKJnevIZpQDxuU7GwPEuA',
#  4732: 'rgVBgYRoCiFaXOdIhPgX7w',
#  4739: '6NpX1zjrUQvkAhcgQzyIZA',
#  4746: 'jAd_EbJNdSSOGu_Nzt3vhw',
#  4753: 'AdeZ1KuhnStneCK-_kLFNA',
#  4760: '4z68bAUVliSEFFH5uQma6Q',
#  4767: 'TWC7koCQ9-AsmSyGNWPkfA',
#  4774: 'yL4whR1Qb63FptG9IVRdVQ',
#  4781: 'Cl2pyB8mWn3RCMV5nQacCA',
#  4788: 'eSyx0XggMWSdawBjg4rviA',
#  4795: 'oAKaBe5XuaehIZagnDGpwA',
#  4802: 'xuEnKqJD0nBEu-1U9aXbhg',
#  4809: 'NJO3C6fF0FfvvdDpXzMoaw',
#  4816: 'hpd24NI4BUWm-Yw8Ckerdw',
#  4823: '5HAWxQplIc2mgMQgd-bvqw',
#  4830: 'vc3CjyJ8_FYGqRxwOWZbTQ',
#  4837: '8O5ZFkqiR8MMkPeSJrnZjA',
#  4844: 'SC9wdjQBeb87nY3KLwCm0w',
#  4851: 'MzqYK6Y4nltupXrbjDW1NA',
#  4858: 'xDl9ZF3SckkZde_48W6WeA',
#  4865: 'V_tKCEpP_3qqW1HxZIGoFg',
#  4872: 'nTvjhx6NrJ8NO6f4PRsC2g',
#  4879: '09NVex09nnEpFwyC64L3uA',
#  4886: 'FnjSFfC54WTP4Th-z6R51Q',
#  4893: 'GWva6TXiI4ZYejGTx4gqiQ',
#  4900: '-n3ix9WOotqgPYVYl_lPiQ',
#  4907: 'B-_t8vBjCyWMabZJ8Sq31Q',
#  4914: 'PLtetfZ5bkC5KUWttNF5XA',
#  4921: 'hF567DSTlBPbA01fgxW4AQ',
#  4928: 'LSDFWfjJaHVyOk-zRBFEjg',
#  4935: 'C23IQ8Ww_UCgy_TwiIZtAw',
#  4942: 'sHtfBnr7lZrx8-IE1eUqJw',
#  4949: 'mQYdpkb3u50-Gbln9gQ0hg',
#  4956: 'I9J9ZyRECxxCyIYRkHbiLw',
#  4963: 'bI3Cc6-8xY55fxy4z8ObQA',
#  4970: 'xAn9rQHLv_-i3NEhpg0meA',
#  4977: 'qa4uoDYHg1BqJjTliKUgww',
#  4984: 'vS_mVPju9reeXQEvxhSQSw',
#  4991: 'XF2WWA7gz1JmXeuyeaCkCw',
#  4998: 'oKaM5MTlyYb_ptyz8U_ZPA',
#  5005: 'OiyUzLMHBj557HVdnunqyw',
#  5012: '8fGunbW6HyL9tDlHN_hYMA',
#  5019: 'x53Dwd0eSh8wuqCI7_fVLQ',
#  5026: '8EVCarfyVLP14hlS4HVk1w',
#  5033: 'LENjgh6DA-FzyvU5x0qwGw',
#  5040: 'tw1LFY_ar-zCyQFzYJrE7A',
#  5047: '3SwUYa59T3I98J6L2HDa4w',
#  5054: 'Hw9-1neH2NYE4LurFt5mAg',
#  5061: 'g1B7jx15jMKXPS0M3fyutQ',
#  5068: 'fhSX9sx0qUF_t4lzuSbgfA',
#  5075: 'V0bVqTKLs8uDI0mbgo6_2w',
#  5082: 'YxnbFcpQTZ0FxsAjk1GoQA',
#  5089: 'cTGsiGLKDQcOwcYx2cq0Zw',
#  5096: 'butsaUQSfW-ZyxqQG7Q3tg',
#  5103: 'ZRUmVAeJGC_pBUbHCk_E8g',
#  5110: 'mgX7RiyezBMCTMIhNhUfaw',
#  5117: 'MnAXxybXr7vBo_N29h4cRA',
#  5124: 'pE_fDlgoawifU-Hus36HFA',
#  5131: 'GURlNerPhi-AfsPUuUR7pQ',
#  5138: 'llpQo7TRQFcGc_vmsdmw9Q',
#  5145: 'dzvcvTXGoIfKcbz2f6PhOg',
#  5152: 'Bkwvqux_O2eoA08KZQL5oQ',
#  5159: '0FM5huNJ9w3buvF4R4iSQQ',
#  5166: 'tzQtx71uULQymkUFgR_mbQ',
#  5173: 'EkUOdHnL_-60VGfW0LDbiA',
#  5180: 'xKjMoTsXpwUPfeBra_wlyw',
#  5187: 'nhs5ZoHhR6uZSu5HlpHwUg',
#  5194: 'Cqn_766h_JpQoV6fwizJhg',
#  5201: 'fcvzSxAxZuqqmvtfdmLjLg',
#  5208: 'blKZVgjdTT0fx8mqr0f6AA',
#  5215: 'E0FFOh5xUIuGuEX-grWd5g',
#  5222: 'eBfQ8ABqB7PJ1yl8d6Ll3w',
#  5229: 'y5viGCfJnQeE1DeKWaYWBw',
#  5236: '-AjfqnmCyTCSu1wwGsq7Hw',
#  5243: 'h7ZQMxTSSCsqBe8tOAsxFA',
#  5250: 'TrU5WKJx4wuq9683pARfSQ',
#  5257: 'Oi3Obr9i65lx4VQ_pghO2g',
#  5264: 'I5fxA7wc4ZajJ4yzTdIVpQ',
#  5271: 'Oa_SM7GEwFCebICeb6zVQA',
#  5278: 'MZF9Cn_oeHm7GTEwF31LOw',
#  5285: 'KQJWB7O83DjGK-ClKcdErA',
#  5292: 'ZbuqfYm-iNkd9nCwmruyJA',
#  5299: 'i96u6qXh43hQ5DVzeQlFdA',
#  5306: '4rg-rTjYpnEjNOqi-ej4RA',
#  5313: 'ztPSSDRbDVuBWlPFRGnnqg',
#  5320: 'HSFNX22WX7igCY-f6kv2_Q',
#  5327: 'GvB4jxX_TTzICMFeKbxEUQ',
#  5334: '2LsOAeGQ_V0hmtOVTockBg',
#  5341: 'jZy74lvSSFHV9Ls9UV9TKg',
#  5348: 'hOzOTyBQHk4WXmiTGaOy4Q',
#  5355: 'I0j8YqgqWhSujWu2PNqTtQ',
#  5362: 'swocJWD8R1iH20-lveXh0Q',
#  5369: 'P_Jv8vuqPL4iACf_Evy7TQ',
#  5376: 'C2YL2atNCwZGG4PUZHiIzA',
#  5383: 'Kmiu0dzeWTBbp_HZomF5KQ',
#  5390: 'bXmJD9Xcr8H1wgIkjC1Blw',
#  5397: 'fxqvyXlml4400BglsxRG_w',
#  5404: 'Yx-hGOItB8WQgIrmEFujuQ',
#  5411: 'ulLNJBYJz_2Pu4uG_BeqoQ',
#  5418: 'o7JJTi3oEtFfgRoVUTd8zw',
#  5425: 'BLoVhGRdJCeqBKZ2o-ZTFQ',
#  5432: 'tTilu3fgu4b0CUBI2F_EXg',
#  5439: 'orgS5g1U22o-XPnA77bKeg',
#  5446: 'ULafEAmIRrcv1hRAUlqiMg',
#  5453: 'wwmJ56OlvMC_Z8llXTd6mA',
#  5460: 'E9qtLQ6PxjiIbswRJCMqAg',
#  5467: '7bnEx6G86DSfS9oUf5UIew',
#  5474: 'R2kcGAHE74vVNZ0FJlFKCg',
#  5481: 'l6QdJ9_1PwjZuxoxqGjq8Q',
#  5488: 'VYQxNSsFcWQrRf1cPtlc0g',
#  5495: 'f5gw3C3jHrytKt69RB9eDA',
#  5502: 'oN1rCB9IHGwDhvzTlpbFfQ',
#  5509: '6CXfLUcXIftWP-k7yTZalg',
#  5516: 'DR7KoX4alg12vwIOnKjxbg',
#  5523: 'Hw4UIeaqLNfZ7TfbdS36zA',
#  5530: 'JrRoxqBtLM_CXywwPwoRIA',
#  5537: 'gBDSvkP75x46rVJZmxhvVQ',
#  5544: '7e9ReRfPBmfgchYNkbk93g',
#  5551: 'BmMJGVW2b6E0yQs497KUEg',
#  5558: 'eSlOI3GhroEtcbaD_nFXJQ',
#  5565: 'iAk617lLNH2M2FRxMHAxNQ',
#  5572: 'GwkWzDZ7PU_9AYtugYCS9w',
#  5579: '3t6fHJFiXO5hTqAIfNRIsg',
#  5586: '0G-bcpdR48tfZy6koGUiTQ',
#  5593: '0cbQ_k3g1AWiM4tDgPIrHw',
#  5600: 'FNcNfJCuOkIHOyQAdaPkHA',
#  5607: 'UXC-jYkm09HQnd6-GCdn_w',
#  5614: 'Wom5ss-owNYkxSy_j4s39A',
#  5621: 'OrYgrJcq43BYrOxuqSumBQ',
#  5628: 'VtLdzz_1olnpRU6AuSsEVg',
#  5635: 'LMjgLqaWa6uS7sjo9EWVig',
#  5642: 'uAb_Pcsqmjk5vLTiGbKfeQ',
#  5649: 'n4LLX8dmys2Ml74tRUpwrg',
#  5656: 'vaqJmwSN4R9-EIIyytCXMQ',
#  5663: 'NJqmAzerpbAIC0-VBclwgA',
#  5670: 'ISY_DfkcYDsjI6B4C0yVbQ',
#  5677: '6DKZbqhMFrk9fidrFtUqmw',
#  5684: 'M6GwVbo9pvnBfq7IGB2tCA',
#  5691: 'Tnr3D0nj8vjUBQGct80t6Q',
#  5698: 'dsu43n2DOR_pB07P1sOOZg',
#  5705: 'edWdmMroLOYQoM-cUWDa0Q',
#  5712: 'xYgdYioZpHUxApiddFhCxg',
#  5719: 'Mkq0w1GrgErIjGidBBidOQ',
#  5726: '0kAqAi3Jp3ieTRglPFQytQ',
#  5733: 'Y3G6XeZ589qu4jY3aiSyUg',
#  5740: 'X6rimtLNwVq7xp_CdBGXFA',
#  5747: 'WXk9DE9hJ1seQ0XTz_aeeA',
#  5754: 'we65oRo5u6g7nGXpY9H3qQ',
#  5761: '5Cp6MX8pn9MzsD559QpVfA',
#  5768: 'uPr3t2M-OykA8M_oro7j1A',
#  5775: 'YXz1LkAJJrJxS50QQ0kAsg',
#  5782: 'mKl0XBCWrNQEMgaHHmcNPg',
#  5789: 'upd0bAa7lGk6aZfWrResQQ',
#  5796: 'wxqxIOP9SoqKY3ZxvKchqg',
#  5803: 'LYkfMgLxtBPue63P4h1Oug',
#  5810: 'NvPOZM1HEW-8SrWGyc2TcQ',
#  5817: 'HpQ6AMW-v2iDFPOE6fkm0Q',
#  5824: 'p_IFsK4pHTKz1f6d2vUN_A',
#  5831: 'tqJxu8-N-PWiuZn30HTwng',
#  5838: 'PounMo8OdcaeGNqiLQ6-uQ',
#  5845: 'fcJ9JoxCnZ09QB6RqVx-dw',
#  5852: 'cVrM2BvOvPV0Vi_rC8kepQ',
#  5859: 'Xo1IpSNvNhOwyFm_tN4sug',
#  5866: 'qanvMcXCDySnEzlOfajBCA',
#  5873: '0iTIPfNx0e4HMnLVj-U9fQ',
#  5880: 'RinuHWn8JjorFscPAm94bw',
#  5887: 'whqfWVBj4x5EDboIVDOymQ',
#  5894: 'eBoyunRiJb-QzwQbv1-1bw',
#  5901: 'wbvjiDpw0FoZDeqbzAIcDQ',
#  5908: 'lTuK6Ypi0uBO2zSf2_WmSQ',
#  5915: 'iYUOZXTYvCYb0of2hL479A',
#  5922: 'mmGPP_jCUq4iiCvjcvXm3A',
#  5929: 'InBIEqapQwtm2u3mq1TQUg',
#  5936: 'wbnDLyFzq-MTde6usZt16w',
#  5943: 'DVS5ceHCDMDt8o5zvv6chg',
#  5950: '2DCMspkT8tmUESEYqA1KqQ',
#  5957: 'BoTcdg0hJS5xhn9HTZG70w',
#  5964: 'iCwuiqyi0m4_biZmkiRRNQ',
#  5971: 'RZxtWxOE7ujjCshdLxQBAA',
#  5978: 'bvqHgljyXw30FAQp1UrHSg',
#  5985: 'DjPfXJWuJYow41B0aHBLAA',
#  5992: '8-LYTAadaIZVn_RCXNEBGg',
#  5999: '5ovc1UdAcdqNM6_gjHM0uw',
#  6006: 'Ljx3xrHYtjSgM8fYiyowMw',
#  6013: 'gk8huqMUvb9reTLOI_yAWQ',
#  6020: '1i_Ygb-L3lWATRJuUyaAxA',
#  6027: 'qnlw8Zm5XM-aWo1zUzB7ww',
#  6034: 'MZoGuvWS3nRqdlg3OxJdgQ',
#  6041: 'hhKwALl0hU1m1SHV7fdHhg',
#  6048: '_XuODOyKJ4G7Nt3Tqk9HlQ',
#  6055: '5UavHXD5IGFw-eSlf5rxIQ',
#  6062: 'fPxE0VgahKU0Xh6YQt2-Kw',
#  6069: 'sUkp3gaMsuWUS4tlvWQj4Q',
#  6076: '7PSEB3s-y8Nppr_7sSlamg',
#  6083: 'dsalGc2bEIVMHYJ8zOP-aQ',
#  6090: 'bK4Y_GZUoAUTXIrmeEUGYw',
#  6097: '0vxYuuiQBvZhApojPINzsQ',
#  6104: 'XE36pmSiByd4YtSiPkn9_A',
#  6111: '3urKHr32KugnoXPjx-kY4Q',
#  6118: 'hXKwwnLCJdIA1kOc_cTxBw',
#  6125: 'ImtfcdUBNfBpPJwrKQH3JQ',
#  6132: '7DJTvRQtHDYvYJA3x94shg',
#  6139: 'o08HY1gCIuROxhThZDZgyQ',
#  6146: 'WvtjSCgt7283c4wL-Znx_Q',
#  6153: '1e6e8f0nwaA2ga25F6umxw',
#  6160: 'bf54Zx8QP9DxM0TXjV1WRQ',
#  6167: 'oBOTde_uEobbnUcgU9wfDg',
#  6174: 'Ts19Rb7uH2MimLjJEnw5Kw',
#  6181: 'x6BbbotUNpCEe5pWfAoBnw',
#  6188: 'MA_QyIk_DpQcX9aaEXXVlw',
#  6195: 'iLLbhhpiytfYauVRLUJ5XQ',
#  6202: 'g83PmTlii_s4yTokVgVRHw',
#  6209: 'fezf-fpb0Qw2B5ICrQ44CQ',
#  6216: 'GYt3ZTKeIj0pRyNfbX9yqA',
#  6223: 'fD8myvZsPcNO0SbpUQeOAw',
#  6230: 'FrXqoFcQqh0UYCvHQTfu-w',
#  6237: 'EnttXKyhOn4fW3Vwrx5RDg',
#  6244: '4Mbri1GnqEPj6ZTDB9u-Wg',
#  6251: 'YWsfD_3-Y6n1GWYADqCcdA',
#  6258: 'QEpNF4Hag6_W9Stc-1Frvg',
#  6265: 'svLQLyFd6lqFf73QZtS5JA',
#  6272: 'AZAQvl1l36E76r8Gva_k4Q',
#  6279: 'ySFWVG4rstXTxb2Od_3hfw',
#  6286: 'Vmb_1iK9OTk3w4ObHlSRGg',
#  6293: '_-gnSzjvS0lAwuvpUdJoyA',
#  6300: 'HAot-CWVjJV6EiZl0WXUSw',
#  6307: 'b-NbCSMmoKtoDtDWwpIhOg',
#  6314: '9AE7Cbe8xi4d16g8XJPdQg',
#  6321: 'eROIJUHTg7f8s2MM2HWLvg',
#  6328: '0NvdVbzbnFTtL7MfEy0G-A',
#  6335: 'ZQVtjdkuUGBDxVMCA80guQ',
#  6342: '_jfxvOnTeDBMkbLblUy56g',
#  6349: 'alRqBnKU_4PUTvGW34Bowg',
#  6356: 'LNLDqexYQC_R60TR13otHA',
#  6363: 'xGxHoeO2Vps9SL8NT6eD5w',
#  6370: '49WXOZ6E8yd_-BDbrg7j5Q',
#  6377: '1mcspXwi0cnbu0_4VJf2Uw',
#  6384: 'G4rYb3ZDC_y58UbX_mxj0A',
#  6391: 'TXb_wkHOsAGZhACfs2UIVg',
#  6398: 'S0Gt7mlAatrbZ7fXBUW9iA',
#  6405: 'x4ecUpNTuN2dNLmRde0WHA',
#  6412: '1PBlkVM9klC3YGpha9Xp4Q',
#  6419: 'myimAha7AXC1mOcMWcFmjg',
#  6426: 'AfyTxXRy261OPA2V5slQrQ',
#  6433: 'am5T0hZBAtE0OPNIv4zbeg',
#  6440: 'Zx__0Ef61cdNO89mINsmPg',
#  6447: 'mrdVskpxG55rxSIzwpbz-w',
#  6454: 'uFJh_X1XCr8gl0cYI67i6w',
#  6461: 'GRbhwB8tFdvaifX6Px3HbA',
#  6468: '7vQ072EpOMoBl2RDOZboUw',
#  6475: 'HmMedCwbr0j-Mle67x7aoA',
#  6482: 'VQFG40gBfnlSd6qhdK9_Iw',
#  6489: 'JU54PFtLnY-zZweOrxsmvw',
#  6496: '0iQZe0WK_7YvtNFOt91dXg',
#  6503: '92vW5zFtlrcC6mqFSpJYFA',
#  6510: 'urThcqroWgGhtyArBz0Yzg',
#  6517: '6vQbM0xmER_HOhlAtArrkw',
#  6524: '-TT3i86qTIPa3A143KlqAw',
#  6531: 'qvPTw-ArHYI1n1n0cw3S7A',
#  6538: 'oxnj45lwk_LUiQ6pUKd63A',
#  6545: 'Tyys_z2heg3GAT3N-WOFxg',
#  6552: 'g7RzHSoh4o26P4Ops8R-FA',
#  6559: 'DeFeQ6QRD9pgPHPhHK3LfA',
#  6566: '0PA5Gns9Xk5l515VdtgZAg',
#  6573: 'ie22n7be186IahWzLEJKSw',
#  6580: '6BbAgshnFXyX2jx1F59Y8Q',
#  6587: '-MgVSbGH4EP1IBlian06XA',
#  6594: 'z2_lj_Moul856_ikPe-svA',
#  6601: 'DrGHapbzU_GXhfNkWQKLUg',
#  6608: 'pUv9qATl3D-w7gLWLEBmzw',
#  6615: 'h9K141zyGaeGuMviHe-cNw',
#  6622: 'FtfNYgcCJc4MCx8HSGtwSg',
#  6629: 'MswMUSnowo3XFiMln8eY-g',
#  6636: 'lPXLs9UG_jv46FDlsMBI4w',
#  6643: 'jlIlwCNlIxChcrVjEUBVtw',
#  6650: 'aGnfzRmdNZ7JqM--8tLXjA',
#  6657: 'RwnGjRe_iwGVw2IiADb1cA',
#  6664: 'mCIeAcb4fdXRbaWNfHSfsQ',
#  6671: 'haYikT8axUlLyNS7k-osng',
#  6678: 'hO7NoN7bBAc7E0tr4Ge0-g',
#  6685: 'GwlypZv5mD2gXj14kpzXdw',
#  6692: 'sjSXoxakmlFuVHQlpoxMZA',
#  6699: 'Xh-Zy5ao-s5bbKrwSGcrbA',
#  6706: 'qWALyXKhVGr-nvycSRxCXQ',
#  6713: '_XqiHHfhwn_bvpG4_jRAVQ',
#  6720: 'bHLJS1Z6FE6zvu2uCzVw8Q',
#  6727: 'uaeU6FBaY5by7V1Cj_2RpQ',
#  6734: 'EcD8tHm3WNgOj6Z79pv2Kg',
#  6741: 'I_nPohNVSN8vDlcEnNC-sA',
#  6748: 'js4ca2QyjLrp09ZVoOKrUg',
#  6755: 'fFcdZ6EYSHUAzKMM8EpNHQ',
#  6762: 'WcjuieI0ifaZdATM1fQM9g',
#  6769: 'uNREzUtk4h_ZRBoWz8vPkQ',
#  6776: 'TLh735J1_tZ__snlxnIQMg',
#  6783: 'OhsCg_yTTSUiRvkTGiPyog',
#  6790: 'h671cjhCtwU_-7LS7pID5w',
#  6797: 'Zzf15Epedbhb6WjG2qgHDg',
#  6804: 'sWGjm6zG5wSrrLofhcULfg',
#  6811: '7OO9MwVmyLlYsBKAJ190lw',
#  6818: 'D9Nph-_t__mLrXmeejEU5Q',
#  6825: 'drRKxFz7aO0vuaoL9Aun5w',
#  6832: 'bmkY1SQMoOBq2jpn4sjEtA',
#  6839: 'Lf5xK1EaU1QT-3L75m91Zw',
#  6846: 'k0Of8z7-V-Muv_mCR5X__g',
#  6853: 'sXWVLQrqPWHXAsKNL82MPQ',
#  6860: 'kTi96LP1DxwlFTe9jqkayQ',
#  6867: '65x9iJk_V8vJwW5tualmpw',
#  6874: 'ciclgWBO82cISxlZctTwUQ',
#  6881: 'zxeCem7KBuWScBGP7NVepQ',
#  6888: 'GIkEueeahJdLXziC4yqbUw',
#  6895: '-gbrMGqujnPCBTD8_8EcoA',
#  6902: 'QD6G-54FXkMfPNeslMIb_A',
#  6909: 'JY_--xgbF2WYzGywcFKf0A',
#  6916: 'S4z-xLmyI2dGmGmsGYL0jg',
#  6923: 'hVXj8lnaTIMLTkD_yjSj6A',
#  6930: '4_59lHC-lkWv2lPpaD8YbQ',
#  6937: 'eXD5soPfeNcRDOaTluzGNQ',
#  6944: 'OkTRWdojomdRDtKjSL55YA',
#  6951: 'KL9woBwyw9qVBxWwnKm1sA',
#  6958: 'epirgQdxVdYnx8LO3fmbwQ',
#  6965: 'GatGN-sRz4HmqjMDCZ6JBQ',
#  6972: '4C7SEdWtByQtNQFC6sTKyQ',
#  6979: 'kLpSvFx55rvjajtauhCC6g',
#  6986: 'rWf9Z1Z2LwoZ6IDUxZ4fYA',
#  6993: 'bBkBuhndCIngB4fzBQmbTQ',
#  ...}

# %%
num_to_biz_dict
# Out:
# {0: 'tJRDll5yqpZwehenzE2cSg',
#  7: 'k7WRPbDd7rztjHcGGkEjlw',
#  14: '8qNOI6Q1-rJrvWWD5Btz6w',
#  21: 'c5NHHW0sNm7eaQBwvQJkkw',
#  28: 'JzB7NITHQ7gVHGVZ1ntgIQ',
#  35: '3pQ4KSnOX9Y2IEMJvGFxUg',
#  42: '-VruCC0mPOyZXW1MfQLkQA',
#  49: 'N_IytPmdrTc9yn3tWPFtQg',
#  56: 'QFPS9JBNdOOHVP0C3pSslw',
#  63: 'GAmd3nHx5TInVN26PLZj7g',
#  70: '4FFhq0e4bxAG4uXqgT14jQ',
#  77: 'EbxaQO95C7PUNTmokE70XA',
#  84: 'eDusRHhrFW_Y555LjQrlzw',
#  91: 'T3syhQWse9WtFMoWk-oN6g',
#  98: 'I-D4qEtJJ4okSLrLKxMMRw',
#  105: 'Tzp6kdtA7coJgnY3-hFHtw',
#  112: '_R1jBQQieKpNGMBqmrLRyA',
#  119: 'DBtmJXpwS31E0cDZo7ypGw',
#  126: 'gh6__q2WXFuyN8gt6VAnWw',
#  133: 'PrNdvlxp2E-PKqQTy6IGfA',
#  140: 'uSVSllAbQ71Aenmdy0r3Rw',
#  147: 'w4T8CLarUWVjjRuOK9wKpw',
#  154: 'JxSmlL_MckX0dvS5XBg0Cg',
#  161: 'QqpzPFFHeHqyWSPZI-DkvQ',
#  168: 'CS7DuVN2YkWDU7aoeFj-og',
#  175: 'nlVjdQq9FzdQ3bfy-8y80g',
#  182: 'PJcOOjebn86geLXG2qPB_Q',
#  189: '2eVpkjDioFSgp2C27mSdHQ',
#  196: 'sHB4PVLgugU9TGfOdBvgqw',
#  203: 'VNOosvcE6HN_dqSTqRicXQ',
#  210: 'sJQszX3VVOpkQAwfIcjqzQ',
#  217: 'WnuRPyTEvILZKCAPk2UwYQ',
#  224: 'Bma7RgPLdDAFvycubjdVOA',
#  231: 'd0GmiP5cai20VZr0a_bNnQ',
#  238: 'txJkOk-oY900paWJQVGdVw',
#  245: 'uiOHK8a0gcEZFtffRVAmwA',
#  252: 'j3jkcLImva-T4ScqF1jvvg',
#  259: 'bfHsrYPH49fI7M1SHOYn8Q',
#  266: 'dTu69dJYUrxkJ4tg_48E-A',
#  273: 'jUatA3vF7cOA45mVxDIuWA',
#  280: 'inLDlmy0p2ZthCYQzGZVnw',
#  287: 'vgFZrMMs2X22aCmxt8LWSA',
#  294: 'rv8g9vf8z-J1aXhRlzjTnw',
#  301: 'KowfRkKCR1qYzIM3-M6FBA',
#  308: 'r78AHYzmDKDffJAwrB5aIg',
#  315: 'w1c_Uy60LSDiMsSjAsEqkw',
#  322: 'CDqPVVvQtVncNQGydnZy7A',
#  329: 'LM3DK2j8W8mmD5_zEEku3Q',
#  336: 'JetIYkfGQ4a3WQmiH_a92w',
#  343: 'ieE2q3Onr9blYYscePOBZg',
#  350: '4l56EXyCWwPlPXcX9qq-jw',
#  357: 'Ky0X7OLqSeBpvNNf0NjVcg',
#  364: 'LCrEGP25XEBDPmirFqd_xg',
#  371: 'VwGjGQe2kjK5yMvNOnomLA',
#  378: 'qKuRIro1X4LzqSfY1SASkw',
#  385: 'w-YZ755_a3SswPSeUwCdSg',
#  392: 'o1ZAzn5IZOLUhpEg2_rK6Q',
#  399: 'xSEcd_8XwH0H_3QXl11V8A',
#  406: 'a384anuGRsOe5IXclb3cNQ',
#  413: '_iUlt5rm-15QoLw0MEEg5A',
#  420: '7PRse3yCQbEprAj1DWrEQQ',
#  427: 'JlnDcCfvrmo_cv8OOzhuoQ',
#  434: 'ZVWSOxlmz1yJfbZaJwYOug',
#  441: 'SeQlCrKvyM2j8m_75gtouQ',
#  448: 'HVCSprTj_USR9HxIeoffZA',
#  455: '3B8hg3Arjhgz33SJpnK9Hw',
#  462: '74gDxr6rs_8tUTcS1vkr0Q',
#  469: 'mJ_ucQ2_3hfTsmCcKb-hgw',
#  476: 'siHpyAfAnoBMPpl9d_ib3A',
#  483: 'BkWF6Xz1KTT-r3fWbxEvjg',
#  490: 'FChZqoNWuLZr5Lj28Cq7yg',
#  497: 'c2YDEpYQ-2IqB57tN0HKbQ',
#  504: 'uV2HVSRXJMqGsF9Br2VnvQ',
#  511: 'eMIX3ldCrPJymVenND0sDg',
#  518: 'vpsc8vfnkaEd7-49_lz9Zg',
#  525: 'vGQxPGvI4QLtupSAxO8c7Q',
#  532: 'gfIVwp0RkM5yMa1u3mbB4Q',
#  539: 'K2C8dSx9215LLcIzHL959Q',
#  546: '7z2x16M7IuG8KPfMsyVrKA',
#  553: 'QIXz6e0SZ4okLBFBsO79_Q',
#  560: 'WdjZK2Zti8mXSXXLYt-aoQ',
#  567: 'Z2NIEKTVVP2nEmOF4jNxqQ',
#  574: 'FG8atOE15c8IoQH_hEb9zA',
#  581: '8FuzQ8WN5WKpBbyT2wBlYA',
#  588: 'QlSpPzc4Oy05ic-PsoYH4g',
#  595: 'SHlfx41Mo4dk2WR1VyT2_Q',
#  602: '4mYS-4UOjTKgsf0tX1_IkQ',
#  609: 'RqmORv3974ZDC6Zh4nSQwg',
#  616: 'ZwuHsufvw1x5rd2c-qyw2w',
#  623: 'erx8tQ0Wdc5YM0FddaKqKA',
#  630: '9CcUyTF8NAkl1bd_eWX7gA',
#  637: 'ndzT1maiVwpz-7VFFzAb5Q',
#  644: 'XgkTmVrlHHO5g96AfOAfpw',
#  651: 'YJA8z0m0B8K9zQrmBoHaeA',
#  658: 'a5mpYojV1dX7XCkAa1qq1A',
#  665: 'MdjZQiYwl8tljeAbx_fFZQ',
#  672: 'JXf04dg9EBlkQFs5hf4QeQ',
#  679: 'UkylJaNbvMENvL61dgwdLg',
#  686: 'bywPKk3pvRBxwMWrFVD7Lw',
#  693: 'b2ZukyGCS7xDlv0ZAlXdYg',
#  700: 'P-HsvYoqSalFAvEHXkIGPg',
#  707: 'gAe_dOlcAd6tEXDUXNiwOA',
#  714: 'kBd3_wYt0BX-RfS8ymUTfQ',
#  721: '3glVZZh_vyZH1VvPU0307A',
#  728: 'FyXDeBswn5cNmK355tTRrg',
#  735: 'bdNyoXY4yJ99derJRqhP3Q',
#  742: 'BskUTTscZ1XGa9ev7TlfeQ',
#  749: '4-QlcyLqRc8To15oOHUjkg',
#  756: 'rxpiO3CB5323XsBVzMB7nw',
#  763: 'EWJbWp3oOwDsv4Lo5eZWxw',
#  770: 'e9KXojla4OuVP7qcC5LNsg',
#  777: 'Eg_M8eeu9SDEdbP7iUmVbQ',
#  784: 'Chr3YCuvt2mD-BHgqeo-OA',
#  791: '1HtxtLaFgTeerAuF9Q5jRQ',
#  798: 'AThUjgEmgHgVdD242hjsAg',
#  805: 'e5sv-sFnoxzitw4fTpPi6w',
#  812: '1pUHPWwAXGFF59SgjyuDAQ',
#  819: 'N8XzoYh6rEdOGL3ZsM0E2A',
#  826: 'gxi-tnX_ze-VTYAVSyvEpA',
#  833: 'hyJboRkFYvJ8kaMY9ZvUGg',
#  840: 'av_-ePHJwSSqMtTQbNoL7g',
#  847: '0IfrcGbFzQvn9w8bl9GKDg',
#  854: '7Qpn2DvgIUpOJQdI4DXETQ',
#  861: 'rZrbLOKfbCawyE13x4AW5w',
#  868: 'AMGe9WK6bxiEkTYNj_cx0w',
#  875: 'FzjluWtXjZqcfXGIrGmVJQ',
#  882: 'FgTzITgrmvrZqoHvkTSDzA',
#  889: 'jZeuTSj4lR2_Y7oHOkP0gw',
#  896: 'L4r6klm7FG4QBbNe8gu5-A',
#  903: 'Y2cwQRPlyf5GKJ88kLOntA',
#  910: '3H1I31BQeHO017Sg92Cbow',
#  917: 'r_8ZJXfVrdh5P4SPt9WYKA',
#  924: 'WoPfxF4x9AWH9SxOJtCPFg',
#  931: 'zViJBFU2FRMNqQljzCV-aQ',
#  938: '6C6GRESqx2bDxgMHN7LUXg',
#  945: 'lROJiqgLEKjYcI07lVNqwA',
#  952: 'D2AKQk8X-SjSRHc1jzISIg',
#  959: '0vAHRd4Xlsdx3fHV8JCRBQ',
#  966: 'GvBGYrTb6HKMA50TuVQztA',
#  973: 'QQIwwU1tyOyKwr_sgqfYmw',
#  980: 'eF2jf-E5ktRQIh_4_-Jxsg',
#  987: 'kIaqY45GaVX136dXomREcg',
#  994: '74wRr6PP6lbaL1YzUcYGAA',
#  1001: '4CbLjvhMy2vpK0bGYq3QXg',
#  1008: 'usFNFsaaHFxEbnBO4FaFHA',
#  1015: '4c19YWOjPmbFUK4-V2GEvg',
#  1022: 'u_8cVZyxh0J468zEZUjNDQ',
#  1029: 'G-5kEa6E6PD5fkBRuA7k9Q',
#  1036: '8mpIro7yAzGIlFZ4oVowBA',
#  1043: 'M6n7INwzxyrmLXHhNV-EIA',
#  1050: 'v9Itp_3tOuY9ByW0caWjbg',
#  1057: 'IL3qkg22Zb0s8B9aJYle9w',
#  1064: 'aHuGV6FS0j8_1_p9vFeNuA',
#  1071: 'lk02Yf1xJ-8Fg2b-2fTZow',
#  1078: 'BHsxZ_ezdMVg78XDMMOvsw',
#  1085: 'qjnJFZtsY_nfRzoL3J_UWQ',
#  1092: 'yz3JQk5Lqbin8mtNfDcy_w',
#  1099: 'oubCbnF9Ugh1vIGjRxQaVg',
#  1106: 'fT6Uwl6abRQfiNgxre_qbg',
#  1113: 'Q3YlWorh2rfASnZ6mbqlEA',
#  1120: 'o9IvrLWtTt5lCYqO-uiJLg',
#  1127: '-sAr-LA9TsIdl37UjwBlvg',
#  1134: 'XYn6ZscbPeNnOQ7eaaFNFw',
#  1141: 'pC1hkqLcrXBxrs7YgfkJ3A',
#  1148: '_n3w5BK4-k7iXCWifCjUZg',
#  1155: 'Ezt1S9niDIiiOsN8b5Dkvw',
#  1162: 'Qa6JB5oJr6w9vjab5P1eMA',
#  1169: 'seYvTmOZGJ2IAMdfQa8pkg',
#  1176: 'k346E5EyDnBrqOwrP8xf8g',
#  1183: 'scspcYwE-SqrSASWmOJNtw',
#  1190: '50Ull2QxpgNT21vB_KBZ9g',
#  1197: 'hPJgmPd3ADBhcDBP3aAKVw',
#  1204: 'cTJjTKz2huGZ-ElScC2pSw',
#  1211: 'QARy4UUOQogMjDp9jP-YVg',
#  1218: 'Cuc2mtRjxa7hPo1SGYD6UQ',
#  1225: 'X2f2s37_cFKo4xpzGFqk1w',
#  1232: 'YjJnGaqvCpxspBLxXrOA9w',
#  1239: 'ZfiU0tULRlH_DasCpi9Sgg',
#  1246: '2nSlEIS7wwOFc4nwTsF7Hg',
#  1253: 'ETFKj1VSHn5zTNddOz6FRQ',
#  1260: '5B-V6vr6TbtMjrRaBAtHqQ',
#  1267: 'M10n-ivjDkkdLaxIYNafFQ',
#  1274: 'DQfZM9b3n3DDMzEg4b4WhA',
#  1281: '_d7ySCr1d4k-NmDsdNTqgQ',
#  1288: 'YrFYBMWnRWkRpy9XyMfMRw',
#  1295: 'F1PVqJKljZcpOZU7Otua6g',
#  1302: 'WbjfPBLko5z1-OFWQ-jDsQ',
#  1309: 'Pn1f4xiZoynF0nDb-vtY0A',
#  1316: '6b5RLz7szHcSTGKjvKWR_w',
#  1323: 'yfxDa8RFOvJPQh0rNtakHA',
#  1330: 'BYX_65ag1N9E0Qp-KcgGrQ',
#  1337: 'JAaABhG2j_bJuVjfFIZWFw',
#  1344: 'VPeMRbFbSEUJqlu2dqo2Kg',
#  1351: '07gh-AImcEcWQ2bew-jprg',
#  1358: 'HaPwC4nxs6RPfe1pAQkQ4A',
#  1365: 'JWDiG0nSsM7GQ9QFRTxU9w',
#  1372: 'bPcqucuuClxYrIM8xWoArg',
#  1379: 'Mqc-4VlnZymZyVJ1VzL_Kg',
#  1386: 'rIeXMt92PLNjZbemWKRXcA',
#  1393: 'glKJGrTjFFky9USreDxUaA',
#  1400: 'PFQU2koM2WymKJh8O6UcoA',
#  1407: 'VVitum45kCla5xkyclh4uA',
#  1414: 'i851zomQeoY7gbrkFcvM7Q',
#  1421: '5TlkaYNie2xjv7nXW12Svg',
#  1428: 'Y5N4DKv-Vt_4b4KHVhCy6g',
#  1435: 'eMM-RgsmMGDxs353XpC3fw',
#  1442: 'BYc5IFQPq-PLVXnYjDp6vw',
#  1449: 'Sry_u4nONZmLLcGOc2t2uQ',
#  1456: 'po1LO9m-a3ilEPAacv5TYg',
#  1463: 'jd1rD7jr-_zI46Oxh5lDLA',
#  1470: 'Ul6JwluSTm12PVDIqnNaTg',
#  1477: 'hcFSc0OHgZJybnjQBrL_8Q',
#  1484: 'EzcrB9DhKtezASq7fZ6ZyA',
#  1491: 'H5PdoEWleg9uDU67ZAy6JA',
#  1498: '8vqAiSXLuBcQc38pbfE0Xw',
#  1505: 'pklva9BUEvq3jtPL8Y8KDQ',
#  1512: '0RhEds8SRYme4TbWZLuUxQ',
#  1519: '5k7HbIAamo1PG0uIYALuRQ',
#  1526: 'ZMvs7F5pGh-A4X2j9_W6kQ',
#  1533: 'RRv0cqZCk_pO1y4B0NnjyQ',
#  1540: '0X3tBvAUGUUDQJ9e5cUXrQ',
#  1547: 'lJbxQFXqbgKBdHPKKxROMQ',
#  1554: 'WUPEnedS_8si30yy4lwcAQ',
#  1561: 'cvELVLQ4jbS5Qqbm79IxVA',
#  1568: 'DwSFTVUZX0xIE6T54yp2JQ',
#  1575: 'S2OUblEc-GaZG8uaB5uFMA',
#  1582: 'oxb73l504iA68bWdHqymHQ',
#  1589: 'zqzR_i_3L0e-NMI9ls-SFg',
#  1596: 'pmePpiiObQzWZfgWV2POoQ',
#  1603: '29uuFClUJeEoq9ERQ4YUgA',
#  1610: 'wXNHLkDkh0HKGJeYVnpafQ',
#  1617: 'WWYFK5rTkQZMOBaRFP51Xg',
#  1624: '0PJQ-WR-S286xH6m2RWeQw',
#  1631: '8t8pZI5SAlYhd6UEIkAcSg',
#  1638: 'o5rtJcyJ6xje1PFj_rhRTA',
#  1645: 'nKEMfFrr83Mir4pYyaXM-g',
#  1652: 'uC4bN2InArpm0T9KPRh2ug',
#  1659: 'idp26EIeHO_FmJLIAjLJQQ',
#  1666: 'ryzdWzd4KErUOvd6MlT6pw',
#  1673: 'GghMYcxRa-idHDb6kqP4BA',
#  1680: 'dgMxiPFkqBnDQly9Ox183w',
#  1687: 'Hi9Mq6SkJRU9E0YzPAl7PQ',
#  1694: 'XzV11KRNHlUaIweyKH21wA',
#  1701: '93otbGHE0s0m-lU1osvg9w',
#  1708: 'ZFC3AIfxMYvvcdjp_J3xsg',
#  1715: 'AzFmvD634INCXO5mrmHThw',
#  1722: 'kVKmTqGHITk7IyASAkXqqA',
#  1729: 'L-mBbXm9lPJIXCweJhESKA',
#  1736: 'buTGupHVDXDJFBzDKIHGzA',
#  1743: 'Bk2fENDaxjFLsx2_W3XKAw',
#  1750: 'PKnJO6iXVuZrH8QwWTm40w',
#  1757: 'wY3dlpLa0BHfDENYAPYuZA',
#  1764: 'mtUscPpaEpOpdBWDGXuNcA',
#  1771: 'WymLKyWx3t9V3VfI7itMtA',
#  1778: 'go623pgRx2nfIpsV4ePHXg',
#  1785: 'GPzFpdUOkcqSs5aaDgml1w',
#  1792: 'q0n4I-zqiI47xispOqc1lA',
#  1799: 'F1CCt2Gl6qpOB73mXi5anA',
#  1806: 'fzPp9ZdDhOovfqH_-Ksk-A',
#  1813: 'HWmUHzxX3JvXkW3qh0SUng',
#  1820: 'bDUJb-CtKkVBSOzFTatFeA',
#  1827: 'N9n4bj5nnuvVgt8iyT5YVg',
#  1834: 'DUHIgv12tm8tW_CKT9-g6A',
#  1841: 'eDuQMHorChFKUu1Au-xhjg',
#  1848: 'BnMnAotMjCw7mYlYFZgCvQ',
#  1855: 'iWfyCpUY2EwcElD8DaFKeQ',
#  1862: 'iJ0X3Ze6nJk-hcoVKF3L6g',
#  1869: 'gae9LAyt7Qvf_OgAkWASxA',
#  1876: '6TgLfxfgEqoCbANmZqjnAQ',
#  1883: '2NXb5LHngfZppLDOZDEhSg',
#  1890: 'WG6GsWEbZe2guw-QOidMDQ',
#  1897: 'HhPVzZYQI-akaXRK_A4dKQ',
#  1904: 'ynKAUSYi3c8M-rkVJI1PcQ',
#  1911: 'VkeVbH5zcm0MBKuKtytGKw',
#  1918: 'T96EG2iK3ZSv9ACiSFw4cw',
#  1925: 'xEt6imdvYi-avmAp3norRw',
#  1932: 'jaQvdQnHnj3kBcsmAVu2CA',
#  1939: 'swfdlAMXwV8OjYD5nkA6nQ',
#  1946: 'PJyOcVCL07PTh-h7EwnaVg',
#  1953: 'JKM8N-qeXl_cLXOFRpevEA',
#  1960: 'kROYR_6mVfg9WgJ7z1HOSA',
#  1967: 'lrcMYPgo5K1GqZFTMGqQOw',
#  1974: 'p2Nr4d7-MS82opzRCNkbNA',
#  1981: '6sqfAMlX68kusvE_FsIr-w',
#  1988: 'oPvYovnl06fy5W0e51zjMQ',
#  1995: 'JJV1sSTQUni18rLn6TcsFA',
#  2002: '10NSeX03xC2th8-HGFq3sw',
#  2009: 'y90JVPFQ_TWGQaBhHtSm3w',
#  2016: 'fihXIqiJQsXAykSux5m-_g',
#  2023: '6wsAW-YkIpHkYpM1mbMD1w',
#  2030: '7m0smV1-RvM1GnWhCTjy7Q',
#  2037: 'qN1tev3ovOyxXXPJMOIC0Q',
#  2044: 'vMWOMRhbyLfdWR_Vshqp3g',
#  2051: 'l6ZrDTwUHZebCG3C9Va3Dw',
#  2058: 'cI8WrDPaI-q5RQs3yb2SmQ',
#  2065: 'g3iEUbELALvSi5c5yc8auw',
#  2072: 'XMNMDA4qO6HfEkHG9I2Qhw',
#  2079: '9jLLUuJ4Ehn3fXDFBfDlyA',
#  2086: 'npsdZ2QmIpVXObkM48_fAw',
#  2093: 'hODnmsq1kK6eA0VLbFQOVw',
#  2100: 'Eepah0Ni9iRx-W10PvkbBA',
#  2107: 'xjViuMrrApPM6Rnz8ovOVw',
#  2114: 'U8pnFAr4uoEGzNJHmAplJQ',
#  2121: 'pNmKwaQ_JDGNScnBCBIWUA',
#  2128: 'KvlaL5wejWOaZayBxP_vUQ',
#  2135: 'lLAifGVomWrO9yMSkBicNQ',
#  2142: 'dkZf0uiYn7Q573xUiMGsqw',
#  2149: 'KIyAce9_U9NUeUVQn8iLSA',
#  2156: 'thD0qgWDmvjOkX4LvA1JMQ',
#  2163: 'y_OJFv5he7x1EXsWNPHKVg',
#  2170: 'lv4erkIq2VCIOGC46T8TsQ',
#  2177: 'uE6hI5_i4QVq12xU99xtqA',
#  2184: 'zuUWG7OdMv6awFRYhEYT5Q',
#  2191: 'SN8w9w-UfKPv1tqEpNFWaw',
#  2198: 'z2RiCl_iU-8bM4Lj1zNL8g',
#  2205: '5KHvSQ9D85ZfBiTXQig4bg',
#  2212: 'nqTvE7ivdU23oUWdI01tOA',
#  2219: '-7bvsSGKnY6O-JmSWc5V6g',
#  2226: '5aeOewSy4RiI8sLLWpeNGA',
#  2233: 'AgIGsyUA0aKhUGFWOsI4AQ',
#  2240: 'OvgqCqGWHrRRxuAGUCE95Q',
#  2247: 'rUrv8zP2UENSO7FRQCOtmQ',
#  2254: 'OpNrObgtHgYijZYOU0yF-Q',
#  2261: 'gYY9U9CXRS12O-oUFoO0cg',
#  2268: 'VRMNW1GXYihRxEnr1UI8hA',
#  2275: 'n5yuDcNR0OygR1wkrvsUhA',
#  2282: 'mtHyTGs45610CPKCETQDEw',
#  2289: 'FR1youGHBIHL4cFWud7mOg',
#  2296: 'YwnkCrb45OKGCSLXmmCHlw',
#  2303: 'DQmEQkOhR4AwifvRPKqz_g',
#  2310: 'RA_Q__KAdk9rJqtAByUFjA',
#  2317: 'CS3ykvbERsTrVxL9HPoCOw',
#  2324: 'P2uPCEBP2VZsApnvEHCgag',
#  2331: 'H6skMpg_g-sOrfTQf_Q5LQ',
#  2338: 'm7VYGZ0dAPuliuUlxzGIjw',
#  2345: 'TC57bONe4THLJzmg48WJsw',
#  2352: 'qME1CvFxSrhqE6-YGcp3Rw',
#  2359: 'wAcmbZyRSwp3td-4Z6BvWQ',
#  2366: 'zRN6HzfkPS1REtGiZ60Pvg',
#  2373: 'plHKBwA18aWeP-TG8DC96Q',
#  2380: 'pf64nDX8AjuZybFT6s5sRQ',
#  2387: 'LFhkMq9DCSGpYI5Cdlpyiw',
#  2394: 'yk8fsGAw2xyEp28cm_1ejQ',
#  2401: 'e4HsCEpfXT3Djcgm8rSvSQ',
#  2408: '9heX2rwUIsos9fXDCpAltw',
#  2415: 'efa70i6arbgeIcZiRMZMRw',
#  2422: 'wkMxHM8JNal6kgzM3Xp8dA',
#  2429: 'IFr8JOyjuMjf0xrmAJmsVg',
#  2436: 'gFwTn0arRsgFh6ldTPlKMA',
#  2443: 'EHKzu5r2NEz5Zq2R84J4ow',
#  2450: '4tJiL2mHKO-erM6xoZji9Q',
#  2457: 'S2icYFHPsV_OSCvbI3YiTg',
#  2464: 'ZRLmQ3oAuspAkk5R6BOfyg',
#  2471: 'MSc5pybthcvHa0g_lg5wuQ',
#  2478: 'eyl5g8MzVLoFjhtSD9DTrw',
#  2485: 'yTv4ptghx8xrErx6dcW3HA',
#  2492: 'UUbxc3MsRQK3I300Y9bJIw',
#  2499: 'CRfYH3Tr5gtqS3Rml4qWIQ',
#  2506: 'sh2m2SXVZlFSpsTOCHftzQ',
#  2513: 'hWzbOi1-eS8PmPyZRV8Lew',
#  2520: '_vzNvnj8ob0hAk2QXEv3Mw',
#  2527: 'jb8eFF8pIqMKwu3jYMuJAg',
#  2534: 'But8zrzUE3-VGr5P6PLgxQ',
#  2541: 'BIqsItY0vyOshMpJ0I4cPg',
#  2548: 'kKTmF-zOqHemgDDem9_0DQ',
#  2555: 'Wxxvi3LZbHNIDwJ-ZimtnA',
#  2562: 'uanCi4OGc1mHLGl_AT4JhQ',
#  2569: 'hUu5im-iTpOvRHtqiuu_dg',
#  2576: 'XO2hZb0xC8jTexSHG4SxFg',
#  2583: 's4c_f9WwcolJTNitq2gWpQ',
#  2590: '1eJ7yIzSAjwC145fnHD5Xw',
#  2597: '3ZmGpETmJpUvEa7lVLn2kA',
#  2604: '9r4KEv7WahExaMDIcbZmYg',
#  2611: 'bQ-sXUqPSr4-iJfB764Nzw',
#  2618: 'VCncaRjqC6ZqUG7jAnODJQ',
#  2625: 'tyniJe6u80Z7QmWlX7Wmaw',
#  2632: 'xnmQ1-YwnQJiV4zrP2LDuw',
#  2639: 'qUqyi82OLmG3VMNMAxf9kw',
#  2646: 'Px6FNVLlN9wZQ-uadZiIcw',
#  2653: '85iB_0J9lCRI7jRtmsAlQA',
#  2660: '-d8gt_XhhUQh2CxlWJe-xw',
#  2667: 'X2lgI8CuVEsH5UDs14rMhw',
#  2674: 'err0FvoRGGSqORd8WRtppA',
#  2681: 'cmCSiSCmTCCH5zVkF1UiJg',
#  2688: 'XaeCGHZzsMwvFcHYq3q9sA',
#  2695: 'ndtSMHlCSKDtEBoOYAdL1Q',
#  2702: 'mifWkkAslOesWX-8Iv3Uhg',
#  2709: 'IdHIcxCFq84evujUVNcB5w',
#  2716: '9cuklQaqN2d3WA0Ef6jECg',
#  2723: 'BILDxxCeTdEinTWDGY3O8g',
#  2730: 'DGAf4J4hXbYiSML6hus3GQ',
#  2737: '20gnq2ZTGn05ZBXXs0aj1Q',
#  2744: 'rzByiKaj-bLeLz-zKNBQdg',
#  2751: 'hn3jQvvLNPB3QkQXEQHSSg',
#  2758: '8PketBhi3DllXR6hM2xsCw',
#  2765: 'h52xXFs7C2X10jR9Aec2NA',
#  2772: '8dAmtiVtZjiRTmDq9QAW5w',
#  2779: 'JpU4vB4twBCe73VN-S7ARA',
#  2786: 'u5zn7j2Pt4doF4wJWOVtbA',
#  2793: 'Uz5BTOmRr9Za2btfFq9JWg',
#  2800: 'm-_3sNY0eLsPp__2C647oA',
#  2807: 'inRKr1zy12CoZmnK-0IRBQ',
#  2814: 'C-88Y8Eydcq9OY3cek--ug',
#  2821: 'Tfpl122z03sp7fPi63Suag',
#  2828: '4AxW2xYpZker9biX6Bg38Q',
#  2835: 'QocKybO6HW2kiaA0et2NWA',
#  2842: 'OU80zeb6HbcuxZT5pct90w',
#  2849: 'v1Ni_SpHYXBxk2fjAkXZ6w',
#  2856: 'aHsjXvac2y8ZpzzOLTPRBg',
#  2863: '-0dWjxaPKrXAn8urSnkSLA',
#  2870: '43xg_y4Fppi2uBydfBAlEw',
#  2877: '5It12biyGxe2Dz6kkf7wGQ',
#  2884: 'fw2V7tFKHQlhHy4bNoSyXg',
#  2891: 'P8nY22PirIp-d1GpDn7qnA',
#  2898: 't_eyLFOgTRXTsgXKo5WDqA',
#  2905: 'lK5apgGrWJkB1awSL5twkw',
#  2912: 'FoE4UrH-Zg8EcNwuJgZWGA',
#  2919: 'tcOP56tZe6hlmdUHX2EH5A',
#  2926: 'W0_gyFpsH0XRP54UobN23g',
#  2933: 'sQgyIZq8F4lG87K_zT3Sxg',
#  2940: '8L8QlR4XJeAblTKCqoDP0A',
#  2947: 'GWlESJxGp0UwPAzimAno3A',
#  2954: 'hHZ1epe7qG14T0B7fguNHw',
#  2961: 'sro9D0YFB-FJyRVLQls1QA',
#  2968: 'QT4ax7JkGZma8oMy5j8t2w',
#  2975: 'e2zO5THDYoDOcyXcWnQv5w',
#  2982: 'hyc5Cg9CJS_ZBuN5OBnC7Q',
#  2989: '1DSEqxx6wxF2zwpPDBwtOg',
#  2996: '23gakZ_NlN3K0SqOBybwug',
#  3003: 'bgcnrM6fbsWIR8amscTQNA',
#  3010: 'rBc22J8NWwN9enF-IQNrTg',
#  3017: 'GVnaMB4Kgg6i04-HRkEa1w',
#  3024: '9cGvOaA1BYw-ByOXjNbu9A',
#  3031: '1jMtot685bxNT7oeSTNCaA',
#  3038: 'v_gCDktW0mMf7pf-jktKzw',
#  3045: 'QImq3SdlFe__1cWMcYBYDg',
#  3052: '1sJs8rfowekLK_yDWB9ocg',
#  3059: 'OBmBMG5bUADvibgbxmVfLg',
#  3066: 'tczCMEtm1-9qNrphMAjQnA',
#  3073: 'F6Q0crsEVEWsfgSpbI-plQ',
#  3080: 'FKJ85T_sZdJXVPJjMOWi3Q',
#  3087: 'ohvif9kmvgq_p0pCT8wdKw',
#  3094: '-x2NjuDTiphKwCixSrv_SQ',
#  3101: '1EqSm7nOAS0s7gYnRaOQYQ',
#  3108: 'C5zOHpwyA-snVGppkbUpQg',
#  3115: 'wFS7Brh_U2QVorbCAS8zZw',
#  3122: 'mQIYGEhJEoj6MxZYqxoCmw',
#  3129: 'SSOG-T0sA2UlQkhqkkHBgQ',
#  3136: 'x5G0GUkGnlWtM49Qe4nHog',
#  3143: 'AV_o0cVmufE1xq8DUlX14g',
#  3150: '0ExzIqe4ijcjkCEfj_TQ5A',
#  3157: '9-eMqJiY9YW_IVTIandMHw',
#  3164: 'DzVv_g6xsLbMh66HtiZK3A',
#  3171: 'uQvGeb0hMeNRQu6oJv0k2A',
#  3178: 'XpzeHZ_9jDynp7ONcWCTCg',
#  3185: '53-Y3Jw20QV6TeDkRjSyJQ',
#  3192: '5dFz332M4vPK9k5gbx90aQ',
#  3199: '2XZ4g_ps_H55CmxFs4Pu8A',
#  3206: 'ssmIZA9wuZxtTVTEuBeF0Q',
#  3213: '_v7lMUtdd6WlgKUEBLA_VA',
#  3220: 'vv769u0PvdQhO5IIBFAcwg',
#  3227: 'DSyBqO8U8INz9cjduM6DzQ',
#  3234: 'sCyER_dSEpznCAkkMWa8GA',
#  3241: 'YV2-i3g657ZP-vDER2dv7w',
#  3248: 'TKCUWxvknp5wAyqeOlCrVQ',
#  3255: 'MtViLqobs9m4Ia07Sdux0Q',
#  3262: 'Yba8oKwXu3qflmPFlGht2A',
#  3269: 'CUUcLheYIxjO643azprFxA',
#  3276: '6FiYR7Buwfo1dzNqFSvmyg',
#  3283: 'dixDXjgRV7sWCHv-Ik592A',
#  3290: '6yGSXuQdqsLiOZkOmd1Jsg',
#  3297: 'heYShXdxU_RVoDcGGGkn5Q',
#  3304: 'LMJW_BncFhCAu9GcZ0JIUg',
#  3311: 'RmY539rfXW8AUzF4T7vmww',
#  3318: '6hjtaTmUpwLt94Mi7MoU-g',
#  3325: 'O40nlfiMpWAKgMx7bH9h6Q',
#  3332: 's9DbjcVealcMBNxGI_wK8w',
#  3339: '9ScF7Bl_XXKBMjawtuBvNQ',
#  3346: '3CMqaslfBkngxN4aGiwcpA',
#  3353: 'NVX_BF_LcDy3fNshXMuz7w',
#  3360: 'BoTb3FqOsJaFe_koVfyGbw',
#  3367: 'VwCtpOYiCKA5VXbKZhCSVA',
#  3374: 'qgeoNhlcNPiJ0Aw4RShdGw',
#  3381: 'Qf83EYNJAXjnM2V-BnZHrQ',
#  3388: '0wGOCIGuwy1U3bJqoRiLKQ',
#  3395: 'xKbcJNaFoLziKm2JyfzfpA',
#  3402: 'cbNRJfC60908TUjmahCTYQ',
#  3409: 'LnkkArYSmU9pYRWOO6oPzw',
#  3416: 'Rt7gjrTceO86sCtnS8Td0g',
#  3423: 'SoleS7vo-3I5u0qqy4ZtxQ',
#  3430: 'io_sYEYttk1dUE-SK8PyGg',
#  3437: '0wca-OLqtMV8Ebp-W2du0g',
#  3444: 'cmcUx0yiIiuVRUhjb0kGXw',
#  3451: 'EY6o59A7qnlr1LxWpzdkiw',
#  3458: 'D-6Z-yPLjhAZlBFAw_xSuA',
#  3465: '2f90tMt0SFkwBJ6exobY3Q',
#  3472: 'qWnEshFu8L6TkERGKhm0qw',
#  3479: 'wNnPxpAOCBk2N1KTJ2PDCw',
#  3486: 'A5EadFyHhq-1rnFTq3yGHQ',
#  3493: 'UGaIul2tDd8T0jRfOGA--w',
#  3500: '4yPy4JUnNqpnS-BARkEBKQ',
#  3507: 'u74oHV8oJEicEbdFTrK0uA',
#  3514: 'ShfG3CTrb6ht5g7edjqcyg',
#  3521: '7L7frgS9I4KeTkqPXh7w2A',
#  3528: 'Lk7qMIfW-w43sWSXsuf7ZA',
#  3535: 'im2J4GZZdEl7s4o21D7rgw',
#  3542: 'zJ-V2GZ9q7UkwYFl3G116w',
#  3549: 'nJVDHjoTilGmhLjXAOwiyg',
#  3556: 'mdgUGxxJqBS5AcvE24yKOg',
#  3563: 'fihcqcjpMWTSGiR_dWLOcw',
#  3570: 'MVIthKWqwkQz0dai7LkVzQ',
#  3577: '_h44VOWq7iKqurDlRu0AlQ',
#  3584: 'UpiMwSUj1RZb5oJ4tjTppw',
#  3591: 'ZBnu1Iz4ySQ58Ow8JhrsWQ',
#  3598: 'IfUPAiF3qMPi27gi-_UZzg',
#  3605: 'fMr9T_YnJ2k-mGo4a9aIQw',
#  3612: 'tvdgapAMPBTUDNUEYbPV3Q',
#  3619: '1o3N4PiPI-fHnJnh-U85iw',
#  3626: 'j2bx_ctb_ED3zbfSaqhQmQ',
#  3633: 'wuHom3KBiBwgwRP2Z9hC5Q',
#  3640: 'iJi7yebXoPVXRyGqqL-v8g',
#  3647: 'FKL48E_EweGcnjydK0KKdA',
#  3654: 'KskYqH1Bi7Z_61pH6Om8pg',
#  3661: 'RJNAeNA-209sctUO0dmwuA',
#  3668: 'Nj3DwfsDAwogVyFrGKxgnA',
#  3675: 'R0DxkEWJfJYBxkeEds9v6w',
#  3682: 'cK5TFSRYtJcQa_BC4y30pQ',
#  3689: '8n13xwvvcuZUylr-y3eNMg',
#  3696: '6h_JDsp9VuvGFpPv2jlRsQ',
#  3703: 'EksV9mtXOQ7HGhPfyk5DMQ',
#  3710: 'GDf1SI_SnW93_lJN__egrQ',
#  3717: 'xLy3aWEbtpoUSVdjuHBS0A',
#  3724: 'RMiE7_RB0yreZqTrPEgBMQ',
#  3731: 'tzUwZKhtDX7QixvXex-wZw',
#  3738: 'TByvxX_5DZlLmf9Zs_j3xg',
#  3745: 'mPec-6ARme_8QAHd7tpJ8g',
#  3752: 'MGIgSvpT89CnKZF8n5TROg',
#  3759: '4C2anQCXmR88Kz0Y3FO7Ww',
#  3766: 'N07yhV5zVYlFP-SM3WSHbg',
#  3773: 'dc1YcZSIfvQpWFQJ3kI9oA',
#  3780: '1MQQZ2kTiBbN3_hpmGdavw',
#  3787: 'pC4MjGg8bV-eIUHRbe9WGQ',
#  3794: 'iK_3WktnHa_YlbWdA0Axkw',
#  3801: 'hUCujBvgttk5jNh_uQwi2Q',
#  3808: 'eCBHpk_jwbaxf1Q6uH3moA',
#  3815: 'dWkPcRiiEW97RwGhFZ3H5A',
#  3822: '6tdkFaMnTfDCiPG97qKVHA',
#  3829: 'lPh04gQTsF77fQnCNSyfHw',
#  3836: 'MIoaKihbI0po8kIV6cIckw',
#  3843: '_Oe8NDjmeYkkHFs7f8CekA',
#  3850: 'Mf1tLeJhoab7fN2r7rGB7g',
#  3857: 'U3_446QN2gdF87stGCfu1Q',
#  3864: '1Vbt1GsmtQm2dkC4A2L_-g',
#  3871: 'fZGTgKUNKKuOKC2tg4pQFw',
#  3878: 'zi6cB_bkswWPLD2k3IVtyg',
#  3885: 'Dq3AZ2f1BffwqRcP44Wh0w',
#  3892: 'OQWa7l95BlEbnSeCWek8gw',
#  3899: 'Rzxf129WeaGmam1Py_H_GQ',
#  3906: 'PEWqLRLzzUIeucqYdkjxYA',
#  3913: 'Ge3Up7SLgfBuNqK5ziHxVg',
#  3920: 'zgjLwTpl50zSmcAptJo4Hw',
#  3927: 'FDRttjo_-iiiUKrft8HrrQ',
#  3934: 'f46eJZ9C9mtEMYCTNnhHug',
#  3941: 'vA2aKRFspZWyxSlk0jNgbA',
#  3948: 'rdusmw5BzRHBgKglyGvUVg',
#  3955: '3zX0S3G9PLSdH3qDGIR_aQ',
#  3962: 'thBWpIcP6vclsHS6GfI1dw',
#  3969: 'pRfIJ6zurjEsWmJheDOP6A',
#  3976: 'c35qzLN6ItDpVIoj2uQW4Q',
#  3983: 'cxVp-a28Cp7lavjaPMvK5w',
#  3990: 'MR6_ysGat5UU0dhqEPcxxQ',
#  3997: 'IvC6thJkTlWmhVB8AR0luA',
#  4004: '1RKD5kqYzFcJGor2g6dBMw',
#  4011: 'K04Pbn_5-xNidh0-xkI9vw',
#  4018: 'rTfIb59txYiwjkFxjOH0tQ',
#  4025: 'ZCqcPHASk_Zyo52UHKBTYg',
#  4032: 'RjwWUrYbcuR9cTM3IRt5-w',
#  4039: 'EGhfelWCDPQSbndU2cARQg',
#  4046: 'dLAxjXghBijV6krvKt1RHQ',
#  4053: 'AanIRR6tCCgIO7OibuvE5A',
#  4060: 'OohsWZ3A0bo8y6N6vi6ePA',
#  4067: 'bftSQN9eaE5EQBe3ZztN8Q',
#  4074: 'nZZaLSXkCBYRri9ZfVOgyw',
#  4081: 'zm3w7U26kDxREFDSLJRBgQ',
#  4088: 'UNCGZu8sPnPdZSV9CaWMnw',
#  4095: '2rJfB1gOM1lwemvlC5kjBQ',
#  4102: 'gmkiuL_6TdB7uCZqQJ2JKg',
#  4109: 'VSjzy2RF0ojIVCSyEoTnXA',
#  4116: 'iuAaxB_4awLIZmWZTeeqFg',
#  4123: '2l7zjTiS-Wfr2zgViAXWcw',
#  4130: 'jFERwgaugFOj9uuT91hfCw',
#  4137: 'T6qjr_kZSH8GECSoMbx8sQ',
#  4144: 'bBYJ8OvDZuS_0GUqKuESxw',
#  4151: 'f7M0QRKGW4jh6_zYDqFUxA',
#  4158: 'OTSQq4ycH4NNhWIHcjnGaw',
#  4165: 'ttuz_S9uD0Hr-wGHM6uEBw',
#  4172: 'hFuhiLDa9uHjg4fZHjI8NQ',
#  4179: '3o1Q1eono7sWBMXecyXS1w',
#  4186: 'eOHhDT9g2y_MqrJkF3CUJg',
#  4193: '749lGtWM9PsrWonlVY4W2w',
#  4200: 'A9MJ0MDkFXvMYPzJk_Jp9w',
#  4207: 'k6EQholZjA03b-O6foAPCA',
#  4214: 'U2rIlPetIBXRIN21SlJ32g',
#  4221: 'DkYS3arLOhA8si5uUEmHOw',
#  4228: '1M3fR7WFdnz7Keg9cRWolw',
#  4235: '831DxBsLy0-91FkHRfiGCw',
#  4242: 'tWNQrXhdl22IVCqJ98rd4Q',
#  4249: 'lwuio1wYukQ_WaC8PPaS4Q',
#  4256: 'TgIglalYS9r2Sy6a-TCc2g',
#  4263: '2IvrdAb6zdxr3ZqplqJHbg',
#  4270: 'nRmTDIs3Gbis9aX2-v1qcw',
#  4277: '-0BxAGlIk5DJAGVkpqBXxg',
#  4284: 'mBBsJUT6x-_Wr9qOy3TBxQ',
#  4291: 'XCBHRifN6A5sLhxqN9Fssw',
#  4298: 'U8L8Xso7cMpNmbFMXm2V0g',
#  4305: '44cJ95tT0rr08d0e5_wyMg',
#  4312: 'm6o8x_cwqJE8QLuwV73yKg',
#  4319: '5_ymZOB8eIfi6nzzL5-SbQ',
#  4326: 'VfFHPsPtTW4Mgx0eHDyJiQ',
#  4333: '2iTsRqUsPGRH1li1WVRvKQ',
#  4340: '4tiFtmGNFcvKRSPXPVT8Hw',
#  4347: 'R_z9LFtqbBB9pANO530w9w',
#  4354: 'e-iVRNr4ag9aKOR9j_5ArQ',
#  4361: 'DrbY96jCL1UqV0Eq2YkN6g',
#  4368: 'wU_V--OY2HOE2qNcDtRP_g',
#  4375: 'pOhX1XjbBdPoO2Fyy8RGJg',
#  4382: 'LQI8R7yYXmWzWKd7wLCf2Q',
#  4389: 'Vay9xHwcvu7VRZOddBgn-A',
#  4396: 'cHdJXLlKNWixBXpDwEGb_A',
#  4403: 'Fy4t2XHIRKwMk_ocCZze0Q',
#  4410: 'XmgdFa3G_CZVfjtQEJMZfQ',
#  4417: 'E9IPxXY6pS2gTW2FBkAJmg',
#  4424: '8SwMaPL6AJIs1ZPSZ3NJ4w',
#  4431: 'YAci8e4YFgaVYyI1mDpp7Q',
#  4438: 'rUDbncoXyV-USlOz2FjzIg',
#  4445: 'URFhSrJPk7JM2pUtsuWsAg',
#  4452: 'hD1xdGhFpUObd420UMDhDg',
#  4459: '9D7h2xfVJrGkkwXDsnfV_Q',
#  4466: 'yZAGhlsrmupLbrgdKm6reg',
#  4473: 'stPpU3S-OCLZOoxOwgJb4A',
#  4480: 'AfN3Z1U6QPEgAb5F2CQm8w',
#  4487: 'XndboLEYVjm3v6MQQM-TtQ',
#  4494: '1mevg35inXfWjQKNbBQGKg',
#  4501: 'tAEKCC7h9h9A79SfYx0Prg',
#  4508: 'sahppzQJ0HtvMC7L8ILTVg',
#  4515: 'ajq9h018m0jhIHgSY_bncA',
#  4522: 'b0CStusyvwyQaAH_ts2pjQ',
#  4529: 'q6C2SPqctueWFuPvLKjCbA',
#  4536: 'e-cxqDjKEHEcISP2iGcZxg',
#  4543: '1CR2ddUcjYYwRd5JLtiRrw',
#  4550: 'CPxUsIkhYDSHqgz6sNDmqw',
#  4557: 'b_8jCti0vuouJ_fjZpdmZw',
#  4564: 'U30HnYk0SVtXHf4MrKuuiw',
#  4571: 'ibf4xvHWD4t1DOOZhidHBg',
#  4578: 'OeQUmob9q5sbEixK2-Tozw',
#  4585: 'u0IBpeFgrr9ZRvq31K_o6w',
#  4592: '38aN0fB_zHtkw1kb3lSj8g',
#  4599: 'zacTq2J8DAj4-ROHM_aRog',
#  4606: 'MH15_FQQCg6edTap3Yy_uA',
#  4613: '0OkfU0vDBprsIEd5hWuhAQ',
#  4620: 'C6C_dc78Zhzei9wrZs-tdQ',
#  4627: 'g-NKvwy8iLePEQHsoUb17g',
#  4634: 'if59L5DHM4pPMrCx9HuD8A',
#  4641: 'WO3L0pmtAO8ozspmaVdHIg',
#  4648: '28UWP-8hZ_-6klybRdzqEQ',
#  4655: 'Aj1G3nvy0tnpUkmcRMhZYg',
#  4662: 'stFchgT2o4iRwaXYxGHizQ',
#  4669: 'QzJRy39dMq844mPzj9Mlfw',
#  4676: '0_-iBZtkhJcJzdUi1yJGGg',
#  4683: 'H1j34TgbrVZkxeww9xlJTw',
#  4690: 'AL-oPXy4k9zUn3pCt9epAQ',
#  4697: 'SUEk02p6qjLfWzMZHjYSjA',
#  4704: '6HQDB-FQlloN7p8MHqSveQ',
#  4711: 'AidPnJXRWRgIG-Bt95rGdQ',
#  4718: 'BedglpnHtjQ9y9kL5mstsQ',
#  4725: '0cjjoeuuWcgrFFe0qd-eOw',
#  4732: 'izw7OBVSeNmlVhjly1amQg',
#  4739: 'CaMwTEn92eJ1T2Zfr1xcnA',
#  4746: 'OjFhcNxN83qMqLMrQUxXag',
#  4753: '1839Avk-JpsRaBtrNRbqyg',
#  4760: 'jpsG16_6JvyXO9hlOyY6nA',
#  4767: 'DwMCE7vxQV8isP0WDyA5OA',
#  4774: 'FLLpzuZh6d-UNWWph9M36g',
#  4781: '2-jI4n2kVK9ltHS-WdnGUA',
#  4788: 'gXpGMGBAv1lfQEcPOzahag',
#  4795: 'rwDJu_c584TV4CqPAwu3ZQ',
#  4802: 'Ltf3TUXESd0V9emwx8NXWA',
#  4809: 'v61dL5IvtgMwYBDNopvPYw',
#  4816: 'sILtYuwEMuwVWRa8eQCoFg',
#  4823: 'Hqnb4hwfrreszzvlzNjadA',
#  4830: 'TQm3wSTX84_g4-BzdQ1jmQ',
#  4837: 'mjDsDnoSghhIiht5cSjF4g',
#  4844: '1ylA7yyrMMUX1zcu5EqO4Q',
#  4851: '69TTOqH18qztsroIii4e6A',
#  4858: 'qNyp4GMPiRqbY3kbbPju8w',
#  4865: 's3rizT0aYEGIg-uP2SUz9w',
#  4872: 'xYZefYQ777honVZnlcD3vQ',
#  4879: '995cDn3wIwi4pw4N_uLSqw',
#  4886: 'Y6Tu9r3AaEaX41BRATQLaQ',
#  4893: '96a54JDbOU6YKFWzur98sA',
#  4900: 'ElqLoKM__uU7DcYzRnMpNw',
#  4907: '1V3fj_J0242-2PZJA6NYSg',
#  4914: 'SGkKiYxnamI5dTCEBR2umg',
#  4921: 'Wc94kBgappa9fz_2Pwez7A',
#  4928: 'fEylCY3UEH8YJ0Xa7lu6lA',
#  4935: 'by_MaktiYQc5oDPd1E9uug',
#  4942: 'M1vpbYIBt_OvQpgprX61hQ',
#  4949: '9yACFTyBd460lJD7YgYZZA',
#  4956: 'l1H6waNwJ0B8zPTa1Fcl5Q',
#  4963: '-s3nJbZRXLMSpwud22iIPA',
#  4970: 'tFXtHPDJ9hVJEb266mpnqA',
#  4977: 'j4jsgp-e315s11ehJfRzAA',
#  4984: 'CzA6ThquEWOXgVjkYeY1JA',
#  4991: 'hiJJ6BcQjlPybA2_fGp6CA',
#  4998: '2yu2vnbkI1cBPe24ys0sEw',
#  5005: 'MosZfnhkQNF1rP-JiPPPzg',
#  5012: 'bD_vqSSU_abcCT0oCzN1xA',
#  5019: 'yauL5BpUTGukejbJskXl_g',
#  5026: '4jNjYtxZ9tPOx6cl9SUIOA',
#  5033: 'K1fjQO9sT_cQWaL6nbTG6Q',
#  5040: 'oiTq668GwyXo5hMHjdW0kA',
#  5047: '9mI2BHTu0at_JA3RA_AEeg',
#  5054: '8pCjg4pMsgRA5-Tfw4neVw',
#  5061: 'pAqgiVcOY5mPouuEW96R0g',
#  5068: 'FgkU1FaanSHipt8bvuIFhw',
#  5075: 'pvcavm_yprIRBAT24JiTRQ',
#  5082: 'liPSeXaAfv8jxRGJ717VmQ',
#  5089: 'STCQj928qKb8Sj1TTLuwQA',
#  5096: 'MrovSlB5Ff0v4VGnvC2i_Q',
#  5103: '0VUbtKyg-_2Y4T1ct2KUNQ',
#  5110: 'bFlP7uApDamdiVHwX8OwfA',
#  5117: '_1Kfr84GDMEjfWdvL0BBRw',
#  5124: 'fSooCL6ZtTLnepgekEU6zQ',
#  5131: 'cZPptgtI7MgnlR5iGLLgkQ',
#  5138: 'vNlJsfKKp968CZWr8J5xDA',
#  5145: 'HmI9nhgOkrXlUr6KZGZZew',
#  5152: '137jrU-pHsEwCwQL6Dw84g',
#  5159: 'm7728TmJG-jH1vZge0EK6g',
#  5166: 'Sp8dpnVOh0SG4_4A3IOT_w',
#  5173: 'ykwGLizkYXRsYy79kDFAKg',
#  5180: '1Vvxx-9AoINg8TJXOZgEHg',
#  5187: 'pQvjqvzPGAh5B6RW2v46QA',
#  5194: 'Uwx1btib8lhsfHTUb2Cycw',
#  5201: 'wUrnir4yQj4Lnta-jdqqxQ',
#  5208: '2MQLD5la1kE6n0-DcIVu7g',
#  5215: '7Ny6x4wX1JJLqdVeKQ1JYg',
#  5222: 'AuXaNKjyBFIXtvCnWU4C7w',
#  5229: 'n3DFC_PRWyy5f_fSUuPvbA',
#  5236: '2wCzZUwcqRRBrAtBBYxnog',
#  5243: 'dUPXrfNaUnK-Doxyw_1S8g',
#  5250: '3NMrUGyQ9tTaDNDS2H2CZQ',
#  5257: 'l_kefVF1frmC0xRW2YkvUA',
#  5264: 'Nf9s7ULgb0Shnc5Mr7JweQ',
#  5271: '0Q5NpqpfjvDV3zaRt2h1EQ',
#  5278: 'fAyRPDQnvG7_PIo3GFAgzA',
#  5285: 'D3UfwfM19oQ-ReHcCjeFVw',
#  5292: 'CaCW63Y68IUlqZQARC3LdQ',
#  5299: 'E8duZ9YKVLn_n75lYY3Hyw',
#  5306: 'pPyg8s0O8JB7bDCaCj398w',
#  5313: '3gkqdLgL1Ca0hy1YRsA2Gw',
#  5320: 'hG-DApl-ua15fbIqav7-IA',
#  5327: 'toc31C-Qy2smSq0A7Q8FgA',
#  5334: 'P6c0lV9DeJ6ofntpTWyqhA',
#  5341: 'nvWb376MYChKSA-To1wyGQ',
#  5348: 'Ac3JAxptiN4wfPg-zNNCNw',
#  5355: 'O2IPbv7l5frXpdwnSZIicQ',
#  5362: 'A9IzIja0q-51YOv0ezUDag',
#  5369: 'BRZ1uct8SipLzxjEoZuC0A',
#  5376: 'ry9MaSq_tpNODhYoIyA42Q',
#  5383: 'FN-rKAu0fx4zMy_jTfw8dw',
#  5390: 'tdLzywYXCOmskX95V53G5g',
#  5397: 'MPLhOV-JbmntkbcXMyCODg',
#  5404: 'RXyBD1euUHNxhU3_LE7z6Q',
#  5411: 'xULATz2siGXOPia614mg2A',
#  5418: 'EOo2My0Wt-h942RbNRzEFQ',
#  5425: 'g5mAOknxJf9JM8_dHjlxjg',
#  5432: 'v2LLg08clPWKyNQFBVlZXg',
#  5439: '7O_mNtg37-1sMvQ5xmA8Dw',
#  5446: 'Im8C3n4D_W9ItRfmAwyxTA',
#  5453: 'dwAPMrdLwSn1KCsJzz_oLA',
#  5460: 'lSxAQR1FeSljX9zeVJTEWA',
#  5467: 'UESdOMLsXn_7WcwOZt7I3A',
#  5474: 'S-Hksc_Hh_dMEbiTWDnblQ',
#  5481: 'PRz-0bPh1FdszZqt9uq4sQ',
#  5488: 'pWffwFHO7Awb4bULH-XoDQ',
#  5495: 'Prd8JRVvPvL2d32GgtNCwQ',
#  5502: 'SGapZBbSgSYY3fziaskULQ',
#  5509: 'xCR6outQ51G0o3zaCUXDxw',
#  5516: 'rcaPajgKOJC2vo_l3xa42A',
#  5523: '74PuNP7egqbaloqDecGsrA',
#  5530: '9JFrPxt656fpjLIeBAFg1w',
#  5537: 'IapQwLdAwztQYN99pQui3w',
#  5544: 'MYyJ9orpiRq0prjVq4ku7w',
#  5551: 'I94IGseS7WnW2ChK0x9BZg',
#  5558: 'KsTsrgto44J3F4vIR0HEAw',
#  5565: 'V29Yw_j2j6VLXRUUZ3uWng',
#  5572: 'vRP9i7ev4hWDf818xUZy6g',
#  5579: 'UYop9KYT-_mJsc2bcH83jw',
#  5586: 'Sg2l7S_huzkRLmk2NoeuSg',
#  5593: 'dHEWn0xIwRlqisLgrfw8vQ',
#  5600: 'FMLJ7orzQQwWxfgeqrvlCQ',
#  5607: 'WTi4ZE99EGuoI3P27vpH8g',
#  5614: 'EQRLqm_pfEgZrSAkYVbBqQ',
#  5621: 'oaTbZh8B-IVFEwbzJcIOBg',
#  5628: 'nwN2iLdDDEYU5-qkLEsPNw',
#  5635: 'ZL6BK8wweb-8ncJ7kFIG-A',
#  5642: '5q_zOkd2X8lU775IoUnxBQ',
#  5649: 'QnTguWLRKRK_reQ__8k7yw',
#  5656: '9hSqfyIrYXsr2WZoLaTV5A',
#  5663: 'n0NH0FW8NU3zfeJY3QluMQ',
#  5670: '7SLdPD6ve1hhrrN_sMH7Fw',
#  5677: '0qsarzXaZau8REdE0rToxA',
#  5684: '8KmqWgL0UEdxJFwTZ_YZvQ',
#  5691: '4twpbw7n4DmsLxAm6-sMkg',
#  5698: 'TKaND6oV1n2ylnCYoAfoag',
#  5705: 'ckycv0GfCz-Ye2V09BFl8Q',
#  5712: 'Nri8ZIsZGGdel0PBRIm6tw',
#  5719: 'CCRgGKhzxSpl38w7yhqKUw',
#  5726: 'e99T6GFJZKebgG3qO9i6Pw',
#  5733: 'YxooeHhZ8NUYO20tOOFDCQ',
#  5740: 'WWVOO8Ha1CUwjFPJ6msihA',
#  5747: 'G7QZWVm-ytyKHpvUq3ggFA',
#  5754: 'CofqjNylNVBkfx266OR9vw',
#  5761: 'Oft6C2yq-1AmcqmutODGIQ',
#  5768: 'EAwh1OmG6t6p3nRaZOW_AA',
#  5775: 'sKVnJqyQlENOXRdsaStYDA',
#  5782: 'Zvlj-r49ftG7FNCpxKoUiA',
#  5789: 'M7O_XMe0eWPMQyjPe_KY_A',
#  5796: 'wftmt-n8OUA4Ng3bWWH5dw',
#  5803: 'gcYwWmzzzC4raKZ5FoTsNw',
#  5810: 'uDTh-jplczxX9iv6flcrBA',
#  5817: 'JnRZbZ7E4VpCh83U56CPMA',
#  5824: 'LrEjsBYlqXdig7x5DFz0ow',
#  5831: '9MPLntyNzhdUXpGT-h0HUw',
#  5838: 'YwXqGKiD9axunX1VlJMIsA',
#  5845: '1ofeAP5vdjnOSeO5S2pzSg',
#  5852: 'DkEOy5-hSds5Y9RvxMzCVg',
#  5859: 'XsYLY9LLaFB45MW88AyUHg',
#  5866: '2PBPh8LTwt_mXP0GUYa9NQ',
#  5873: 'ruWTngdiC68O9la27hvvHw',
#  5880: 'X9KOQUXiEH94QDpgeRofyg',
#  5887: 'oyQ5CRBeTjpv5OwIo21TMA',
#  5894: 'UOgXJSfTk5rFvENXL-4xgg',
#  5901: '-uPtUCKK2sctjV8JcCM2rQ',
#  5908: '3YWxVDgKctiVBCSXFEuWcg',
#  5915: 'FrEVQuO1Qr6LlIEY7ycJQw',
#  5922: 'Tcqj9kMSKC1fPyNgXpczFQ',
#  5929: 'zStrtfesb610i8otA6mIJQ',
#  5936: 'WuTdb365xF8kY2KAu6gm9A',
#  5943: 'aWP9BbRqMBP5Wc2xrfFmog',
#  5950: 'Sb2a5N9gSLICYkMVSjszsA',
#  5957: '1v9TVINzMod7JfSQI7Aayw',
#  5964: 'YPtjfnmsm0K6747d-g5HKg',
#  5971: '2mEBIa3NSKyS6UIfxpKR9g',
#  5978: 'nCHs1mANWBdFIAYBKdUy4Q',
#  5985: 'CJX5vuFPv4dYEfuQ1KU94g',
#  5992: 'BjnJKoYFmjBRHUCCcUkiwg',
#  5999: 'NfYA4ntbt1CeqmzrSipVpg',
#  6006: 'DD9iLVS8C8pqLhLkPs0eQg',
#  6013: 'Q_2DxyQ9nHLRdYciJaNLHg',
#  6020: 'xVopquE2JKetpNJkor_jOA',
#  6027: 'ih2F8a3IM8gJSmBKvYCS4w',
#  6034: 'qLy2F9EzCsFYIKd40OJvZA',
#  6041: 'P_Sv7-nv4FhrfS8Byldnfg',
#  6048: 'pYeQ80rPttM6KzMQ3MXE8g',
#  6055: 'LpKloJ5DFU1rjEENALnGZg',
#  6062: '5G-ulG_g_MpcIYlNzaCMmA',
#  6069: 't1D7K0mG37aSk8x1Pj54VA',
#  6076: 'qpfbMbWB_ROqe35MIO_amw',
#  6083: 'Tuj_q3-gFRsRzR1xxQqNeA',
#  6090: '4hJHSMKyKJRl50k9EM6jkA',
#  6097: 'U8FC3Z_L_tHEUIvkwSSAXw',
#  6104: 'jVaDrytDdOmkQX9moPWHTA',
#  6111: 'c1y77QPMdkSaomMPjGNXPw',
#  6118: 'jBxoNxh4OtXJT1yYOoomvQ',
#  6125: '92KZBnzEki_70Dh_IB_Vkg',
#  6132: 'EgtyW19V-64c6PmRuvzSEA',
#  6139: 'DxgSVufr_6y_Rc63CC17Zg',
#  6146: 'SIWwh4m6kkvUaa5skrVAQQ',
#  6153: 'j0B0CYbvHMMLBcE9tNHiYg',
#  6160: 'YWLkcMOx6YmCxDlLjBG8eA',
#  6167: 'ttKbmaIhQREGeT2esJnIMQ',
#  6174: 'UTodxk-Mjmvf_Zc7f5pdTw',
#  6181: 'n9r6Rxr3gxbZiSHWEB7ujg',
#  6188: 'yFumR3CWzpfvTH2FCthvVw',
#  6195: '89N3YfIoe50feyqS0qwMXg',
#  6202: '3BBkhChwKTEx9l83bIl1ng',
#  6209: 'QcxB4grIr-bLSqqydTV6Ag',
#  6216: 'r_ZcprwRLOC1IHcJ6fRg8g',
#  6223: 'nJj6lNHq30xYDsCfLughCw',
#  6230: 'mhaAZW7jjpwUgicYuFXgXA',
#  6237: 'hqineK2tQMxcZ9iQVMPlQA',
#  6244: 'OCrIahNGIu0lipGuqiiApA',
#  6251: 'jmVkdK74daUoD2_kfsCTyw',
#  6258: 'PIm9f5--JwYqep5eKycEWg',
#  6265: 'YnGa16TSqBCcQyJDm9PIuA',
#  6272: 'BsLxCm_DMxCNVEPHoaj8hw',
#  6279: 'vfsbLhXGiXm8lqI12abrbQ',
#  6286: '1dl1WpWpVW1KjXbEcVZQlg',
#  6293: 'ggVKI26wizfVcXXIKMXXmA',
#  6300: '9x7LXcLO87GiwMMduqFcCQ',
#  6307: 'p7GsNqUSIjAd7TV1sZUBxQ',
#  6314: 'MG_OxSRPUs2WqtQCMCn1Xg',
#  6321: 'ogmjK0R0K9vpPTfhNKrXzg',
#  6328: '5o5xDSgOocBEeu_MVIckTg',
#  6335: '3Wl58ou8llxY2UMRKwaICg',
#  6342: 'Wsk9CyM-FhybMA48I38JKg',
#  6349: '-OHcd6mJL90wiQYE1e3gGg',
#  6356: '7TMcUzNqnUV5Bfwni800HQ',
#  6363: 'vW9WldtS_zDa6LyAn5x3aw',
#  6370: '7T6K5UQuEa_Ia8gZu6NoEg',
#  6377: '22lLsW2-h6enhfaJBknCMg',
#  6384: 'XuvmzFC-_mmSymB-aYurpg',
#  6391: 'E_lefFxPNhu8aT70nToR6Q',
#  6398: 'kWPCYYQZb6w6Eny2Cz0rnQ',
#  6405: '--cjBEbXMI2obtaRHNSFrA',
#  6412: 'cCM4ERe4Ot9oMuAiJb0F_Q',
#  6419: 'N7IWzVy-2t8qDKLLk81jXw',
#  6426: '4aWJLkiyxJVpTWVJePv_sg',
#  6433: 'WmRWGaUK8pU_hBLSdDUuJA',
#  6440: '_QkGfsQaQbuyUf-hy_2muw',
#  6447: 'Hdnx6cZBo0JfZopnQDWVYg',
#  6454: 'VC2TurJlC6DokYu_lHOVSg',
#  6461: 'Ku4iZZ9hvKHd2u2yzoFj0A',
#  6468: 'rpck22B4eb5GyqSZfE1Ukg',
#  6475: 'Bqz24USKl4Rpb2nfGKo1XA',
#  6482: 'MDSNSm8D7Jhp6EUKpOha5w',
#  6489: 'yTeTCkzIIw1rXatDWh_ISA',
#  6496: '_6hReDyVSr94W2WMO1LJLw',
#  6503: 'QweIJ0v_XL1GCCEzco7w9Q',
#  6510: '63ieHAevJ5szVnClT8FzGQ',
#  6517: 'FdbCq4kPInhZlJKEYL5P8Q',
#  6524: '7I_xWHdCaH-CtZLQGkhsjg',
#  6531: '260JIedrJp04Y5HBXsmAVg',
#  6538: 'CV1VfZBR38LFR0pGSfBGwg',
#  6545: 'OizfDRfXlr8qUShdWwiCEA',
#  6552: 'WO3P5BpPHYB-zbDgJZOuCw',
#  6559: 'JVJ9v-gFH68m6hA1NyQmbg',
#  6566: '20ib4z2Yo2wlfARFMcFwSQ',
#  6573: 'qR5xHLWGJXvuWLTTwCYkLw',
#  6580: 'PWhD0UuipXzkp1rv6praCA',
#  6587: 'UyZqOcWxShRRtACCkZFkpQ',
#  6594: 'LQBq9du2mcxK-RndgNofnA',
#  6601: 'x7upRA9Av-WpljTrri1rtw',
#  6608: 'PVZvb1Cr0IUcJq5xiEqkgA',
#  6615: '5_cn7M-9swHrFbnqZtYGBQ',
#  6622: 'OoI3WUe4Xl86d53avy3oVA',
#  6629: 'T6qMxypoF9rrI4XG2enlWA',
#  6636: 'MfAkKXp-nZpmGhfPXNlLEw',
#  6643: 'uBNa7bGlgglxSy-HLaN_Dw',
#  6650: 'cw4m6QjZVG2PkdSYeim1Gg',
#  6657: 'P6O50VeFlBIJpP0QPYsXbQ',
#  6664: 'sWqQQRiD3YBxNJlPrMSNIw',
#  6671: 'jY7Ql_Qk8duv7jZrMZahaw',
#  6678: 'z26ZG4Zv6P1itMq4VC5zGQ',
#  6685: 'EY8Kuqx5gxcfMLsyq84lSg',
#  6692: 'Gml97gSULiA6HFjie01d3Q',
#  6699: '3nzK3K-Dfo1L6mpB8FTKkw',
#  6706: 'KhvwEXKJXRTgcJRNmJNhsA',
#  6713: 'ghDNHpqETRJGxG5iUtaZtw',
#  6720: 'YILyHegzhy1vlc_LNVfObw',
#  6727: 'eaNenRk_liZBERFFLCXqqQ',
#  6734: 'XU-52fK8L5e9cpwPgvp34Q',
#  6741: 'wkKlpSx3OcoGJiv7p8VZzw',
#  6748: 'sz6_gKcHjtcpWKIZLXV85w',
#  6755: 'pgCwweX7pWyjEsAAIo-vrQ',
#  6762: 'uuaxHHCABQmJL12jrC5k2w',
#  6769: '4GXII-GU7S0ZyU6ElkhscQ',
#  6776: 'L3dAvYkqMsLhyPLoeJgwsQ',
#  6783: '5T6kFKFycym_GkhgOiysIw',
#  6790: '74vqVbTFUYqvSqrBiVj6RA',
#  6797: 'nXgyXL-OXk6NGi477xt5eA',
#  6804: 'Z0U46Uee8TNY_rZXqBeHjA',
#  6811: 'ZBKpDT_PqTWRuqDVDoWqLA',
#  6818: 'b6vi3Ub0tbGzGtG-pVgJfQ',
#  6825: '3ylcv8d9010OTlZ_yNWvtw',
#  6832: 'v3rXLmTCX6ZFR6kIYTY2fg',
#  6839: 'a6iD1btU3fo6P6UV-YFLsw',
#  6846: 'TrCiLMGy_bxbeAQcuSSUeQ',
#  6853: 'J38n-oFC0V_PUo4qcTxang',
#  6860: 'qYpaEjltL1xSxqx3VYpyGw',
#  6867: 'L1KkmY4vTgCrS1J5aUFMtA',
#  6874: 'vn0wYNms_5PseeYZ6pfLmA',
#  6881: '5V9i2FuhQ3o8ynYwbubmQg',
#  6888: 'BYBUMAn6ts1HInNZ5PP9FA',
#  6895: 'MHH6mQtGZ8BUmb_PE-3vuw',
#  6902: 'x8wDG0ASWFZTRMvUFnynRA',
#  6909: '9_onoqwv9ZdItxc8OlUKAg',
#  6916: '0apMOBL1jGoHqOXDivMszg',
#  6923: 'x8-MzrVwJCwzqoACL21AJw',
#  6930: 'Eq49yASGm5OLM0HMh3nZEw',
#  6937: 'Vu641FmSuZcUBI8PymYRIg',
#  6944: 'tOUFYUVuhdvtHVSrYu2hwA',
#  6951: '3ug1xM71zxibq5RETXCi4Q',
#  6958: 'cSVmQusncacVHsCHObA1Gg',
#  6965: 'kj1p6NwUGROOoqNySf0I1Q',
#  6972: '-Y0HN99LWf43NYQAx0T5aQ',
#  6979: 'F-QY0xyNi9z1p0wjZvnk3g',
#  6986: 'mPfdYJj4d5KBPINDkaZY-Q',
#  6993: 'gFyntTks-Qd5CjDU8_2Kog',
#  ...}

# %%
affinity_dict[14, 56]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 affinity_dict[14, 56]
#
# KeyError: (14, 56)

# %%
def get_affinity_score(row):
    user_index = user_to_num_dict.get(row['user_id'], None)
    biz_index = biz_to_num_dict.get(row['business_id'], None)
    if user_index is not None and biz_index is not None:
        return affinity_dict.get((user_index, biz_index), None)
    return None

# %%
val_df['affinity_score'] = val_df.apply(get_affinity_score, axis=1)

# %%
val_df.head()
# Out:
#                   user_id             business_id  stars  affinity_score
# 0  wf1GqnKQuvH-V3QN80UOOQ  fThrN4tfupIGetkrz18JOg    5.0             NaN
# 1  39FT2Ui8KUXwmUt6hnwy-g  uW6UHfONAmm8QttPkbMewQ    5.0             NaN
# 2  7weuSPSSqYLUFga6IYP4pg  IhNASEZ3XnBHmuuVnWdIwA    4.0             NaN
# 3  CqaIzLiWaa-lMFYBAsYQxw  G859H6xfAmVLxbzQgipuoA    5.0             NaN
# 4  yy7shAsNWRbGg-8Y67Dzag  rS39YnrhoXmPqHLzCBjeqw    3.0             NaN

# %%
affinity_dict[(0,60)]
# Out:
# 0.18571836330326622

# %% [markdown]
# ## Archived

# %%
# unknown_user_entries = processed_scores_rdd.filter(lambda x: x[0][0] == "Unknown User").collect()
# count_unknown_user = len(unknown_user_entries)

# # 查找包含"Unknown Business"的条目
# unknown_business_entries = processed_scores_rdd.filter(lambda x: x[0][1] == "Unknown Business").collect()
# count_unknown_business = len(unknown_business_entries)

# # 打印结果
# print("Number of entries with 'Unknown User':", count_unknown_user)
# print("Number of entries with 'Unknown Business':", count_unknown_business)

# %%
# def calculate_affinity_scores(sc, user_features, business_features_bcast, user_ids_bcast, business_ids_bcast):
#     """
#     计算每个用户与所有商户之间的亲和力得分，并使用广播变量映射用户和商户ID, Avoid CrossJoin。

#     :param user_features: 用户特征向量的字典
#     :param business_features_bcast: 商户特征向量的广播变量
#     :param user_ids_bcast: 用户ID映射表的广播变量
#     :param business_ids_bcast: 商户ID映射表的广播变量
#     :return: RDD，包含((用户ID字符串, 商户ID字符串), 亲和力得分)
#     """

#     if business_features_bcast.value is None:
#         raise Exception("Broadcast variable not loaded correctly")

#     # 转换用户特征字典为RDD
#     users_rdd = sc.parallelize(user_features.items(), numSlices=100).cache()
    
#     # 计算亲和力得分
#     def calculate_scores(user_item):
#         user_id, user_vec = user_item
#         results = []
#         user_id_str = user_ids_bcast.value.get(user_id, "Unknown User")
#         for biz_id, biz_vec in business_features_bcast.value.items():
#             biz_id_str = business_ids_bcast.value.get(biz_id, "Unknown Business")
#             score = np.dot(user_vec, biz_vec)
#             results.append(((user_id_str, biz_id_str), score))
#         return results

#     # 对每个用户进行计算
#     scores_rdd = users_rdd.flatMap(calculate_scores)
    
#     return scores_rdd

# # Usage: 
# # user_features, business_features_bcast, user_ids_bcast, business_ids_bcast = matrix_factorization_als(data_path)
# # processed_scores_rdd = calculate_affinity_scores(sc, user_features, business_features_bcast, user_ids_bcast, business_ids_bcast)

# %%
# # 计算亲和力分数
# user_features = best_model.userFeatures()
# item_features = best_model.productFeatures()

# # 将特征转换为字典形式，方便查找
# user_feature_dict = {k: v for k, v in user_features}
# item_feature_dict = {k: v for k, v in item_features}

# # 计算点积
# def affinity_score(user, item):
#     """计算用户和商户之间的亲和力分数"""
#     user_vector = np.array(user_feature_dict[user])
#     item_vector = np.array(item_feature_dict[item])
#     return np.dot(user_vector, item_vector)

# # 示例：计算验证集中某个用户-商户对的亲和力分数
# example_user_item_pair = (example_user_id, example_item_id)
# score = affinity_score(*example_user_item_pair)
# print(f"Affinity Score for user {example_user_id} and item {example_item_id}: {score}")

# %% [markdown]
# # FAILURE ANALYSIS
# 代码出现问题主要是因为在使用Apache Spark进行分布式计算时，涉及到函数的序列化和网络传输。特别是当在Spark的转换函数（如map、filter等）中使用外部变量或数据结构（如RDD）时，如果这些外部引用不能被有效序列化，就会导致运行错误。
#
# - 原因分析
#
# > 非法引用外部RDD：在您的初始代码中，函数train_model尝试直接使用外部定义的RDD（training_rdd和validation_rdd），这在Spark中是不允许的。因为Spark的设计不允许在一个节点上的执行函数中直接引用另一个节点上的数据结构，这样的操作会引起序列化问题，因为RDD本身并不支持序列化。
#
# - 广播变量的错误使用：尽管广播变量用来解决类似问题很有效，但在您的初始尝试中，可能存在对这些广播变量使用不当的情况，导致了序列化错误。
#
# - PicklingError：这是Python的一个序列化错误，常在尝试将函数（尤其是包含不可序列化对象引用的函数）进行序列化时出现。在您的代码中，尝试将含有RDD操作的函数进行分布式传输时遇到了这个问题。
#
# 为了解决这些问题，我进行了以下几个关键的修改：
#
# 1. 函数封装和参数化：
#
# > 重新封装了train_model函数，使其不直接引用任何外部RDD。相反，通过函数参数将必要的数据（例如映射字典）传入，确保了函数的独立性和可序列化性。
# 这样做不仅避免了序列化问题，也使得函数更加通用和可重用。
#
# 2. 使用广播变量传递小数据集：
#
# > 将用户和商家的ID映射转换为广播变量，这样每个节点可以独立访问这些数据而无需通过网络传输。
# 广播变量是Spark专门为了高效分布式处理而设计的一种数据结构，可以避免数据的重复传输，提升计算效率。
#
# 3. 本地化RDD操作：
#
# > 在train_model中，创建局部的RDD处理逻辑，确保所有RDD操作都在函数内部定义和执行，不依赖外部的RDD状态。
# 这个改动有助于提升函数的封闭性和网络传输的安全性，因为所有的数据流都在预定义的操作范围内完成
#
#
# 通过上述修改，代码现在可以在分布式环境中安全有效地运行，同时避免了常见的序列化和RDD操作错误。
#
# Note:考虑使用更高级的调优工具：如使用Apache Spark的MLlib中的CrossValidator或TrainValidationSplit来进行更系统的模型评估和参数调优。

# %%
# from pyspark.mllib.recommendation import ALS, Rating
# from pyspark import SparkContext
# from math import sqrt
# import itertools

# user_to_num_dict = user_ids_bcast.value
# business_to_num_dict = business_ids_bcast.value
# user_to_num_bc = sc.broadcast(user_to_num_dict)
# business_to_num_bc = sc.broadcast(business_to_num_dict)

# # Create Train, Val Set: ((user_id, business_id), count) format
# training_rdd, validation_rdd = user_business_interaction_counts.randomSplit([0.8, 0.2], seed=42)

# # 改为从全部数据集构建映射，而不只是训练集
# full_rdd = user_business_interaction_counts
# user_to_num = full_rdd.map(lambda p: p[0][0]).distinct().zipWithIndex().collectAsMap()
# business_to_num = full_rdd.map(lambda p: p[0][1]).distinct().zipWithIndex().collectAsMap()

# # 广播映射字典
# user_to_num_bc = sc.broadcast(user_to_num)
# business_to_num_bc = sc.broadcast(business_to_num)

# # 准备验证集的RDD，增加错误处理
# validation_for_predict_rdd = validation_rdd.map(
#     lambda p: (
#         user_to_num_bc.value.get(p[0][0], -1),  # 使用get方法，如果ID不存在返回-1
#         business_to_num_bc.value.get(p[0][1], -1)
#     )
# )

# try:
#     collected_data = validation_for_predict_rdd.collect()
#     print("Data collected successfully:", collected_data[:5])  # 打印前5条数据
# except Exception as e:
#     print("Error in collecting data:", e)

# validation_for_predict_rdd.filter(lambda x: x[1] == -1).count()

# def train_model(params):
#     rank, reg_param, alpha = params
#     # Explicitly extract broadcast variables to avoid any hidden serialization issues.
#     user_to_num = user_to_num_bc.value
#     business_to_num = business_to_num_bc.value
    
#     # Construct the ratings and validation RDDs within the function to avoid any serialization issues
#     def rating_mapper(p):
#         user_id = user_to_num.get(p[0][0], -1)
#         business_id = business_to_num.get(p[0][1], -1)
#         return Rating(user_id, business_id, float(p[1]))
    
#     def validation_mapper(p):
#         return (user_to_num.get(p[0][0], -1), business_to_num.get(p[0][1], -1))

#     local_ratings_rdd = training_rdd.map(rating_mapper)
#     local_validation_for_predict_rdd = validation_rdd.map(validation_mapper)

#     # Train model using the locally created RDDs
#     model = ALS.trainImplicit(local_ratings_rdd, rank, iterations=10, lambda_=reg_param, alpha=alpha)

#     # Predict and calculate RMSE
#     predictions = model.predictAll(local_validation_for_predict_rdd).map(lambda r: ((r.user, r.product), r.rating))
#     rates_and_preds = validation_rdd.map(
#         lambda p: ((user_to_num.get(p[0][0], -1), business_to_num.get(p[0][1], -1)), p[1])
#     ).join(predictions)
#     rmse = sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

#     return (rmse, rank, reg_param, alpha)

# # 并行执行网格搜索
# params_rdd = sc.parallelize([(5, 0.01, 1.0), (10, 0.1, 0.1)])  # Example parameter set
# results = params_rdd.map(train_model).collect()
# best_params = min(results, key=lambda x: x[0])

# Exception: It appears that you are attempting to broadcast an RDD or reference an RDD from an action or transformation. RDD transformations and actions can only be invoked by the driver, not inside of other transformations; for example, rdd1.map(lambda x: rdd2.values.count() * x) is invalid because the values transformation and count action cannot be performed inside of the rdd1.map transformation. For more information, see SPARK-5063.

# During handling of the above exception, another exception occurred:

# PicklingError                             Traceback (most recent call last)
# Cell In[32], line 5
#       2 sc = SparkContext.getOrCreate()
#       4 params_rdd = sc.parallelize([(5, 0.01, 1.0), (10, 0.1, 0.1)])  # Example parameter set
# ----> 5 results = params_rdd.map(train_model).collect()
#       7 best_params = min(results, key=lambda x: x[0])
